# %%
cd /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus
# Out:
# /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus

# %%
from sklearn.metrics import cohen_kappa_score
import pandas as pd

# %%
# rater1 = ['yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes']
# rater2 = ['yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes']

# multi_rater = pd.read_csv('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment Analysis/Kappa_Calculate/multi_rater_3.csv')
multi_rater = pd.read_csv('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus/outsourced_for_tagging/for_kappa_calculate.csv')

start = 1
end = 100
rater1 = multi_rater['ashan'][start:end]
rater2 = multi_rater['lahiru'][start:end]

# %%
kappa = cohen_kappa_score(rater1, rater2)
print(kappa)
# Out:
# 0.467741935483871
