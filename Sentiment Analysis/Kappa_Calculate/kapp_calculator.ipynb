# %%
cd /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus
# Out:
# /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus

# %%
from sklearn.metrics import cohen_kappa_score
import pandas as pd
import numpy as np

# %%
# rater1 = ['yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes']
# rater2 = ['yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes']

multi_rater = pd.read_csv('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment Analysis/Kappa_Calculate/tagged_by_dataPirates.csv')
# multi_rater = pd.read_csv('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus/outsourced_for_tagging/Reviews for Pramuditha - gossipLanka_500_600.csv')

#load file = 0 -> actual_file = 2
# start = 998
# end = 1098
# start = 2398
# end = 2498
# start = 2998
# end = 3098
start = 3898
end = 3998
# start = 5998
# end = 6098
# start = 7498
# end = 7598

rater1 = multi_rater['corrected_label'][start:end]
rater2 = multi_rater['tagged_for_review'][start:end]

# %%
# rater1 =  multi_rater['corrected_label'].to_numpy()
# rater2 =  multi_rater['tagged_for_review'].to_numpy()

# rater1 = rater1[:,np.r_[998:1098,2398:2498,2998:3098,3898:3998,5998:6098,7498:7598]]
# rater2 = rater2[:,np.r_[998:1098,2398:2498,2998:3098,3898:3998,5998:6098,7498:7598]]

# rater1 =  multi_rater['corrected_label'].ix[998:1098,2398:2498,2998:3098,3898:3998,5998:6098,7498:7598]
# rater2 = multi_rater['tagged_for_review'].ix[998:1098,2398:2498,2998:3098,3898:3998,5998:6098,7498:7598]

# %%
kappa = cohen_kappa_score(rater1, rater2)
print(kappa)
# Out:
# 0.5674463313040692
