# %%
import pandas as pd

data_path = '/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus/new/preprocess_from_unicode_values/'

data = pd.read_csv(data_path + 'gossip_lanka_all_comments.csv',',')

print(len(data))

# comments_200 = data['comment'][:2000]

# comments_200.to_csv(data_path + 'lankadeepa_2000.csv',',')
# Out:
# 30437
