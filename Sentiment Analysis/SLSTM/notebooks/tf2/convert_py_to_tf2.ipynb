# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
cd /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment Analysis/SLSTM/tf2
# Out:
# /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment Analysis/SLSTM/tf2

# %%
# !tf_upgrade_v2 \
  --infile slstm_with_fasttext_with_skopt.py \
  --outfile slstm_with_fasttext_with_skopt_tf2.py

# %%
# !pip install ipynb-py-convert
# Out:
# ...
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.5-cp36-none-any.whl size=4323 sha256=811b752dc9442c213f40966654ae224abddd6d54baeabd060aaff424b962faed
#   Stored in directory: /root/.cache/pip/wheels/d4/99/01/24932d0201ed03d2d9e129b40f8e933e8ab51329ed88380cdc
# Successfully built ipynb-py-convert
# ...

# %% [markdown]
# # covert *.py to *.ipynb

# %%
import sys

import nbformat
from nbformat.v4 import new_notebook, new_code_cell

nb = new_notebook()
with open("slstm_with_fasttext_with_skopt_tf2.py") as f:
    code = f.read()

nb.cells.append(new_code_cell(code))
nbformat.write(nb, "slstm_with_fasttext_with_skopt_tf2"+'.ipynb')
