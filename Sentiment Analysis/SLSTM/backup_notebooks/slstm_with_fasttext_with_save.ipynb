# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/My Drive/University/FYP/Sentiment Analysis/supportive/S-LSTM/classfication/parsed_data/from_fasttext/data_set'
vector_path = '/content/drive/My Drive/University/FYP/Sentiment Analysis/supportive/S-LSTM/classfication/parsed_data/from_fasttext/fasttext_vectors'
# run from lahiru1st@gmail.com
# path='/content/drive/My Drive/UNI/FYP/Sentiment Analysis/supportive/S-LSTM/classfication/parsed_data/from_fasttext/data_set'
# vector_path = '/content/drive/My Drive/UNI/FYP/Sentiment Analysis/supportive/S-LSTM/classfication/parsed_data/from_fasttext/fasttext_vectors'

# %% [markdown]
# # Imports

# %% [markdown]
# ## Standard Imports

# %%
from __future__ import print_function
# import six.moves.cPickle as pickle
# from collections import OrderedDict
import sys
import time
import numpy as np
import tensorflow as tf
# import read_data
# from random import shuffle
# import random
import pickle
# import math
from keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import confusion_matrix
# from general_utils import Progbar
# import tensorflow.contrib.slim as slim
# from sst_config import Config

# %% [markdown]
# ## config

# %%
class Config(object):
    vocab_size=15000
    max_grad_norm = 5
    init_scale = 0.05
    hidden_size = 300
    lr_decay = 0.95
    valid_portion=0.0
    batch_size=5
    keep_prob = 0.5
    #0.05
    learning_rate = 0.002
    max_epoch =2
    # max_max_epoch =40
    max_max_epoch = 500
    num_label=5
    attention_iteration=3
    random_initialize=False
    embedding_trainable=True
    l2_beta=0.0

# %% [markdown]
# ## Progbar

# %%
import time
import sys
import logging
import numpy as np


class Progbar(object):
    """Progbar class copied from keras (https://github.com/fchollet/keras/)

    Displays a progress bar.
    Small edit : added strict arg to update
    # Arguments
        target: Total number of steps expected.
        interval: Minimum visual progress update interval (in seconds).
    """

    def __init__(self, target, width=30, verbose=0):
        self.width = width
        self.target = target
        self.sum_values = {}
        self.unique_values = []
        self.start = time.time()
        self.total_width = 0
        self.seen_so_far = 0
        self.verbose = verbose

    def update(self, current, values=[], exact=[], strict=[]):
        """
        Updates the progress bar.
        # Arguments
            current: Index of current step.
            values: List of tuples (name, value_for_last_step).
                The progress bar will display averages for these values.
            exact: List of tuples (name, value_for_last_step).
                The progress bar will display these values directly.
        """

        for k, v in values:
            if k not in self.sum_values:
                self.sum_values[k] = [v * (current - self.seen_so_far),
                                      current - self.seen_so_far]
                self.unique_values.append(k)
            else:
                self.sum_values[k][0] += v * (current - self.seen_so_far)
                self.sum_values[k][1] += (current - self.seen_so_far)
        for k, v in exact:
            if k not in self.sum_values:
                self.unique_values.append(k)
            self.sum_values[k] = [v, 1]

        for k, v in strict:
            if k not in self.sum_values:
                self.unique_values.append(k)
            self.sum_values[k] = v

        self.seen_so_far = current

        now = time.time()
        if self.verbose == 1:
            prev_total_width = self.total_width
            sys.stdout.write("\b" * prev_total_width)
            sys.stdout.write("\r")

            numdigits = int(np.floor(np.log10(self.target))) + 1
            barstr = '%%%dd/%%%dd [' % (numdigits, numdigits)
            bar = barstr % (current, self.target)
            prog = float(current)/self.target
            prog_width = int(self.width*prog)
            if prog_width > 0:
                bar += ('='*(prog_width-1))
                if current < self.target:
                    bar += '>'
                else:
                    bar += '='
            bar += ('.'*(self.width-prog_width))
            bar += ']'
            sys.stdout.write(bar)
            self.total_width = len(bar)

            if current:
                time_per_unit = (now - self.start) / current
            else:
                time_per_unit = 0
            eta = time_per_unit*(self.target - current)
            info = ''
            if current < self.target:
                info += ' - ETA: %ds' % eta
            else:
                info += ' - %ds' % (now - self.start)
            for k in self.unique_values:
                if type(self.sum_values[k]) is list:
                    info += ' - %s: %.4f' % (k,
                        self.sum_values[k][0] / max(1, self.sum_values[k][1]))
                else:
                    info += ' - %s: %s' % (k, self.sum_values[k])

            self.total_width += len(info)
            if prev_total_width > self.total_width:
                info += ((prev_total_width-self.total_width) * " ")

            sys.stdout.write(info)
            sys.stdout.flush()

            if current >= self.target:
                sys.stdout.write("\n")

        if self.verbose == 2:
            if current >= self.target:
                info = '%ds' % (now - self.start)
                for k in self.unique_values:
                    info += ' - %s: %.4f' % (k,
                        self.sum_values[k][0] / max(1, self.sum_values[k][1]))
                sys.stdout.write(info + "\n")

    def add(self, n, values=[]):
        self.update(self.seen_so_far+n, values)

# %% [markdown]
# ## Read Data

# %%
from __future__ import print_function
from six.moves import xrange
import six.moves.cPickle as pickle
import gzip
import os
import numpy

def generate_matrix(seqs, maxlen, lengths):
    n_samples = len(seqs)
    x= numpy.zeros((n_samples, maxlen)).astype('int64')

    for idx, s in enumerate(seqs):
        if lengths[idx]>= maxlen:
            s=s[:maxlen]
        x[idx, :lengths[idx]] = s
    return x

def prepare_data(seqs, labels):
    lengths = [len(s) for s in seqs]
    labels = numpy.array(labels).astype('int32')
    return [numpy.array(seqs), labels, numpy.array(lengths).astype('int32')]

def remove_unk(x, n_words):
    return [[1 if w >= n_words else w for w in sen] for sen in x] 

def load_data(path, n_words):
    with open(path, 'rb') as f:
        dataset_x, dataset_label= pickle.load(f)
        train_set_x, train_set_y = dataset_x[0], dataset_label[0]
        # valid_set_x, valid_set_y =dataset_x[1], dataset_label[1]
        test_set_x, test_set_y = dataset_x[1], dataset_label[1]
    #remove unknown words
    train_set_x = remove_unk(train_set_x, n_words)
    # valid_set_x = remove_unk(valid_set_x, n_words)
    test_set_x = remove_unk(test_set_x, n_words)

    return [train_set_x, train_set_y],[test_set_x, test_set_y]

# %% [markdown]
# # Implementation

# %% [markdown]
# ## LSTM Layer

# %%
def lstm_layer(initial_hidden_states, config, keep_prob, mask):
    with tf.variable_scope('forward'):
        fw_lstm = tf.contrib.rnn.BasicLSTMCell(config.hidden_size, forget_bias=0.0)
        fw_lstm = tf.contrib.rnn.DropoutWrapper(fw_lstm, output_keep_prob=keep_prob)

    with tf.variable_scope('backward'):
        bw_lstm = tf.contrib.rnn.BasicLSTMCell(config.hidden_size, forget_bias=0.0)
        bw_lstm = tf.contrib.rnn.DropoutWrapper(bw_lstm, output_keep_prob=keep_prob)

    #bidirectional rnn
    with tf.variable_scope('bilstm'):
        lstm_output=tf.nn.bidirectional_dynamic_rnn(fw_lstm, bw_lstm, inputs=initial_hidden_states, sequence_length=mask, time_major=False, dtype=tf.float32)
        lstm_output=tf.concat(lstm_output[0], 2)

    return lstm_output

# %% [markdown]
# ## Classifier

# %%
class Classifer(object):

    def get_hidden_states_before(self, hidden_states, step, shape, hidden_size):
        #padding zeros
        padding=tf.zeros((shape[0], step, hidden_size), dtype=tf.float32)
        #remove last steps
        displaced_hidden_states=hidden_states[:,:-step,:]
        #concat padding
        return tf.concat([padding, displaced_hidden_states], axis=1)
        #return tf.cond(step<=shape[1], lambda: tf.concat([padding, displaced_hidden_states], axis=1), lambda: tf.zeros((shape[0], shape[1], self.config.hidden_size_sum), dtype=tf.float32))

    def get_hidden_states_after(self, hidden_states, step, shape, hidden_size):
        #padding zeros
        padding=tf.zeros((shape[0], step, hidden_size), dtype=tf.float32)
        #remove last steps
        displaced_hidden_states=hidden_states[:,step:,:]
        #concat padding
        return tf.concat([displaced_hidden_states, padding], axis=1)
        #return tf.cond(step<=shape[1], lambda: tf.concat([displaced_hidden_states, padding], axis=1), lambda: tf.zeros((shape[0], shape[1], self.config.hidden_size_sum), dtype=tf.float32))

    def sum_together(self, l):
        combined_state=None
        for tensor in l:
            if combined_state==None:
                combined_state=tensor
            else:
                combined_state=combined_state+tensor
        return combined_state
    
    def slstm_cell(self, name_scope_name, hidden_size, lengths, initial_hidden_states, initial_cell_states, num_layers):
        with tf.name_scope(name_scope_name):
            #Word parameters 
            #forget gate for left 
            with tf.name_scope("f1_gate"):
                #current
                Wxf1 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxf")
                #left right
                Whf1 = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whf")
                #initial state
                Wif1 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wif")
                #dummy node
                Wdf1 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdf")
            #forget gate for right 
            with tf.name_scope("f2_gate"):
                Wxf2 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxf")
                Whf2 = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whf")
                Wif2 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wif")
                Wdf2 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdf")
            #forget gate for inital states     
            with tf.name_scope("f3_gate"):
                Wxf3 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxf")
                Whf3 = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whf")
                Wif3 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wif")
                Wdf3 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdf")
            #forget gate for dummy states     
            with tf.name_scope("f4_gate"):
                Wxf4 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxf")
                Whf4 = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whf")
                Wif4 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wif")
                Wdf4 = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdf")
            #input gate for current state     
            with tf.name_scope("i_gate"):
                Wxi = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxi")
                Whi = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whi")
                Wii = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wii")
                Wdi = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdi")
            #input gate for output gate
            with tf.name_scope("o_gate"):
                Wxo = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxo")
                Who = tf.Variable(tf.random_normal([2*hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Who")
                Wio = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wio")
                Wdo = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wdo")
            #bias for the gates    
            with tf.name_scope("biases"):
                bi = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bi")
                bo = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bo")
                bf1 = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bf1")
                bf2 = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bf2")
                bf3 = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bf3")
                bf4 = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bf4")

            #dummy node gated attention parameters
            #input gate for dummy state
            with tf.name_scope("gated_d_gate"):
                gated_Wxd = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxf")
                gated_Whd = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Whf")
            #output gate
            with tf.name_scope("gated_o_gate"):
                gated_Wxo = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxo")
                gated_Who = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Who")
            #forget gate for states of word
            with tf.name_scope("gated_f_gate"):
                gated_Wxf = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Wxo")
                gated_Whf = tf.Variable(tf.random_normal([hidden_size, hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="Who")
            #biases
            with tf.name_scope("gated_biases"):
                gated_bd = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bi")
                gated_bo = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bo")
                gated_bf = tf.Variable(tf.random_normal([hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="bo")

        #filters for attention        
        mask_softmax_score=tf.cast(tf.sequence_mask(lengths), tf.float32)*1e25-1e25
        mask_softmax_score_expanded=tf.expand_dims(mask_softmax_score, dim=2)               
        #filter invalid steps
        sequence_mask=tf.expand_dims(tf.cast(tf.sequence_mask(lengths), tf.float32),axis=2)
        #filter embedding states
        initial_hidden_states=initial_hidden_states*sequence_mask
        initial_cell_states=initial_cell_states*sequence_mask
        #record shape of the batch
        shape=tf.shape(initial_hidden_states)
        
        #initial embedding states
        embedding_hidden_state=tf.reshape(initial_hidden_states, [-1, hidden_size])      
        embedding_cell_state=tf.reshape(initial_cell_states, [-1, hidden_size])

        #randomly initialize the states
        if config.random_initialize:
            initial_hidden_states=tf.random_uniform(shape, minval=-0.05, maxval=0.05, dtype=tf.float32, seed=None, name=None)
            initial_cell_states=tf.random_uniform(shape, minval=-0.05, maxval=0.05, dtype=tf.float32, seed=None, name=None)
            #filter it
            initial_hidden_states=initial_hidden_states*sequence_mask
            initial_cell_states=initial_cell_states*sequence_mask

        #inital dummy node states
        dummynode_hidden_states=tf.reduce_mean(initial_hidden_states, axis=1)
        dummynode_cell_states=tf.reduce_mean(initial_cell_states, axis=1)

        for i in range(num_layers):
            #update dummy node states
            #average states
            combined_word_hidden_state=tf.reduce_mean(initial_hidden_states, axis=1)
            reshaped_hidden_output=tf.reshape(initial_hidden_states, [-1, hidden_size])
            #copy dummy states for computing forget gate
            transformed_dummynode_hidden_states=tf.reshape(tf.tile(tf.expand_dims(dummynode_hidden_states, axis=1), [1, shape[1],1]), [-1, hidden_size])
            #input gate
            gated_d_t = tf.nn.sigmoid(
                tf.matmul(dummynode_hidden_states, gated_Wxd) + tf.matmul(combined_word_hidden_state, gated_Whd) + gated_bd
            )
            #output gate
            gated_o_t = tf.nn.sigmoid(
                tf.matmul(dummynode_hidden_states, gated_Wxo) + tf.matmul(combined_word_hidden_state, gated_Who) + gated_bo
            )
            #forget gate for hidden states
            gated_f_t = tf.nn.sigmoid(
                tf.matmul(transformed_dummynode_hidden_states, gated_Wxf) + tf.matmul(reshaped_hidden_output, gated_Whf) + gated_bf
            )

            #softmax on each hidden dimension 
            reshaped_gated_f_t=tf.reshape(gated_f_t, [shape[0], shape[1], hidden_size])+ mask_softmax_score_expanded
            gated_softmax_scores=tf.nn.softmax(tf.concat([reshaped_gated_f_t, tf.expand_dims(gated_d_t, dim=1)], axis=1), dim=1)
            #split the softmax scores
            new_reshaped_gated_f_t=gated_softmax_scores[:,:shape[1],:]
            new_gated_d_t=gated_softmax_scores[:,shape[1]:,:]
            #new dummy states
            dummy_c_t=tf.reduce_sum(new_reshaped_gated_f_t * initial_cell_states, axis=1) + tf.squeeze(new_gated_d_t, axis=1)*dummynode_cell_states
            dummy_h_t=gated_o_t * tf.nn.tanh(dummy_c_t)

            #update word node states
            #get states before
            initial_hidden_states_before=[tf.reshape(self.get_hidden_states_before(initial_hidden_states, step+1, shape, hidden_size), [-1, hidden_size]) for step in range(self.config.step)]
            initial_hidden_states_before=self.sum_together(initial_hidden_states_before)
            initial_hidden_states_after= [tf.reshape(self.get_hidden_states_after(initial_hidden_states, step+1, shape, hidden_size), [-1, hidden_size]) for step in range(self.config.step)]
            initial_hidden_states_after=self.sum_together(initial_hidden_states_after)
            #get states after
            initial_cell_states_before=[tf.reshape(self.get_hidden_states_before(initial_cell_states, step+1, shape, hidden_size), [-1, hidden_size]) for step in range(self.config.step)]
            initial_cell_states_before=self.sum_together(initial_cell_states_before)
            initial_cell_states_after=[tf.reshape(self.get_hidden_states_after(initial_cell_states, step+1, shape, hidden_size), [-1, hidden_size]) for step in range(self.config.step)]
            initial_cell_states_after=self.sum_together(initial_cell_states_after)
            
            #reshape for matmul
            initial_hidden_states=tf.reshape(initial_hidden_states, [-1, hidden_size])
            initial_cell_states=tf.reshape(initial_cell_states, [-1, hidden_size])

            #concat before and after hidden states
            concat_before_after=tf.concat([initial_hidden_states_before, initial_hidden_states_after], axis=1)

            #copy dummy node states 
            transformed_dummynode_hidden_states=tf.reshape(tf.tile(tf.expand_dims(dummynode_hidden_states, axis=1), [1, shape[1],1]), [-1, hidden_size])
            transformed_dummynode_cell_states=tf.reshape(tf.tile(tf.expand_dims(dummynode_cell_states, axis=1), [1, shape[1],1]), [-1, hidden_size])

            f1_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxf1) + tf.matmul(concat_before_after, Whf1) + 
                tf.matmul(embedding_hidden_state, Wif1) + tf.matmul(transformed_dummynode_hidden_states, Wdf1)+ bf1
            )

            f2_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxf2) + tf.matmul(concat_before_after, Whf2) + 
                tf.matmul(embedding_hidden_state, Wif2) + tf.matmul(transformed_dummynode_hidden_states, Wdf2)+ bf2
            )

            f3_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxf3) + tf.matmul(concat_before_after, Whf3) + 
                tf.matmul(embedding_hidden_state, Wif3) + tf.matmul(transformed_dummynode_hidden_states, Wdf3) + bf3
            )

            f4_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxf4) + tf.matmul(concat_before_after, Whf4) + 
                tf.matmul(embedding_hidden_state, Wif4) + tf.matmul(transformed_dummynode_hidden_states, Wdf4) + bf4
            )
            
            i_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxi) + tf.matmul(concat_before_after, Whi) + 
                tf.matmul(embedding_hidden_state, Wii) + tf.matmul(transformed_dummynode_hidden_states, Wdi)+ bi
            )
            
            o_t = tf.nn.sigmoid(
                tf.matmul(initial_hidden_states, Wxo) + tf.matmul(concat_before_after, Who) + 
                tf.matmul(embedding_hidden_state, Wio) + tf.matmul(transformed_dummynode_hidden_states, Wdo) + bo
            )
            
            f1_t, f2_t, f3_t, f4_t, i_t=tf.expand_dims(f1_t, axis=1), tf.expand_dims(f2_t, axis=1),tf.expand_dims(f3_t, axis=1), tf.expand_dims(f4_t, axis=1), tf.expand_dims(i_t, axis=1)


            five_gates=tf.concat([f1_t, f2_t, f3_t, f4_t,i_t], axis=1)
            five_gates=tf.nn.softmax(five_gates, dim=1)
            f1_t,f2_t,f3_t, f4_t,i_t= tf.split(five_gates, num_or_size_splits=5, axis=1)
            
            f1_t, f2_t, f3_t, f4_t, i_t=tf.squeeze(f1_t, axis=1), tf.squeeze(f2_t, axis=1),tf.squeeze(f3_t, axis=1), tf.squeeze(f4_t, axis=1),tf.squeeze(i_t, axis=1)

            c_t = (f1_t * initial_cell_states_before) + (f2_t * initial_cell_states_after)+(f3_t * embedding_cell_state)+ (f4_t * transformed_dummynode_cell_states)+ (i_t * initial_cell_states)
            
            h_t = o_t * tf.nn.tanh(c_t)

            #update states
            initial_hidden_states=tf.reshape(h_t, [shape[0], shape[1], hidden_size])
            initial_cell_states=tf.reshape(c_t, [shape[0], shape[1], hidden_size])
            initial_hidden_states=initial_hidden_states*sequence_mask
            initial_cell_states=initial_cell_states*sequence_mask

            dummynode_hidden_states=dummy_h_t
            dummynode_cell_states=dummy_c_t

        initial_hidden_states = tf.nn.dropout(initial_hidden_states,self.dropout)
        initial_cell_states = tf.nn.dropout(initial_cell_states, self.dropout)

        return initial_hidden_states, initial_cell_states, dummynode_hidden_states



    def __init__(self, config, session):
        #inputs: features, mask, keep_prob, labels
        self.input_data = tf.placeholder(tf.int32, [None, None], name="inputs")
        self.labels=tf.placeholder(tf.int64, [None,], name="labels")
        self.mask=tf.placeholder(tf.int32, [None,], name="mask")
        self.dropout=self.keep_prob=keep_prob=tf.placeholder(tf.float32, name="keep_prob")
        self.config=config
        shape=tf.shape(self.input_data)
        #if sys.argv[4]=='lstm':
        #    self.dummy_input = tf.placeholder(tf.float32, [None, None], name="dummy")
        #embedding
        self.embedding=embedding = tf.Variable(tf.random_normal([config.vocab_size, config.hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="embedding", trainable=config.embedding_trainable)
        #apply embedding
        initial_hidden_states=tf.nn.embedding_lookup(embedding, self.input_data)
        initial_cell_states=tf.identity(initial_hidden_states)

        initial_hidden_states = tf.nn.dropout(initial_hidden_states,keep_prob)
        initial_cell_states = tf.nn.dropout(initial_cell_states, keep_prob)

        #create layers 
        if argument4=='slstm':
            new_hidden_states,new_cell_state, dummynode_hidden_states=self.slstm_cell("word_slstm", config.hidden_size,self.mask, initial_hidden_states, initial_cell_states, config.layer)
            
            softmax_w = tf.Variable(tf.random_normal([2*config.hidden_size, config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_w")
            softmax_b = tf.Variable(tf.random_normal([config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_b")
            #representation=dummynode_hidden_states
            representation=tf.reduce_mean(tf.concat([new_hidden_states, tf.expand_dims(dummynode_hidden_states, axis=1)], axis=1), axis=1)
            
            softmax_w2 = tf.Variable(tf.random_normal([config.hidden_size, 2*config.hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_w2")
            softmax_b2 = tf.Variable(tf.random_normal([2*config.hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_b2")
            representation=tf.nn.tanh(tf.matmul(representation, softmax_w2)+softmax_b2)

        elif argument4=='lstm':
            initial_hidden_states=lstm_layer(initial_hidden_states,config, self.keep_prob, self.mask)
            softmax_w = tf.Variable(tf.random_normal([2*config.hidden_size, config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_w")
            softmax_b = tf.Variable(tf.random_normal([config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_b")
            representation=tf.reduce_sum(initial_hidden_states,axis=1)
            config.hidden_size_sum=2*config.hidden_size
        elif argument4=='cnn':
            initial_hidden_states=tf.reshape(initial_hidden_states, [-1, 700, config.hidden_size])            
            initial_hidden_states = tf.expand_dims(initial_hidden_states, -1)
            pooled_outputs = []
            for i, filter_size in enumerate([3]):
                with tf.name_scope("conv-maxpool-%s" % filter_size):
                    # Convolution Layer
                    filter_shape = [filter_size, config.hidden_size, 1, config.hidden_size]
                    W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W")
                    b = tf.Variable(tf.constant(0.1, shape=[config.hidden_size]), name="b")

                    W2 = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W2")
                    b2 = tf.Variable(tf.constant(0.1, shape=[config.hidden_size]), name="b2")

                    W3 = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W3")
                    b3 = tf.Variable(tf.constant(0.1, shape=[config.hidden_size]), name="b3")

                    W4 = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W4")
                    b4 = tf.Variable(tf.constant(0.1, shape=[config.hidden_size]), name="b4")

                    conv = tf.nn.conv2d(
                        initial_hidden_states,
                        W,
                        strides=[1, 1, 1, 1],
                        padding="VALID",
                        name="conv")
                    h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                    print(h.get_shape())
                    h=tf.transpose(h, [0,1,3,2])
                    # Apply nonlinearity


                    conv2 = tf.nn.conv2d(
                        h,
                        W2,
                        strides=[1, 1, 1, 1],
                        padding="VALID",
                        name="conv2")
                    h2 = tf.nn.relu(tf.nn.bias_add(conv2, b2), name="relu2")
                    print(h2.get_shape())
                    h2=tf.transpose(h2, [0,1,3,2])

                    conv3 = tf.nn.conv2d(
                        h2,
                        W3,
                        strides=[1, 1, 1, 1],
                        padding="VALID",
                        name="conv3")  
                    h3 = tf.nn.relu(tf.nn.bias_add(conv3, b3), name="relu3")
                    print(h3.get_shape())

                    # Max-pooling over the outputs
                    pooled = tf.nn.max_pool(
                        h3,
                        ksize=[1, 700 - 3*filter_size + 3, 1, 1],
                        strides=[1, 1, 1, 1],
                        padding='VALID',
                        name="pool")
                    pooled_outputs.append(pooled)
            # Combine all the pooled features
            num_filters_total = 1 * config.hidden_size
            self.h_pool = tf.concat(pooled_outputs, axis=3)
            representation = tf.reshape(self.h_pool, [-1, num_filters_total])

            softmax_w = tf.Variable(tf.random_normal([2*config.hidden_size, config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_w")
            softmax_b = tf.Variable(tf.random_normal([config.num_label], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_b")

            softmax_w2 = tf.Variable(tf.random_normal([config.hidden_size, 2*config.hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_w2")
            softmax_b2 = tf.Variable(tf.random_normal([2*config.hidden_size], mean=0.0, stddev=0.1, dtype=tf.float32), dtype=tf.float32, name="softmax_b2")
            representation=tf.nn.tanh(tf.matmul(representation, softmax_w2)+softmax_b2)
        else:
            print("Invalid model")
            exit(1)
        
        self.logits=logits = tf.matmul(representation, softmax_w) + softmax_b
        self.to_print=tf.nn.softmax(logits)
        #operators for prediction
        self.prediction=prediction=tf.argmax(logits,1)
        correct_prediction = tf.equal(prediction, self.labels)
        self.accuracy = tf.reduce_sum(tf.cast(correct_prediction, tf.float32))
        
        #cross entropy loss
        loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=self.labels, logits=logits)
        self.cost=cost=tf.reduce_mean(loss)+ config.l2_beta*tf.nn.l2_loss(embedding)

        #designate training variables
        tvars=tf.trainable_variables()
        self.lr = tf.Variable(0.0, trainable=False)
        grads=tf.gradients(cost, tvars)
        grads, _ = tf.clip_by_global_norm(grads,config.max_grad_norm)
        self.grads=grads
        optimizer = tf.train.AdamOptimizer(config.learning_rate)        
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    #assign value to learning rate
    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# ## get_minibatches_idx()

# %%
def get_minibatches_idx(n, batch_size, shuffle=True):
    idx_list = np.arange(n, dtype="int32")

    if shuffle:
        np.random.shuffle(idx_list)

    minibatches = []
    minibatch_start = 0
    for i in range(n // batch_size):
        minibatches.append(idx_list[minibatch_start:
                                    minibatch_start + batch_size])
        minibatch_start += batch_size
    if (minibatch_start != n):
        # Make a minibatch out of what is left
        minibatches.append(idx_list[minibatch_start:])
    return minibatches

# %% [markdown]
# ## run_epoch

# %%
def run_epoch(session, config, model, data, eval_op, keep_prob, is_training):
    n_samples = len(data[0])
    print("Running %d samples:"%(n_samples))  
    minibatches = get_minibatches_idx(n_samples, config.batch_size, shuffle=False)

    predictions = []
    correct = 0.
    total = 0
    total_cost=0
    prog = Progbar(target=len(minibatches))
    #dummynode_hidden_states_collector=np.array([[0]*config.hidden_size])

    to_print_total=np.array([[0]*2])
    for i, inds in enumerate(minibatches):
        x = data[0][inds]
        if argument4=='cnn':
            x=pad_sequences(x, maxlen=700, dtype='int32',padding='post', truncating='post', value=0.)
        else:
            x=pad_sequences(x, maxlen=None, dtype='int32',padding='post', truncating='post', value=0.)
        y = data[1][inds]
        mask = data[2][inds]



        count, _, cost, to_print,prediction= \
        session.run([model.accuracy, eval_op,model.cost, model.to_print,model.prediction],\
            {model.input_data: x, model.labels: y, model.mask:mask, model.keep_prob:keep_prob}) 
        

        if not is_training:
            to_print_total=np.concatenate((to_print_total, to_print),axis=0)
        correct += count 
        total += len(inds)
        total_cost+=cost
        predictions.extend(prediction.tolist())
        prog.update(i + 1, [("train loss", cost)])
    #if not is_training:
    #    print(to_print_total[:, 0].tolist())
    #    print(data[1].tolist())
    #    print(data[2].tolist())

    actual = data[1]

    TN, FP, FN, TP = confusion_matrix(actual, predictions).ravel()

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)

    print("Total loss:")
    print(total_cost)

    accuracy = correct/total

    return accuracy,precision,recall,f1, actual, predictions

# %% [markdown]
# ## train_test_model

# %%
def train_test_model(config, i, session, model, train_dataset,test_dataset):
    #compute lr_decay
    lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
    #update learning rate
    model.assign_lr(session, config.learning_rate * lr_decay)

    #training            
    print("Epoch: %d Learning rate: %.5f" % (i + 1, session.run(model.lr)))
    start_time = time.time()
    train_acc, train_precision, train_recall, train_f1,actual,predictions = run_epoch(session, config, model, train_dataset, model.train_op, config.keep_prob, True)
    print("Training Accuracy = %.4f, time = %.3f seconds\n"%(train_acc, time.time()-start_time))

    # #valid 
    # valid_acc = run_epoch(session, config, model, valid_dataset, tf.no_op(),1, False)
    # print("Valid Accuracy = %.4f\n" % valid_acc)

    #testing
    start_time = time.time()
    test_acc,test_precision, test_recall, test_f1,test_actual,test_predictions = run_epoch(session, config, model, test_dataset, tf.no_op(),1, False)
    print("Test Accuracy = %.4f, Test Precision = %.4f, Test Recall = %.4f, Test F1 = %.4f\n" % (test_acc,test_precision,test_recall,test_f1))    
    print("Time = %.3f seconds\n"%(time.time()-start_time))
    print('confusion metric : ')
    print((confusion_matrix(test_actual, test_predictions).ravel()))
    #return valid_acc, test_acc
    return test_actual,test_predictions

# %% [markdown]
# ## start_epoches

# %%
def start_epoches(config, session,classifier, train_dataset, test_dataset):
    #record max
    #max_val_acc=-1
    #max_test_acc=-1
    # saver = tf.train.Saver()
    all_actual = []
    all_predictions = []

    for i in range(config.max_max_epoch):
      test_actual,test_predictions = train_test_model(config, i, session, classifier, train_dataset, test_dataset)
      
      all_actual.extend(test_actual)
      all_predictions.extend(test_predictions)

      if(i%5 == 0 and i != 0):
        print("for iteration : ",i)
        for j in range(len(test_predictions)):
          print (j, " actual : ", test_actual[j], " predicted : ",test_predictions[j])

      # if (i % 1 == 0 and i != 0):
      #   save_path = saver.save(session, "/content/drive/My Drive/University/FYP/Sentiment Analysis/supportive/S-LSTM/Trained_Model/slstm_models/pretrained_lstm.ckpt", global_step=i)
      #     print("saved to %s" % save_path)

    TN, FP, FN, TP = confusion_matrix(all_actual, all_predictions).ravel()

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)
    accuracy = (TP+TN)/(TP+TN+FN+FP)

    print("final Accuracy : ",accuracy)
    print("final precision : ",precision)
    print("final recall : ",recall)
    print("final f1 : ",f1)

# %% [markdown]
# ## word_to_vec

# %%
def word_to_vec(matrix, session,config, *args):
    
    print("word2vec shape: ", matrix.shape)
    
    for model in args:
        session.run(tf.assign(model.embedding, matrix))

# %% [markdown]
# # Main

# %% [markdown]
# ## configs

# %%
argument1 = "7" # slstm iteration
argument2 = "2" #num window_size
argument3 = "sinhala_news" #dataset_name
argument4 = "slstm" #model_name

config = Config()
config.layer=int(argument1)
config.step=int(argument2)
config.vocab_size=(18413) # number of words in fastText model
print("dataset: "+argument3)
print("iteration: "+str(config.layer))
print("step: "+str(config.step))
print("model: "+str(argument4))
# Out:
# dataset: sinhala_news
# iteration: 7
# step: 2
# model: slstm

# %% [markdown]
# ## Word2Vec

# %%
f = open(vector_path, 'rb')
matrix= np.array(pickle.load(f))
config.vocab_size=matrix.shape[0]
print(config.vocab_size)
# Out:
# 18415

# %%
# from gensim.models import word2vec
# model = word2vec.Word2Vec.load(vector_path)

# %% [markdown]
# ## Load Dataset

# %%
# def load_vectors():
#     train_data_vectors = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/vectors/train_data_vectors.npy')
#     train_data_labels = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/vectors/train_data_labels.npy')
#     test_data_vectors = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/vectors/test_data_vectors.npy')
#     test_data_labels = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/vectors/test_data_labels.npy')
#     return train_data_vectors, train_data_labels, test_data_vectors, test_data_labels

# %%
# convert_to_vectors()
# train_data_vectors, train_data_labels, test_data_vectors, test_data_labels = load_vectors()

# %%
train_dataset, test_dataset = load_data(path=path,n_words=config.vocab_size)
config.num_label= len(set(train_dataset[1]))

# %%
print("number label: "+str(config.num_label))
train_dataset = prepare_data(train_dataset[0], train_dataset[1])
# valid_dataset = prepare_data(valid_dataset[0], valid_dataset[1])
test_dataset = prepare_data(test_dataset[0], test_dataset[1])
# Out:
# number label: 2

# %%
print(train_dataset)
# Out:
# [array([list([133, 105, 445, 19, 207, 2, 6, 4429, 12, 4430, 1533, 375, 77, 160, 33, 7, 10, 423, 17, 2088, 155, 10, 3205]),
#        list([204, 26]),
#        list([318, 180, 4431, 303, 7096, 181, 2512, 7097, 7, 4432, 682, 7098, 723, 48, 7099, 7100, 2513, 4433, 1534, 887, 772, 7101, 7102, 1337, 7103, 1338, 7104, 7105, 34, 150, 127]),
#        ...,
#        list([5173, 8, 2340, 3150, 22, 297, 76, 6640, 16198, 420, 3586, 16199, 1531, 164, 16200, 1932, 625, 16201, 469, 133, 1980, 4291, 218, 5065, 16202]),
#        list([1802, 6909, 716, 5437, 2938, 6613, 350, 16203, 6843, 1802, 5440, 395, 78]),
#        list([329, 7, 1043, 64, 2180])], dtype=object), array([1, 0, 1, ..., 0, 0, 1], dtype=int32), array([23,  2, 31, ..., 25, 13,  5], dtype=int32)]

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_normal_initializer(0, 0.05)

    classifier= Classifer(config=config, session=session)
    saver = tf.train.Saver()

    total=0
    #print trainable variables
    for v in tf.trainable_variables():
        print(v.name)
        shape=v.get_shape()
        try:
            size=shape[0].value*shape[1].value
        except:
            size=shape[0].value
        total+=size
    print(total)
    #initialize
    init = tf.global_variables_initializer()

    session.run(init)
    #train test model

    print ("model_test",matrix)



    word_to_vec(matrix, session,config, classifier)
    start_epoches(config, session,classifier, train_dataset, test_dataset)
    # # Add ops to save and restore all the variables.
    
    # save_path = saver.save(session, "/content/drive/My Drive/UNI/FYP/Sentiment Analysis/supportive/S-LSTM/Trained_Model/slstm_models/500epochs/1/")
    # print("Model saved in path: %s" % save_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# 317  actual :  0  predicted :  0
# 318  actual :  1  predicted :  1
# 319  actual :  1  predicted :  1
# 320  actual :  1  predicted :  1
# 321  actual :  1  predicted :  1
# 322  actual :  0  predicted :  0
# 323  actual :  0  predicted :  0
# 324  actual :  0  predicted :  0
# 325  actual :  1  predicted :  1
# 326  actual :  0  predicted :  0
# 327  actual :  1  predicted :  0
# 328  actual :  0  predicted :  0
# 329  actual :  0  predicted :  0
# 330  actual :  1  predicted :  1
# 331  actual :  0  predicted :  0
# 332  actual :  1  predicted :  1
# 333  actual :  1  predicted :  0
# 334  actual :  1  predicted :  1
# 335  actual :  0  predicted :  0
# 336  actual :  1  predicted :  0
# 337  actual :  0  predicted :  0
# 338  actual :  0  predicted :  0
# 339  actual :  1  predicted :  1
# 340  actual :  0  predicted :  0
# 341  actual :  0  predicted :  0
# 342  actual :  0  predicted :  0
# 343  actual :  0  predicted :  0
# 344  actual :  0  predicted :  0
# 345  actual :  1  predicted :  1
# 346  actual :  1  predicted :  1
# 347  actual :  1  predicted :  0
# 348  actual :  0  predicted :  0
# 349  actual :  1  predicted :  1
# 350  actual :  0  predicted :  0
# 351  actual :  0  predicted :  0
# 352  actual :  0  predicted :  0
# 353  actual :  1  predicted :  1
# 354  actual :  0  predicted :  0
# 355  actual :  1  predicted :  1
# 356  actual :  1  predicted :  1
# 357  actual :  1  predicted :  1
# 358  actual :  0  predicted :  0
# 359  actual :  1  predicted :  1
# 360  actual :  1  predicted :  1
# 361  actual :  1  predicted :  1
# 362  actual :  0  predicted :  0
# 363  actual :  0  predicted :  0
# 364  actual :  1  predicted :  1
# 365  actual :  1  predicted :  1
# 366  actual :  1  predicted :  1
# 367  actual :  0  predicted :  0
# 368  actual :  0  predicted :  1
# 369  actual :  0  predicted :  0
# 370  actual :  0  predicted :  0
# 371  actual :  0  predicted :  0
# 372  actual :  1  predicted :  1
# 373  actual :  1  predicted :  1
# 374  actual :  1  predicted :  1
# 375  actual :  1  predicted :  0
# 376  actual :  0  predicted :  0
# 377  actual :  0  predicted :  1
# 378  actual :  1  predicted :  1
# 379  actual :  1  predicted :  0
# 380  actual :  1  predicted :  0
# 381  actual :  0  predicted :  0
# 382  actual :  1  predicted :  1
# 383  actual :  0  predicted :  0
# 384  actual :  1  predicted :  0
# 385  actual :  0  predicted :  0
# 386  actual :  1  predicted :  1
# 387  actual :  1  predicted :  1
# 388  actual :  1  predicted :  1
# 389  actual :  1  predicted :  1
# 390  actual :  1  predicted :  1
# 391  actual :  1  predicted :  1
# 392  actual :  0  predicted :  0
# 393  actual :  1  predicted :  1
# 394  actual :  0  predicted :  0
# 395  actual :  0  predicted :  0
# 396  actual :  1  predicted :  0
# 397  actual :  1  predicted :  1
# 398  actual :  1  predicted :  1
# 399  actual :  1  predicted :  1
# 400  actual :  0  predicted :  0
# 401  actual :  0  predicted :  0
# 402  actual :  1  predicted :  1
# 403  actual :  1  predicted :  1
# 404  actual :  0  predicted :  0
# 405  actual :  1  predicted :  1
# 406  actual :  0  predicted :  0
# 407  actual :  1  predicted :  1
# 408  actual :  0  predicted :  0
# 409  actual :  0  predicted :  0
# 410  actual :  1  predicted :  1
# 411  actual :  1  predicted :  0
# 412  actual :  0  predicted :  0
# 413  actual :  0  predicted :  1
# 414  actual :  0  predicted :  0
# 415  actual :  0  predicted :  0
# 416  actual :  0  predicted :  0
# 417  actual :  0  predicted :  0
# 418  actual :  1  predicted :  1
# 419  actual :  1  predicted :  1
# 420  actual :  1  predicted :  1
# 421  actual :  1  predicted :  1
# 422  actual :  0  predicted :  0
# 423  actual :  1  predicted :  1
# 424  actual :  1  predicted :  1
# 425  actual :  0  predicted :  1
# 426  actual :  0  predicted :  0
# 427  actual :  1  predicted :  1
# 428  actual :  0  predicted :  0
# 429  actual :  1  predicted :  1
# 430  actual :  0  predicted :  0
# 431  actual :  1  predicted :  1
# 432  actual :  0  predicted :  1
# 433  actual :  1  predicted :  1
# 434  actual :  1  predicted :  1
# 435  actual :  1  predicted :  1
# 436  actual :  0  predicted :  0
# 437  actual :  1  predicted :  1
# 438  actual :  1  predicted :  0
# 439  actual :  0  predicted :  0
# 440  actual :  1  predicted :  0
# 441  actual :  1  predicted :  1
# 442  actual :  1  predicted :  1
# 443  actual :  0  predicted :  1
# 444  actual :  0  predicted :  0
# 445  actual :  1  predicted :  1
# 446  actual :  0  predicted :  1
# 447  actual :  1  predicted :  1
# 448  actual :  1  predicted :  1
# 449  actual :  1  predicted :  1
# 450  actual :  1  predicted :  0
# 451  actual :  0  predicted :  0
# 452  actual :  0  predicted :  0
# 453  actual :  0  predicted :  0
# 454  actual :  0  predicted :  0
# 455  actual :  0  predicted :  0
# 456  actual :  1  predicted :  1
# 457  actual :  0  predicted :  0
# 458  actual :  0  predicted :  0
# 459  actual :  1  predicted :  0
# 460  actual :  0  predicted :  0
# 461  actual :  0  predicted :  1
# 462  actual :  1  predicted :  1
# 463  actual :  0  predicted :  0
# 464  actual :  1  predicted :  1
# 465  actual :  1  predicted :  1
# 466  actual :  1  predicted :  1
# 467  actual :  0  predicted :  0
# 468  actual :  0  predicted :  0
# 469  actual :  1  predicted :  1
# 470  actual :  1  predicted :  0
# 471  actual :  1  predicted :  1
# 472  actual :  1  predicted :  1
# 473  actual :  1  predicted :  1
# 474  actual :  0  predicted :  0
# 475  actual :  0  predicted :  0
# 476  actual :  0  predicted :  0
# 477  actual :  0  predicted :  0
# 478  actual :  1  predicted :  1
# 479  actual :  0  predicted :  0
# 480  actual :  0  predicted :  0
# 481  actual :  0  predicted :  0
# 482  actual :  0  predicted :  0
# 483  actual :  1  predicted :  1
# 484  actual :  0  predicted :  0
# 485  actual :  1  predicted :  1
# 486  actual :  0  predicted :  0
# 487  actual :  0  predicted :  0
# 488  actual :  0  predicted :  0
# 489  actual :  0  predicted :  1
# 490  actual :  0  predicted :  0
# 491  actual :  0  predicted :  0
# 492  actual :  0  predicted :  0
# 493  actual :  0  predicted :  0
# 494  actual :  1  predicted :  1
# 495  actual :  0  predicted :  0
# 496  actual :  0  predicted :  0
# 497  actual :  1  predicted :  1
# 498  actual :  1  predicted :  1
# 499  actual :  1  predicted :  0
# 500  actual :  1  predicted :  1
# 501  actual :  0  predicted :  0
# 502  actual :  1  predicted :  1
# 503  actual :  0  predicted :  0
# 504  actual :  1  predicted :  1
# 505  actual :  1  predicted :  0
# 506  actual :  0  predicted :  1
# 507  actual :  1  predicted :  1
# 508  actual :  0  predicted :  0
# 509  actual :  0  predicted :  0
# 510  actual :  0  predicted :  0
# 511  actual :  0  predicted :  0
# 512  actual :  1  predicted :  1
# 513  actual :  0  predicted :  0
# 514  actual :  1  predicted :  1
# 515  actual :  1  predicted :  1
# 516  actual :  1  predicted :  1
# 517  actual :  1  predicted :  0
# 518  actual :  0  predicted :  0
# 519  actual :  0  predicted :  0
# 520  actual :  0  predicted :  1
# 521  actual :  1  predicted :  1
# 522  actual :  1  predicted :  1
# 523  actual :  0  predicted :  0
# 524  actual :  0  predicted :  0
# 525  actual :  0  predicted :  0
# 526  actual :  0  predicted :  0
# 527  actual :  0  predicted :  0
# 528  actual :  0  predicted :  0
# 529  actual :  0  predicted :  0
# 530  actual :  0  predicted :  0
# 531  actual :  1  predicted :  0
# 532  actual :  0  predicted :  0
# 533  actual :  0  predicted :  0
# 534  actual :  0  predicted :  1
# 535  actual :  0  predicted :  0
# 536  actual :  1  predicted :  1
# 537  actual :  0  predicted :  0
# 538  actual :  1  predicted :  1
# 539  actual :  0  predicted :  0
# 540  actual :  0  predicted :  0
# 541  actual :  1  predicted :  1
# 542  actual :  1  predicted :  1
# 543  actual :  1  predicted :  1
# 544  actual :  1  predicted :  1
# 545  actual :  1  predicted :  0
# 546  actual :  0  predicted :  0
# 547  actual :  0  predicted :  0
# 548  actual :  0  predicted :  0
# 549  actual :  1  predicted :  0
# 550  actual :  0  predicted :  0
# 551  actual :  1  predicted :  1
# 552  actual :  0  predicted :  0
# 553  actual :  0  predicted :  0
# 554  actual :  1  predicted :  1
# 555  actual :  0  predicted :  0
# 556  actual :  1  predicted :  1
# 557  actual :  1  predicted :  1
# 558  actual :  0  predicted :  0
# 559  actual :  0  predicted :  0
# 560  actual :  0  predicted :  1
# 561  actual :  1  predicted :  0
# 562  actual :  1  predicted :  1
# 563  actual :  0  predicted :  0
# 564  actual :  1  predicted :  1
# 565  actual :  1  predicted :  1
# 566  actual :  1  predicted :  1
# 567  actual :  0  predicted :  0
# 568  actual :  0  predicted :  0
# 569  actual :  1  predicted :  0
# 570  actual :  0  predicted :  0
# 571  actual :  0  predicted :  0
# 572  actual :  1  predicted :  1
# 573  actual :  1  predicted :  1
# 574  actual :  1  predicted :  0
# 575  actual :  1  predicted :  1
# 576  actual :  1  predicted :  1
# 577  actual :  1  predicted :  1
# 578  actual :  1  predicted :  1
# 579  actual :  0  predicted :  0
# 580  actual :  0  predicted :  0
# 581  actual :  0  predicted :  0
# 582  actual :  0  predicted :  0
# 583  actual :  1  predicted :  1
# 584  actual :  0  predicted :  0
# 585  actual :  1  predicted :  0
# 586  actual :  1  predicted :  1
# 587  actual :  1  predicted :  1
# 588  actual :  1  predicted :  1
# 589  actual :  1  predicted :  1
# 590  actual :  1  predicted :  1
# 591  actual :  0  predicted :  0
# 592  actual :  0  predicted :  0
# 593  actual :  0  predicted :  0
# 594  actual :  0  predicted :  0
# 595  actual :  0  predicted :  0
# 596  actual :  1  predicted :  1
# 597  actual :  1  predicted :  0
# 598  actual :  0  predicted :  1
# 599  actual :  0  predicted :  0
# 600  actual :  1  predicted :  0
# 601  actual :  1  predicted :  1
# 602  actual :  0  predicted :  0
# 603  actual :  0  predicted :  0
# 604  actual :  0  predicted :  0
# 605  actual :  1  predicted :  1
# 606  actual :  0  predicted :  0
# 607  actual :  1  predicted :  1
# 608  actual :  1  predicted :  1
# 609  actual :  1  predicted :  1
# 610  actual :  0  predicted :  0
# 611  actual :  1  predicted :  0
# 612  actual :  0  predicted :  0
# 613  actual :  0  predicted :  0
# 614  actual :  0  predicted :  0
# 615  actual :  0  predicted :  1
# 616  actual :  0  predicted :  0
# 617  actual :  1  predicted :  1
# 618  actual :  0  predicted :  0
# 619  actual :  0  predicted :  0
# 620  actual :  1  predicted :  1
# 621  actual :  1  predicted :  1
# 622  actual :  1  predicted :  1
# 623  actual :  1  predicted :  1
# 624  actual :  0  predicted :  0
# 625  actual :  1  predicted :  1
# 626  actual :  1  predicted :  1
# 627  actual :  1  predicted :  0
# 628  actual :  1  predicted :  0
# 629  actual :  1  predicted :  1
# 630  actual :  0  predicted :  0
# 631  actual :  1  predicted :  1
# 632  actual :  0  predicted :  0
# 633  actual :  0  predicted :  0
# 634  actual :  0  predicted :  0
# 635  actual :  0  predicted :  0
# 636  actual :  0  predicted :  0
# 637  actual :  1  predicted :  1
# 638  actual :  0  predicted :  0
# 639  actual :  1  predicted :  0
# 640  actual :  0  predicted :  0
# 641  actual :  1  predicted :  1
# 642  actual :  0  predicted :  0
# 643  actual :  1  predicted :  1
# 644  actual :  1  predicted :  0
# 645  actual :  0  predicted :  0
# 646  actual :  0  predicted :  0
# 647  actual :  1  predicted :  1
# 648  actual :  0  predicted :  0
# 649  actual :  1  predicted :  1
# 650  actual :  1  predicted :  1
# 651  actual :  1  predicted :  1
# 652  actual :  1  predicted :  0
# 653  actual :  1  predicted :  1
# 654  actual :  1  predicted :  0
# 655  actual :  0  predicted :  0
# 656  actual :  1  predicted :  1
# 657  actual :  0  predicted :  0
# 658  actual :  0  predicted :  0
# 659  actual :  1  predicted :  1
# 660  actual :  0  predicted :  0
# 661  actual :  0  predicted :  0
# 662  actual :  0  predicted :  0
# 663  actual :  1  predicted :  0
# 664  actual :  0  predicted :  0
# 665  actual :  0  predicted :  0
# 666  actual :  0  predicted :  0
# 667  actual :  0  predicted :  0
# 668  actual :  1  predicted :  1
# 669  actual :  0  predicted :  0
# 670  actual :  0  predicted :  0
# 671  actual :  1  predicted :  1
# 672  actual :  0  predicted :  0
# 673  actual :  0  predicted :  0
# 674  actual :  0  predicted :  0
# 675  actual :  0  predicted :  0
# 676  actual :  1  predicted :  1
# 677  actual :  0  predicted :  0
# 678  actual :  1  predicted :  0
# 679  actual :  0  predicted :  0
# 680  actual :  1  predicted :  1
# 681  actual :  1  predicted :  1
# 682  actual :  1  predicted :  1
# 683  actual :  0  predicted :  0
# 684  actual :  0  predicted :  0
# 685  actual :  1  predicted :  1
# 686  actual :  0  predicted :  0
# 687  actual :  0  predicted :  1
# 688  actual :  1  predicted :  1
# 689  actual :  0  predicted :  0
# 690  actual :  0  predicted :  0
# 691  actual :  1  predicted :  0
# 692  actual :  1  predicted :  1
# 693  actual :  0  predicted :  0
# 694  actual :  1  predicted :  1
# 695  actual :  0  predicted :  0
# 696  actual :  1  predicted :  1
# 697  actual :  1  predicted :  1
# 698  actual :  0  predicted :  1
# 699  actual :  0  predicted :  0
# 700  actual :  1  predicted :  1
# 701  actual :  0  predicted :  0
# 702  actual :  1  predicted :  1
# 703  actual :  0  predicted :  0
# 704  actual :  1  predicted :  0
# 705  actual :  1  predicted :  1
# 706  actual :  1  predicted :  1
# 707  actual :  1  predicted :  1
# 708  actual :  1  predicted :  0
# 709  actual :  1  predicted :  1
# 710  actual :  1  predicted :  1
# 711  actual :  0  predicted :  0
# 712  actual :  1  predicted :  0
# 713  actual :  1  predicted :  1
# 714  actual :  1  predicted :  1
# 715  actual :  1  predicted :  1
# 716  actual :  0  predicted :  0
# 717  actual :  1  predicted :  1
# 718  actual :  0  predicted :  0
# 719  actual :  1  predicted :  1
# 720  actual :  1  predicted :  1
# 721  actual :  0  predicted :  0
# 722  actual :  0  predicted :  1
# 723  actual :  0  predicted :  0
# 724  actual :  1  predicted :  0
# 725  actual :  1  predicted :  1
# 726  actual :  1  predicted :  0
# 727  actual :  0  predicted :  0
# 728  actual :  1  predicted :  1
# 729  actual :  1  predicted :  1
# 730  actual :  1  predicted :  1
# 731  actual :  0  predicted :  0
# 732  actual :  0  predicted :  0
# 733  actual :  1  predicted :  0
# 734  actual :  0  predicted :  0
# 735  actual :  1  predicted :  1
# 736  actual :  0  predicted :  0
# 737  actual :  0  predicted :  0
# 738  actual :  0  predicted :  0
# 739  actual :  1  predicted :  1
# 740  actual :  0  predicted :  0
# 741  actual :  0  predicted :  0
# 742  actual :  1  predicted :  0
# 743  actual :  0  predicted :  0
# 744  actual :  1  predicted :  1
# 745  actual :  1  predicted :  0
# 746  actual :  1  predicted :  1
# 747  actual :  0  predicted :  0
# 748  actual :  1  predicted :  1
# 749  actual :  1  predicted :  1
# 750  actual :  0  predicted :  0
# 751  actual :  0  predicted :  0
# 752  actual :  0  predicted :  0
# 753  actual :  1  predicted :  1
# 754  actual :  0  predicted :  0
# 755  actual :  1  predicted :  1
# 756  actual :  1  predicted :  1
# 757  actual :  1  predicted :  1
# 758  actual :  0  predicted :  0
# 759  actual :  0  predicted :  0
# 760  actual :  1  predicted :  1
# 761  actual :  0  predicted :  1
# 762  actual :  0  predicted :  0
# 763  actual :  1  predicted :  1
# 764  actual :  1  predicted :  1
# 765  actual :  0  predicted :  0
# 766  actual :  1  predicted :  0
# 767  actual :  1  predicted :  0
# 768  actual :  1  predicted :  1
# 769  actual :  0  predicted :  0
# 770  actual :  0  predicted :  1
# 771  actual :  0  predicted :  0
# 772  actual :  1  predicted :  0
# 773  actual :  1  predicted :  1
# 774  actual :  0  predicted :  0
# 775  actual :  1  predicted :  1
# 776  actual :  0  predicted :  0
# 777  actual :  1  predicted :  1
# 778  actual :  0  predicted :  0
# 779  actual :  1  predicted :  1
# 780  actual :  0  predicted :  0
# 781  actual :  0  predicted :  1
# 782  actual :  0  predicted :  0
# 783  actual :  0  predicted :  0
# 784  actual :  1  predicted :  1
# 785  actual :  1  predicted :  1
# 786  actual :  0  predicted :  0
# 787  actual :  0  predicted :  0
# 788  actual :  0  predicted :  0
# 789  actual :  0  predicted :  0
# 790  actual :  0  predicted :  0
# 791  actual :  0  predicted :  0
# 792  actual :  0  predicted :  0
# 793  actual :  0  predicted :  0
# 794  actual :  0  predicted :  1
# 795  actual :  1  predicted :  1
# 796  actual :  1  predicted :  1
# 797  actual :  0  predicted :  0
# 798  actual :  0  predicted :  0
# 799  actual :  1  predicted :  1
# 800  actual :  0  predicted :  0
# 801  actual :  1  predicted :  1
# 802  actual :  1  predicted :  0
# 803  actual :  0  predicted :  0
# 804  actual :  1  predicted :  1
# 805  actual :  0  predicted :  0
# 806  actual :  1  predicted :  1
# 807  actual :  1  predicted :  1
# 808  actual :  1  predicted :  1
# 809  actual :  0  predicted :  0
# 810  actual :  0  predicted :  0
# 811  actual :  1  predicted :  0
# 812  actual :  0  predicted :  1
# 813  actual :  0  predicted :  0
# 814  actual :  1  predicted :  1
# 815  actual :  0  predicted :  0
# 816  actual :  0  predicted :  0
# 817  actual :  1  predicted :  1
# 818  actual :  0  predicted :  0
# 819  actual :  0  predicted :  0
# 820  actual :  1  predicted :  1
# 821  actual :  0  predicted :  0
# 822  actual :  0  predicted :  0
# 823  actual :  1  predicted :  0
# 824  actual :  1  predicted :  1
# 825  actual :  0  predicted :  0
# 826  actual :  1  predicted :  1
# 827  actual :  0  predicted :  0
# 828  actual :  1  predicted :  1
# 829  actual :  0  predicted :  0
# 830  actual :  0  predicted :  0
# 831  actual :  0  predicted :  0
# 832  actual :  0  predicted :  0
# 833  actual :  1  predicted :  1
# 834  actual :  0  predicted :  0
# 835  actual :  1  predicted :  1
# 836  actual :  1  predicted :  1
# 837  actual :  0  predicted :  0
# 838  actual :  0  predicted :  0
# 839  actual :  1  predicted :  0
# 840  actual :  0  predicted :  0
# 841  actual :  0  predicted :  0
# 842  actual :  1  predicted :  1
# 843  actual :  0  predicted :  0
# 844  actual :  0  predicted :  1
# 845  actual :  0  predicted :  1
# 846  actual :  1  predicted :  1
# 847  actual :  0  predicted :  0
# 848  actual :  1  predicted :  0
# 849  actual :  1  predicted :  0
# 850  actual :  1  predicted :  1
# 851  actual :  1  predicted :  0
# 852  actual :  1  predicted :  0
# 853  actual :  0  predicted :  1
# 854  actual :  1  predicted :  1
# 855  actual :  1  predicted :  1
# 856  actual :  1  predicted :  1
# 857  actual :  1  predicted :  1
# 858  actual :  1  predicted :  1
# 859  actual :  0  predicted :  0
# 860  actual :  0  predicted :  0
# 861  actual :  1  predicted :  1
# 862  actual :  1  predicted :  1
# 863  actual :  1  predicted :  1
# 864  actual :  1  predicted :  0
# 865  actual :  1  predicted :  1
# 866  actual :  0  predicted :  0
# 867  actual :  1  predicted :  1
# 868  actual :  1  predicted :  1
# 869  actual :  1  predicted :  0
# 870  actual :  1  predicted :  0
# 871  actual :  1  predicted :  1
# 872  actual :  1  predicted :  1
# 873  actual :  1  predicted :  1
# 874  actual :  1  predicted :  1
# 875  actual :  0  predicted :  0
# 876  actual :  0  predicted :  0
# 877  actual :  0  predicted :  0
# 878  actual :  1  predicted :  1
# 879  actual :  1  predicted :  1
# 880  actual :  1  predicted :  1
# 881  actual :  0  predicted :  0
# 882  actual :  0  predicted :  0
# 883  actual :  0  predicted :  1
# 884  actual :  0  predicted :  1
# 885  actual :  0  predicted :  0
# 886  actual :  0  predicted :  1
# 887  actual :  1  predicted :  0
# 888  actual :  1  predicted :  1
# 889  actual :  1  predicted :  1
# 890  actual :  0  predicted :  0
# 891  actual :  0  predicted :  0
# 892  actual :  1  predicted :  1
# 893  actual :  0  predicted :  0
# 894  actual :  1  predicted :  1
# 895  actual :  1  predicted :  1
# 896  actual :  0  predicted :  0
# 897  actual :  1  predicted :  1
# 898  actual :  1  predicted :  1
# 899  actual :  0  predicted :  0
# 900  actual :  1  predicted :  1
# 901  actual :  0  predicted :  0
# 902  actual :  1  predicted :  1
# 903  actual :  1  predicted :  1
# 904  actual :  0  predicted :  0
# 905  actual :  0  predicted :  0
# 906  actual :  1  predicted :  0
# 907  actual :  0  predicted :  0
# 908  actual :  0  predicted :  0
# 909  actual :  0  predicted :  0
# 910  actual :  0  predicted :  0
# 911  actual :  0  predicted :  0
# 912  actual :  1  predicted :  1
# 913  actual :  1  predicted :  1
# 914  actual :  1  predicted :  1
# 915  actual :  1  predicted :  1
# 916  actual :  1  predicted :  1
# 917  actual :  0  predicted :  0
# 918  actual :  1  predicted :  1
# 919  actual :  1  predicted :  0
# 920  actual :  1  predicted :  1
# 921  actual :  1  predicted :  1
# 922  actual :  1  predicted :  1
# 923  actual :  1  predicted :  1
# 924  actual :  1  predicted :  1
# 925  actual :  0  predicted :  0
# 926  actual :  1  predicted :  1
# 927  actual :  1  predicted :  1
# 928  actual :  0  predicted :  0
# 929  actual :  1  predicted :  0
# 930  actual :  1  predicted :  1
# 931  actual :  1  predicted :  1
# 932  actual :  1  predicted :  1
# 933  actual :  1  predicted :  0
# 934  actual :  1  predicted :  1
# 935  actual :  0  predicted :  0
# 936  actual :  1  predicted :  1
# 937  actual :  1  predicted :  1
# 938  actual :  0  predicted :  0
# 939  actual :  0  predicted :  0
# 940  actual :  1  predicted :  1
# 941  actual :  0  predicted :  0
# 942  actual :  0  predicted :  0
# 943  actual :  1  predicted :  1
# 944  actual :  1  predicted :  1
# 945  actual :  1  predicted :  1
# 946  actual :  0  predicted :  0
# 947  actual :  1  predicted :  1
# 948  actual :  0  predicted :  0
# 949  actual :  0  predicted :  0
# 950  actual :  1  predicted :  1
# 951  actual :  1  predicted :  0
# 952  actual :  0  predicted :  0
# 953  actual :  1  predicted :  0
# 954  actual :  0  predicted :  0
# 955  actual :  1  predicted :  0
# 956  actual :  0  predicted :  0
# 957  actual :  1  predicted :  1
# 958  actual :  0  predicted :  0
# 959  actual :  1  predicted :  1
# 960  actual :  1  predicted :  1
# 961  actual :  1  predicted :  1
# 962  actual :  1  predicted :  0
# 963  actual :  1  predicted :  1
# 964  actual :  0  predicted :  0
# 965  actual :  1  predicted :  1
# 966  actual :  0  predicted :  0
# 967  actual :  0  predicted :  0
# 968  actual :  0  predicted :  0
# 969  actual :  1  predicted :  1
# 970  actual :  1  predicted :  1
# 971  actual :  1  predicted :  1
# 972  actual :  0  predicted :  0
# 973  actual :  0  predicted :  0
# 974  actual :  0  predicted :  0
# 975  actual :  0  predicted :  0
# 976  actual :  1  predicted :  1
# 977  actual :  1  predicted :  0
# 978  actual :  1  predicted :  1
# 979  actual :  1  predicted :  1
# 980  actual :  1  predicted :  1
# 981  actual :  1  predicted :  1
# 982  actual :  1  predicted :  1
# 983  actual :  0  predicted :  0
# 984  actual :  1  predicted :  1
# 985  actual :  0  predicted :  0
# 986  actual :  0  predicted :  0
# 987  actual :  1  predicted :  1
# 988  actual :  1  predicted :  1
# 989  actual :  0  predicted :  0
# 990  actual :  1  predicted :  1
# 991  actual :  0  predicted :  0
# 992  actual :  1  predicted :  1
# 993  actual :  1  predicted :  1
# 994  actual :  1  predicted :  1
# 995  actual :  0  predicted :  0
# 996  actual :  1  predicted :  1
# 997  actual :  1  predicted :  1
# 998  actual :  1  predicted :  1
# 999  actual :  1  predicted :  1
# 1000  actual :  1  predicted :  1
# 1001  actual :  1  predicted :  1
# Epoch: 222 Learning rate: 0.00000
# Running 4008 samples:
# Total loss:
# 1.0129607830095289
# Training Accuracy = 0.9998, time = 28.818 seconds
#
# Running 1002 samples:
# Total loss:
# 1651.3928419762415
# Test Accuracy = 0.8713, Test Precision = 0.8907, Test Recall = 0.8582, Test F1 = 0.8741
#
# Time = 2.751 seconds
#
# confusion metric :
# [425  55  74 448]
# Epoch: 223 Learning rate: 0.00000
# Running 4008 samples:
# Total loss:
# 0.0
# Training Accuracy = 1.0000, time = 28.979 seconds
#
# Running 1002 samples:
# Total loss:
# 1651.3928511325394
# Test Accuracy = 0.8713, Test Precision = 0.8907, Test Recall = 0.8582, Test F1 = 0.8741
#
# Time = 2.761 seconds
#
# confusion metric :
# [425  55  74 448]
# Epoch: 224 Learning rate: 0.00000
# Running 4008 samples:
# Total loss:
# 0.8251064419746399
# Training Accuracy = 0.9998, time = 30.234 seconds
#
# Running 1002 samples:
# Total loss:
# 1615.7014999429432
# Test Accuracy = 0.8653, Test Precision = 0.8686, Test Recall = 0.8736, Test F1 = 0.8711
#
# Time = 2.943 seconds
#
# confusion metric :
# [411  69  66 456]
# Epoch: 225 Learning rate: 0.00000
# Running 4008 samples:
# Total loss:
# 19.45361144542693
# Training Accuracy = 0.9995, time = 30.914 seconds
#
# Running 1002 samples:
# Total loss:
# 1022.6938671541944
# Test Accuracy = 0.8713, Test Precision = 0.8786, Test Recall = 0.8736, Test F1 = 0.8761
#
# Time = 2.974 seconds
#
# confusion metric :
# [417  63  66 456]
# Epoch: 226 Learning rate: 0.00000
# Running 4008 samples:
# Total loss:
# 0.0051685741170715005
# Training Accuracy = 1.0000, time = 31.199 seconds
#
# Running 1002 samples:
# Total loss:
# 1026.2367227407765
# Test Accuracy = 0.8713, Test Precision = 0.8801, Test Recall = 0.8716, Test F1 = 0.8758
#
# Time = 2.979 seconds
#
# confusion metric :
# [418  62  67 455]
# for iteration :  225
# 0  actual :  1  predicted :  1
# 1  actual :  1  predicted :  1
# 2  actual :  1  predicted :  1
# 3  actual :  1  predicted :  1
# 4  actual :  0  predicted :  0
# 5  actual :  0  predicted :  0
# 6  actual :  0  predicted :  0
# 7  actual :  1  predicted :  1
# 8  actual :  1  predicted :  1
# 9  actual :  0  predicted :  0
# 10  actual :  1  predicted :  1
# 11  actual :  0  predicted :  0
# 12  actual :  1  predicted :  1
# 13  actual :  1  predicted :  1
# 14  actual :  1  predicted :  1
# 15  actual :  0  predicted :  0
# 16  actual :  0  predicted :  0
# 17  actual :  1  predicted :  1
# 18  actual :  0  predicted :  0
# 19  actual :  0  predicted :  0
# 20  actual :  0  predicted :  0
# 21  actual :  1  predicted :  0
# 22  actual :  1  predicted :  1
# 23  actual :  1  predicted :  1
# 24  actual :  1  predicted :  1
# 25  actual :  0  predicted :  0
# 26  actual :  1  predicted :  1
# 27  actual :  0  predicted :  0
# 28  actual :  1  predicted :  1
# 29  actual :  1  predicted :  1
# 30  actual :  1  predicted :  1
# 31  actual :  0  predicted :  0
# 32  actual :  1  predicted :  1
# 33  actual :  1  predicted :  1
# 34  actual :  1  predicted :  0
# 35  actual :  0  predicted :  1
# 36  actual :  1  predicted :  0
# 37  actual :  0  predicted :  0
# 38  actual :  0  predicted :  0
# 39  actual :  0  predicted :  0
# 40  actual :  0  predicted :  0
# 41  actual :  0  predicted :  0
# 42  actual :  0  predicted :  0
# 43  actual :  0  predicted :  1
# 44  actual :  1  predicted :  1
# 45  actual :  0  predicted :  0
# 46  actual :  0  predicted :  0
# 47  actual :  1  predicted :  1
# 48  actual :  1  predicted :  0
# 49  actual :  1  predicted :  1
# 50  actual :  0  predicted :  0
# 51  actual :  1  predicted :  1
# 52  actual :  0  predicted :  0
# 53  actual :  0  predicted :  0
# 54  actual :  1  predicted :  1
# 55  actual :  1  predicted :  1
# 56  actual :  1  predicted :  1
# 57  actual :  0  predicted :  0
# 58  actual :  1  predicted :  1
# 59  actual :  0  predicted :  0
# 60  actual :  0  predicted :  0
# 61  actual :  1  predicted :  0
# 62  actual :  0  predicted :  0
# 63  actual :  1  predicted :  1
# 64  actual :  1  predicted :  1
# 65  actual :  1  predicted :  1
# 66  actual :  1  predicted :  1
# 67  actual :  0  predicted :  0
# 68  actual :  0  predicted :  0
# 69  actual :  0  predicted :  0
# 70  actual :  1  predicted :  0
# 71  actual :  0  predicted :  0
# 72  actual :  1  predicted :  1
# 73  actual :  0  predicted :  0
# 74  actual :  0  predicted :  0
# 75  actual :  1  predicted :  1
# 76  actual :  1  predicted :  1
# 77  actual :  0  predicted :  0
# 78  actual :  0  predicted :  0
# 79  actual :  1  predicted :  1
# 80  actual :  0  predicted :  0
# 81  actual :  0  predicted :  0
# 82  actual :  0  predicted :  0
# 83  actual :  1  predicted :  1
# 84  actual :  1  predicted :  1
# 85  actual :  0  predicted :  0
# 86  actual :  0  predicted :  1
# 87  actual :  1  predicted :  1
# 88  actual :  1  predicted :  1
# 89  actual :  1  predicted :  1
# 90  actual :  0  predicted :  0
# 91  actual :  0  predicted :  0
# 92  actual :  1  predicted :  1
# 93  actual :  0  predicted :  0
# 94  actual :  0  predicted :  0
# 95  actual :  1  predicted :  1
# 96  actual :  0  predicted :  0
# 97  actual :  1  predicted :  1
# 98  actual :  0  predicted :  0
# 99  actual :  0  predicted :  0
# 100  actual :  1  predicted :  1
# 101  actual :  1  predicted :  1
# 102  actual :  0  predicted :  0
# 103  actual :  1  predicted :  1
# 104  actual :  1  predicted :  1
# 105  actual :  0  predicted :  0
# 106  actual :  1  predicted :  1
# 107  actual :  1  predicted :  1
# 108  actual :  1  predicted :  1
# 109  actual :  1  predicted :  1
# 110  actual :  0  predicted :  0
# 111  actual :  0  predicted :  0
# 112  actual :  0  predicted :  0
# 113  actual :  1  predicted :  0
# 114  actual :  1  predicted :  1
# 115  actual :  1  predicted :  0
# 116  actual :  1  predicted :  1
# 117  actual :  0  predicted :  0
# 118  actual :  1  predicted :  1
# 119  actual :  1  predicted :  1
# 120  actual :  1  predicted :  1
# 121  actual :  1  predicted :  1
# 122  actual :  1  predicted :  1
# 123  actual :  0  predicted :  0
# 124  actual :  1  predicted :  1
# 125  actual :  0  predicted :  0
# 126  actual :  1  predicted :  0
# 127  actual :  0  predicted :  0
# 128  actual :  0  predicted :  0
# 129  actual :  0  predicted :  0
# 130  actual :  0  predicted :  0
# 131  actual :  0  predicted :  1
# 132  actual :  1  predicted :  1
# 133  actual :  1  predicted :  1
# 134  actual :  1  predicted :  1
# 135  actual :  0  predicted :  0
# 136  actual :  1  predicted :  1
# 137  actual :  1  predicted :  0
# 138  actual :  0  predicted :  0
# 139  actual :  0  predicted :  0
# 140  actual :  0  predicted :  1
# 141  actual :  1  predicted :  1
# 142  actual :  0  predicted :  0
# 143  actual :  1  predicted :  1
# 144  actual :  1  predicted :  1
# 145  actual :  1  predicted :  1
# 146  actual :  1  predicted :  1
# 147  actual :  1  predicted :  0
# 148  actual :  1  predicted :  1
# 149  actual :  1  predicted :  1
# 150  actual :  0  predicted :  0
# 151  actual :  0  predicted :  0
# 152  actual :  0  predicted :  0
# 153  actual :  0  predicted :  0
# 154  actual :  0  predicted :  0
# 155  actual :  1  predicted :  1
# 156  actual :  1  predicted :  1
# 157  actual :  1  predicted :  1
# 158  actual :  0  predicted :  0
# 159  actual :  1  predicted :  0
# 160  actual :  1  predicted :  1
# 161  actual :  0  predicted :  0
# 162  actual :  0  predicted :  0
# 163  actual :  0  predicted :  0
# 164  actual :  0  predicted :  0
# 165  actual :  1  predicted :  1
# 166  actual :  1  predicted :  1
# 167  actual :  0  predicted :  1
# 168  actual :  1  predicted :  1
# 169  actual :  0  predicted :  0
# 170  actual :  1  predicted :  1
# 171  actual :  0  predicted :  0
# 172  actual :  1  predicted :  1
# 173  actual :  0  predicted :  0
# 174  actual :  0  predicted :  0
# 175  actual :  1  predicted :  1
# 176  actual :  1  predicted :  1
# 177  actual :  0  predicted :  0
# 178  actual :  1  predicted :  1
# 179  actual :  0  predicted :  0
# 180  actual :  1  predicted :  1
# 181  actual :  0  predicted :  1
# 182  actual :  0  predicted :  0
# 183  actual :  1  predicted :  0
# 184  actual :  1  predicted :  1
# 185  actual :  0  predicted :  0
# 186  actual :  0  predicted :  0
# 187  actual :  0  predicted :  0
# 188  actual :  1  predicted :  1
# 189  actual :  1  predicted :  1
# 190  actual :  1  predicted :  1
# 191  actual :  1  predicted :  1
# 192  actual :  0  predicted :  0
# 193  actual :  1  predicted :  1
# 194  actual :  1  predicted :  1
# 195  actual :  0  predicted :  0
# 196  actual :  1  predicted :  1
# 197  actual :  0  predicted :  1
# 198  actual :  1  predicted :  1
# 199  actual :  1  predicted :  1
# 200  actual :  1  predicted :  1
# 201  actual :  1  predicted :  1
# 202  actual :  0  predicted :  0
# 203  actual :  0  predicted :  0
# 204  actual :  1  predicted :  1
# 205  actual :  0  predicted :  0
# 206  actual :  0  predicted :  0
# 207  actual :  1  predicted :  1
# 208  actual :  0  predicted :  1
# 209  actual :  1  predicted :  1
# 210  actual :  0  predicted :  0
# 211  actual :  1  predicted :  1
# 212  actual :  0  predicted :  0
# 213  actual :  0  predicted :  0
# 214  actual :  1  predicted :  1
# 215  actual :  1  predicted :  1
# 216  actual :  1  predicted :  1
# 217  actual :  1  predicted :  1
# 218  actual :  1  predicted :  1
# 219  actual :  1  predicted :  1
# 220  actual :  0  predicted :  1
# 221  actual :  1  predicted :  0
# 222  actual :  0  predicted :  0
# 223  actual :  0  predicted :  0
# 224  actual :  0  predicted :  1
# 225  actual :  1  predicted :  1
# 226  actual :  0  predicted :  1
# 227  actual :  0  predicted :  0
# 228  actual :  1  predicted :  1
# 229  actual :  1  predicted :  1
# 230  actual :  0  predicted :  0
# 231  actual :  1  predicted :  1
# 232  actual :  0  predicted :  0
# 233  actual :  0  predicted :  0
# 234  actual :  0  predicted :  1
# 235  actual :  0  predicted :  0
# 236  actual :  1  predicted :  1
# 237  actual :  1  predicted :  1
# 238  actual :  1  predicted :  1
# 239  actual :  0  predicted :  0
# 240  actual :  0  predicted :  0
# 241  actual :  0  predicted :  0
# 242  actual :  1  predicted :  1
# 243  actual :  1  predicted :  1
# 244  actual :  0  predicted :  0
# 245  actual :  1  predicted :  0
# 246  actual :  1  predicted :  1
# 247  actual :  1  predicted :  0
# 248  actual :  0  predicted :  0
# 249  actual :  0  predicted :  0
# 250  actual :  1  predicted :  1
# 251  actual :  0  predicted :  0
# 252  actual :  1  predicted :  1
# 253  actual :  0  predicted :  0
# 254  actual :  0  predicted :  0
# 255  actual :  1  predicted :  1
# 256  actual :  1  predicted :  1
# 257  actual :  1  predicted :  1
# 258  actual :  0  predicted :  0
# 259  actual :  1  predicted :  1
# 260  actual :  0  predicted :  0
# 261  actual :  1  predicted :  1
# 262  actual :  1  predicted :  1
# 263  actual :  0  predicted :  0
# 264  actual :  0  predicted :  0
# 265  actual :  0  predicted :  0
# 266  actual :  0  predicted :  0
# 267  actual :  1  predicted :  1
# 268  actual :  1  predicted :  1
# 269  actual :  0  predicted :  0
# 270  actual :  0  predicted :  0
# 271  actual :  1  predicted :  1
# 272  actual :  0  predicted :  0
# 273  actual :  0  predicted :  0
# 274  actual :  1  predicted :  1
# 275  actual :  1  predicted :  1
# 276  actual :  0  predicted :  0
# 277  actual :  1  predicted :  0
# 278  actual :  0  predicted :  1
# 279  actual :  1  predicted :  1
# 280  actual :  1  predicted :  1
# 281  actual :  0  predicted :  0
# 282  actual :  0  predicted :  0
# 283  actual :  0  predicted :  1
# 284  actual :  0  predicted :  0
# 285  actual :  0  predicted :  0
# 286  actual :  1  predicted :  1
# 287  actual :  0  predicted :  0
# 288  actual :  1  predicted :  0
# 289  actual :  1  predicted :  1
# 290  actual :  0  predicted :  0
# 291  actual :  1  predicted :  1
# 292  actual :  1  predicted :  1
# 293  actual :  1  predicted :  1
# 294  actual :  1  predicted :  1
# 295  actual :  0  predicted :  0
# 296  actual :  0  predicted :  1
# 297  actual :  0  predicted :  0
# 298  actual :  1  predicted :  1
# 299  actual :  0  predicted :  1
# 300  actual :  1  predicted :  1
# 301  actual :  0  predicted :  0
# 302  actual :  1  predicted :  1
# 303  actual :  0  predicted :  0
# 304  actual :  0  predicted :  0
# 305  actual :  0  predicted :  0
# 306  actual :  1  predicted :  1
# 307  actual :  1  predicted :  1
# 308  actual :  1  predicted :  0
# 309  actual :  1  predicted :  1
# 310  actual :  1  predicted :  1
# 311  actual :  1  predicted :  1
# 312  actual :  0  predicted :  1
# 313  actual :  0  predicted :  0
# 314  actual :  0  predicted :  1
# 315  actual :  1  predicted :  1
# 316  actual :  1  predicted :  1
# 317  actual :  0  predicted :  0
# 318  actual :  1  predicted :  1
# 319  actual :  1  predicted :  1
# 320  actual :  1  predicted :  1
# 321  actual :  1  predicted :  1
# 322  actual :  0  predicted :  0
# 323  actual :  0  predicted :  0
# 324  actual :  0  predicted :  0
# 325  actual :  1  predicted :  1
# 326  actual :  0  predicted :  0
# 327  actual :  1  predicted :  0
# 328  actual :  0  predicted :  0
# 329  actual :  0  predicted :  0
# 330  actual :  1  predicted :  1
# 331  actual :  0  predicted :  0
# 332  actual :  1  predicted :  1
# 333  actual :  1  predicted :  0
# 334  actual :  1  predicted :  1
# 335  actual :  0  predicted :  0
# 336  actual :  1  predicted :  0
# 337  actual :  0  predicted :  0
# 338  actual :  0  predicted :  0
# 339  actual :  1  predicted :  1
# 340  actual :  0  predicted :  0
# 341  actual :  0  predicted :  0
# 342  actual :  0  predicted :  0
# 343  actual :  0  predicted :  1
# 344  actual :  0  predicted :  0
# 345  actual :  1  predicted :  1
# 346  actual :  1  predicted :  1
# 347  actual :  1  predicted :  1
# 348  actual :  0  predicted :  0
# 349  actual :  1  predicted :  1
# 350  actual :  0  predicted :  0
# 351  actual :  0  predicted :  0
# 352  actual :  0  predicted :  0
# 353  actual :  1  predicted :  1
# 354  actual :  0  predicted :  0
# 355  actual :  1  predicted :  1
# 356  actual :  1  predicted :  1
# 357  actual :  1  predicted :  1
# 358  actual :  0  predicted :  1
# 359  actual :  1  predicted :  1
# 360  actual :  1  predicted :  1
# 361  actual :  1  predicted :  1
# 362  actual :  0  predicted :  0
# 363  actual :  0  predicted :  0
# 364  actual :  1  predicted :  1
# 365  actual :  1  predicted :  1
# 366  actual :  1  predicted :  1
# 367  actual :  0  predicted :  0
# 368  actual :  0  predicted :  1
# 369  actual :  0  predicted :  0
# 370  actual :  0  predicted :  0
# 371  actual :  0  predicted :  0
# 372  actual :  1  predicted :  1
# 373  actual :  1  predicted :  1
# 374  actual :  1  predicted :  1
# 375  actual :  1  predicted :  0
# 376  actual :  0  predicted :  0
# 377  actual :  0  predicted :  1
# 378  actual :  1  predicted :  1
# 379  actual :  1  predicted :  1
# 380  actual :  1  predicted :  1
# 381  actual :  0  predicted :  1
# 382  actual :  1  predicted :  1
# 383  actual :  0  predicted :  0
# 384  actual :  1  predicted :  0
# 385  actual :  0  predicted :  0
# 386  actual :  1  predicted :  1
# 387  actual :  1  predicted :  1
# 388  actual :  1  predicted :  1
# 389  actual :  1  predicted :  1
# 390  actual :  1  predicted :  1
# 391  actual :  1  predicted :  1
# 392  actual :  0  predicted :  0
# 393  actual :  1  predicted :  1
# 394  actual :  0  predicted :  1
# 395  actual :  0  predicted :  0
# 396  actual :  1  predicted :  0
# 397  actual :  1  predicted :  1
# 398  actual :  1  predicted :  1
# 399  actual :  1  predicted :  1
# 400  actual :  0  predicted :  0
# 401  actual :  0  predicted :  0
# 402  actual :  1  predicted :  1
# 403  actual :  1  predicted :  1
# 404  actual :  0  predicted :  0
# 405  actual :  1  predicted :  1
# 406  actual :  0  predicted :  0
# 407  actual :  1  predicted :  1
# 408  actual :  0  predicted :  0
# 409  actual :  0  predicted :  0
# 410  actual :  1  predicted :  1
# 411  actual :  1  predicted :  0
# 412  actual :  0  predicted :  0
# 413  actual :  0  predicted :  1
# 414  actual :  0  predicted :  0
# 415  actual :  0  predicted :  0
# 416  actual :  0  predicted :  0
# 417  actual :  0  predicted :  0
# 418  actual :  1  predicted :  1
# 419  actual :  1  predicted :  1
# 420  actual :  1  predicted :  1
# 421  actual :  1  predicted :  1
# 422  actual :  0  predicted :  0
# 423  actual :  1  predicted :  1
# 424  actual :  1  predicted :  1
# 425  actual :  0  predicted :  1
# 426  actual :  0  predicted :  0
# 427  actual :  1  predicted :  1
# 428  actual :  0  predicted :  0
# 429  actual :  1  predicted :  1
# 430  actual :  0  predicted :  0
# 431  actual :  1  predicted :  1
# 432  actual :  0  predicted :  1
# 433  actual :  1  predicted :  1
# 434  actual :  1  predicted :  1
# 435  actual :  1  predicted :  1
# 436  actual :  0  predicted :  0
# 437  actual :  1  predicted :  1
# 438  actual :  1  predicted :  0
# 439  actual :  0  predicted :  0
# 440  actual :  1  predicted :  0
# 441  actual :  1  predicted :  1
# 442  actual :  1  predicted :  1
# 443  actual :  0  predicted :  1
# 444  actual :  0  predicted :  0
# 445  actual :  1  predicted :  1
# 446  actual :  0  predicted :  1
# 447  actual :  1  predicted :  1
# 448  actual :  1  predicted :  1
# 449  actual :  1  predicted :  1
# 450  actual :  1  predicted :  0
# 451  actual :  0  predicted :  0
# 452  actual :  0  predicted :  0
# 453  actual :  0  predicted :  0
# 454  actual :  0  predicted :  0
# 455  actual :  0  predicted :  0
# 456  actual :  1  predicted :  1
# 457  actual :  0  predicted :  0
# 458  actual :  0  predicted :  0
# 459  actual :  1  predicted :  0
# 460  actual :  0  predicted :  0
# 461  actual :  0  predicted :  1
# 462  actual :  1  predicted :  1
# 463  actual :  0  predicted :  0
# 464  actual :  1  predicted :  1
# 465  actual :  1  predicted :  1
# 466  actual :  1  predicted :  1
# 467  actual :  0  predicted :  0
# 468  actual :  0  predicted :  0
# 469  actual :  1  predicted :  1
# 470  actual :  1  predicted :  0
# 471  actual :  1  predicted :  1
# 472  actual :  1  predicted :  1
# 473  actual :  1  predicted :  1
# 474  actual :  0  predicted :  0
# 475  actual :  0  predicted :  0
# 476  actual :  0  predicted :  0
# 477  actual :  0  predicted :  0
# 478  actual :  1  predicted :  1
# 479  actual :  0  predicted :  0
# 480  actual :  0  predicted :  0
# 481  actual :  0  predicted :  0
# 482  actual :  0  predicted :  0
# 483  actual :  1  predicted :  1
# 484  actual :  0  predicted :  0
# 485  actual :  1  predicted :  1
# 486  actual :  0  predicted :  0
# 487  actual :  0  predicted :  0
# 488  actual :  0  predicted :  1
# 489  actual :  0  predicted :  1
# 490  actual :  0  predicted :  0
# 491  actual :  0  predicted :  0
# 492  actual :  0  predicted :  0
# 493  actual :  0  predicted :  0
# 494  actual :  1  predicted :  1
# 495  actual :  0  predicted :  0
# 496  actual :  0  predicted :  0
# 497  actual :  1  predicted :  1
# 498  actual :  1  predicted :  1
# 499  actual :  1  predicted :  0
# 500  actual :  1  predicted :  1
# 501  actual :  0  predicted :  0
# 502  actual :  1  predicted :  1
# 503  actual :  0  predicted :  0
# 504  actual :  1  predicted :  1
# 505  actual :  1  predicted :  1
# 506  actual :  0  predicted :  1
# 507  actual :  1  predicted :  1
# 508  actual :  0  predicted :  0
# 509  actual :  0  predicted :  0
# 510  actual :  0  predicted :  0
# 511  actual :  0  predicted :  0
# 512  actual :  1  predicted :  1
# 513  actual :  0  predicted :  0
# 514  actual :  1  predicted :  1
# 515  actual :  1  predicted :  1
# 516  actual :  1  predicted :  1
# 517  actual :  1  predicted :  0
# 518  actual :  0  predicted :  0
# 519  actual :  0  predicted :  0
# 520  actual :  0  predicted :  1
# 521  actual :  1  predicted :  1
# 522  actual :  1  predicted :  1
# 523  actual :  0  predicted :  0
# 524  actual :  0  predicted :  0
# 525  actual :  0  predicted :  0
# 526  actual :  0  predicted :  0
# 527  actual :  0  predicted :  0
# 528  actual :  0  predicted :  0
# 529  actual :  0  predicted :  0
# 530  actual :  0  predicted :  0
# 531  actual :  1  predicted :  1
# 532  actual :  0  predicted :  0
# 533  actual :  0  predicted :  0
# 534  actual :  0  predicted :  1
# 535  actual :  0  predicted :  0
# 536  actual :  1  predicted :  1
# 537  actual :  0  predicted :  0
# 538  actual :  1  predicted :  1
# 539  actual :  0  predicted :  0
# 540  actual :  0  predicted :  0
# 541  actual :  1  predicted :  1
# 542  actual :  1  predicted :  1
# 543  actual :  1  predicted :  1
# 544  actual :  1  predicted :  1
# 545  actual :  1  predicted :  0
# 546  actual :  0  predicted :  0
# 547  actual :  0  predicted :  0
# 548  actual :  0  predicted :  0
# 549  actual :  1  predicted :  0
# 550  actual :  0  predicted :  0
# 551  actual :  1  predicted :  1
# 552  actual :  0  predicted :  0
# 553  actual :  0  predicted :  0
# 554  actual :  1  predicted :  1
# 555  actual :  0  predicted :  0
# 556  actual :  1  predicted :  1
# 557  actual :  1  predicted :  1
# 558  actual :  0  predicted :  0
# 559  actual :  0  predicted :  0
# 560  actual :  0  predicted :  1
# 561  actual :  1  predicted :  0
# 562  actual :  1  predicted :  1
# 563  actual :  0  predicted :  0
# 564  actual :  1  predicted :  1
# 565  actual :  1  predicted :  1
# 566  actual :  1  predicted :  1
# 567  actual :  0  predicted :  1
# 568  actual :  0  predicted :  0
# 569  actual :  1  predicted :  0
# 570  actual :  0  predicted :  0
# 571  actual :  0  predicted :  0
# 572  actual :  1  predicted :  1
# 573  actual :  1  predicted :  1
# 574  actual :  1  predicted :  0
# 575  actual :  1  predicted :  1
# 576  actual :  1  predicted :  1
# 577  actual :  1  predicted :  1
# 578  actual :  1  predicted :  1
# 579  actual :  0  predicted :  0
# 580  actual :  0  predicted :  0
# 581  actual :  0  predicted :  0
# 582  actual :  0  predicted :  0
# 583  actual :  1  predicted :  1
# 584  actual :  0  predicted :  0
# 585  actual :  1  predicted :  0
# 586  actual :  1  predicted :  1
# 587  actual :  1  predicted :  1
# 588  actual :  1  predicted :  1
# 589  actual :  1  predicted :  1
# 590  actual :  1  predicted :  1
# 591  actual :  0  predicted :  0
# 592  actual :  0  predicted :  0
# 593  actual :  0  predicted :  1
# 594  actual :  0  predicted :  0
# 595  actual :  0  predicted :  0
# 596  actual :  1  predicted :  1
# 597  actual :  1  predicted :  0
# 598  actual :  0  predicted :  1
# 599  actual :  0  predicted :  0
# 600  actual :  1  predicted :  1
# 601  actual :  1  predicted :  1
# 602  actual :  0  predicted :  0
# 603  actual :  0  predicted :  0
# 604  actual :  0  predicted :  0
# 605  actual :  1  predicted :  1
# 606  actual :  0  predicted :  0
# 607  actual :  1  predicted :  1
# 608  actual :  1  predicted :  1
# 609  actual :  1  predicted :  1
# 610  actual :  0  predicted :  0
# 611  actual :  1  predicted :  1
# 612  actual :  0  predicted :  0
# 613  actual :  0  predicted :  0
# 614  actual :  0  predicted :  0
# 615  actual :  0  predicted :  1
# 616  actual :  0  predicted :  0
# 617  actual :  1  predicted :  1
# 618  actual :  0  predicted :  0
# 619  actual :  0  predicted :  0
# 620  actual :  1  predicted :  1
# 621  actual :  1  predicted :  1
# 622  actual :  1  predicted :  1
# 623  actual :  1  predicted :  1
# 624  actual :  0  predicted :  0
# 625  actual :  1  predicted :  1
# 626  actual :  1  predicted :  1
# 627  actual :  1  predicted :  1
# 628  actual :  1  predicted :  1
# 629  actual :  1  predicted :  1
# 630  actual :  0  predicted :  0
# 631  actual :  1  predicted :  1
# 632  actual :  0  predicted :  0
# 633  actual :  0  predicted :  0
# 634  actual :  0  predicted :  0
# 635  actual :  0  predicted :  0
# 636  actual :  0  predicted :  1
# 637  actual :  1  predicted :  1
# 638  actual :  0  predicted :  0
# 639  actual :  1  predicted :  1
# 640  actual :  0  predicted :  1
# 641  actual :  1  predicted :  1
# 642  actual :  0  predicted :  0
# 643  actual :  1  predicted :  1
# 644  actual :  1  predicted :  0
# 645  actual :  0  predicted :  0
# 646  actual :  0  predicted :  0
# 647  actual :  1  predicted :  1
# 648  actual :  0  predicted :  0
# 649  actual :  1  predicted :  1
# 650  actual :  1  predicted :  1
# 651  actual :  1  predicted :  1
# 652  actual :  1  predicted :  1
# 653  actual :  1  predicted :  1
# 654  actual :  1  predicted :  0
# 655  actual :  0  predicted :  0
# 656  actual :  1  predicted :  1
# 657  actual :  0  predicted :  0
# 658  actual :  0  predicted :  0
# 659  actual :  1  predicted :  1
# 660  actual :  0  predicted :  0
# 661  actual :  0  predicted :  0
# 662  actual :  0  predicted :  1
# 663  actual :  1  predicted :  0
# 664  actual :  0  predicted :  0
# 665  actual :  0  predicted :  0
# 666  actual :  0  predicted :  0
# 667  actual :  0  predicted :  0
# 668  actual :  1  predicted :  1
# 669  actual :  0  predicted :  0
# 670  actual :  0  predicted :  0
# 671  actual :  1  predicted :  1
# 672  actual :  0  predicted :  0
# 673  actual :  0  predicted :  0
# 674  actual :  0  predicted :  0
# 675  actual :  0  predicted :  0
# 676  actual :  1  predicted :  1
# 677  actual :  0  predicted :  0
# 678  actual :  1  predicted :  0
# 679  actual :  0  predicted :  0
# 680  actual :  1  predicted :  1
# 681  actual :  1  predicted :  1
# 682  actual :  1  predicted :  1
# 683  actual :  0  predicted :  0
# 684  actual :  0  predicted :  0
# 685  actual :  1  predicted :  1
# 686  actual :  0  predicted :  0
# 687  actual :  0  predicted :  1
# 688  actual :  1  predicted :  1
# 689  actual :  0  predicted :  1
# 690  actual :  0  predicted :  0
# 691  actual :  1  predicted :  0
# 692  actual :  1  predicted :  1
# 693  actual :  0  predicted :  0
# 694  actual :  1  predicted :  1
# 695  actual :  0  predicted :  0
# 696  actual :  1  predicted :  1
# 697  actual :  1  predicted :  1
# 698  actual :  0  predicted :  1
# 699  actual :  0  predicted :  0
# 700  actual :  1  predicted :  1
# 701  actual :  0  predicted :  0
# 702  actual :  1  predicted :  1
# 703  actual :  0  predicted :  0
# 704  actual :  1  predicted :  0
# 705  actual :  1  predicted :  1
# 706  actual :  1  predicted :  1
# 707  actual :  1  predicted :  1
# 708  actual :  1  predicted :  0
# 709  actual :  1  predicted :  1
# 710  actual :  1  predicted :  1
# 711  actual :  0  predicted :  0
# 712  actual :  1  predicted :  1
# 713  actual :  1  predicted :  1
# 714  actual :  1  predicted :  1
# 715  actual :  1  predicted :  1
# 716  actual :  0  predicted :  0
# 717  actual :  1  predicted :  1
# 718  actual :  0  predicted :  0
# ...
# 519  actual :  0  predicted :  0
# 520  actual :  0  predicted :  1
# 521  actual :  1  predicted :  1
# 522  actual :  1  predicted :  1
# 523  actual :  0  predicted :  0
# 524  actual :  0  predicted :  0
# 525  actual :  0  predicted :  0
# 526  actual :  0  predicted :  0
# 527  actual :  0  predicted :  0
# 528  actual :  0  predicted :  0
# 529  actual :  0  predicted :  0
# 530  actual :  0  predicted :  0
# 531  actual :  1  predicted :  1
# 532  actual :  0  predicted :  0
# 533  actual :  0  predicted :  0
# 534  actual :  0  predicted :  1
# 535  actual :  0  predicted :  0
# 536  actual :  1  predicted :  1
# 537  actual :  0  predicted :  0
# 538  actual :  1  predicted :  1
# 539  actual :  0  predicted :  0
# 540  actual :  0  predicted :  0
# 541  actual :  1  predicted :  1
# 542  actual :  1  predicted :  1
# 543  actual :  1  predicted :  1
# 544  actual :  1  predicted :  1
# 545  actual :  1  predicted :  0
# 546  actual :  0  predicted :  0
# 547  actual :  0  predicted :  0
# 548  actual :  0  predicted :  0
# 549  actual :  1  predicted :  0
# 550  actual :  0  predicted :  0
# 551  actual :  1  predicted :  1
# 552  actual :  0  predicted :  0
# 553  actual :  0  predicted :  0
# 554  actual :  1  predicted :  1
# 555  actual :  0  predicted :  0
# 556  actual :  1  predicted :  1
# 557  actual :  1  predicted :  1
# 558  actual :  0  predicted :  0
# 559  actual :  0  predicted :  0
# 560  actual :  0  predicted :  1
# 561  actual :  1  predicted :  0
# 562  actual :  1  predicted :  1
# 563  actual :  0  predicted :  0
# 564  actual :  1  predicted :  1
# 565  actual :  1  predicted :  1
# 566  actual :  1  predicted :  1
# 567  actual :  0  predicted :  1
# 568  actual :  0  predicted :  0
# 569  actual :  1  predicted :  0
# 570  actual :  0  predicted :  0
# 571  actual :  0  predicted :  0
# 572  actual :  1  predicted :  1
# 573  actual :  1  predicted :  1
# 574  actual :  1  predicted :  0
# 575  actual :  1  predicted :  1
# 576  actual :  1  predicted :  1
# 577  actual :  1  predicted :  1
# 578  actual :  1  predicted :  1
# 579  actual :  0  predicted :  0
# 580  actual :  0  predicted :  0
# 581  actual :  0  predicted :  0
# 582  actual :  0  predicted :  0
# 583  actual :  1  predicted :  1
# 584  actual :  0  predicted :  0
# 585  actual :  1  predicted :  0
# 586  actual :  1  predicted :  1
# 587  actual :  1  predicted :  1
# 588  actual :  1  predicted :  1
# 589  actual :  1  predicted :  1
# 590  actual :  1  predicted :  1
# 591  actual :  0  predicted :  0
# 592  actual :  0  predicted :  0
# 593  actual :  0  predicted :  0
# 594  actual :  0  predicted :  0
# 595  actual :  0  predicted :  0
# 596  actual :  1  predicted :  1
# 597  actual :  1  predicted :  0
# 598  actual :  0  predicted :  1
# 599  actual :  0  predicted :  0
# 600  actual :  1  predicted :  0
# 601  actual :  1  predicted :  1
# 602  actual :  0  predicted :  0
# 603  actual :  0  predicted :  0
# 604  actual :  0  predicted :  0
# 605  actual :  1  predicted :  1
# 606  actual :  0  predicted :  0
# 607  actual :  1  predicted :  1
# 608  actual :  1  predicted :  1
# 609  actual :  1  predicted :  1
# 610  actual :  0  predicted :  0
# 611  actual :  1  predicted :  0
# 612  actual :  0  predicted :  0
# 613  actual :  0  predicted :  0
# 614  actual :  0  predicted :  0
# 615  actual :  0  predicted :  1
# 616  actual :  0  predicted :  0
# 617  actual :  1  predicted :  1
# 618  actual :  0  predicted :  0
# 619  actual :  0  predicted :  0
# 620  actual :  1  predicted :  1
# 621  actual :  1  predicted :  1
# 622  actual :  1  predicted :  1
# 623  actual :  1  predicted :  1
# 624  actual :  0  predicted :  0
# 625  actual :  1  predicted :  1
# 626  actual :  1  predicted :  1
# 627  actual :  1  predicted :  0
# 628  actual :  1  predicted :  1
# 629  actual :  1  predicted :  1
# 630  actual :  0  predicted :  0
# 631  actual :  1  predicted :  1
# 632  actual :  0  predicted :  0
# 633  actual :  0  predicted :  0
# 634  actual :  0  predicted :  0
# 635  actual :  0  predicted :  0
# 636  actual :  0  predicted :  0
# 637  actual :  1  predicted :  1
# 638  actual :  0  predicted :  0
# 639  actual :  1  predicted :  1
# 640  actual :  0  predicted :  0
# 641  actual :  1  predicted :  1
# 642  actual :  0  predicted :  0
# 643  actual :  1  predicted :  1
# 644  actual :  1  predicted :  0
# 645  actual :  0  predicted :  0
# 646  actual :  0  predicted :  0
# 647  actual :  1  predicted :  1
# 648  actual :  0  predicted :  0
# 649  actual :  1  predicted :  1
# 650  actual :  1  predicted :  1
# 651  actual :  1  predicted :  1
# 652  actual :  1  predicted :  1
# 653  actual :  1  predicted :  1
# 654  actual :  1  predicted :  0
# 655  actual :  0  predicted :  0
# 656  actual :  1  predicted :  1
# 657  actual :  0  predicted :  0
# 658  actual :  0  predicted :  0
# 659  actual :  1  predicted :  1
# 660  actual :  0  predicted :  0
# 661  actual :  0  predicted :  0
# 662  actual :  0  predicted :  0
# 663  actual :  1  predicted :  0
# 664  actual :  0  predicted :  0
# 665  actual :  0  predicted :  0
# 666  actual :  0  predicted :  0
# 667  actual :  0  predicted :  0
# 668  actual :  1  predicted :  1
# 669  actual :  0  predicted :  0
# 670  actual :  0  predicted :  0
# 671  actual :  1  predicted :  1
# 672  actual :  0  predicted :  0
# 673  actual :  0  predicted :  0
# 674  actual :  0  predicted :  0
# 675  actual :  0  predicted :  0
# 676  actual :  1  predicted :  1
# 677  actual :  0  predicted :  0
# 678  actual :  1  predicted :  0
# 679  actual :  0  predicted :  0
# 680  actual :  1  predicted :  1
# 681  actual :  1  predicted :  1
# 682  actual :  1  predicted :  1
# 683  actual :  0  predicted :  0
# 684  actual :  0  predicted :  0
# 685  actual :  1  predicted :  1
# 686  actual :  0  predicted :  0
# 687  actual :  0  predicted :  1
# 688  actual :  1  predicted :  1
# 689  actual :  0  predicted :  1
# 690  actual :  0  predicted :  0
# 691  actual :  1  predicted :  0
# 692  actual :  1  predicted :  1
# 693  actual :  0  predicted :  0
# 694  actual :  1  predicted :  1
# 695  actual :  0  predicted :  0
# 696  actual :  1  predicted :  1
# 697  actual :  1  predicted :  1
# 698  actual :  0  predicted :  1
# 699  actual :  0  predicted :  0
# 700  actual :  1  predicted :  1
# 701  actual :  0  predicted :  0
# 702  actual :  1  predicted :  1
# 703  actual :  0  predicted :  0
# 704  actual :  1  predicted :  0
# 705  actual :  1  predicted :  1
# 706  actual :  1  predicted :  0
# 707  actual :  1  predicted :  1
# 708  actual :  1  predicted :  0
# 709  actual :  1  predicted :  1
# 710  actual :  1  predicted :  1
# 711  actual :  0  predicted :  0
# 712  actual :  1  predicted :  1
# 713  actual :  1  predicted :  1
# 714  actual :  1  predicted :  1
# 715  actual :  1  predicted :  1
# 716  actual :  0  predicted :  0
# 717  actual :  1  predicted :  1
# 718  actual :  0  predicted :  0
# 719  actual :  1  predicted :  1
# 720  actual :  1  predicted :  1
# 721  actual :  0  predicted :  0
# 722  actual :  0  predicted :  1
# 723  actual :  0  predicted :  0
# 724  actual :  1  predicted :  0
# 725  actual :  1  predicted :  1
# 726  actual :  1  predicted :  0
# 727  actual :  0  predicted :  0
# 728  actual :  1  predicted :  1
# 729  actual :  1  predicted :  1
# 730  actual :  1  predicted :  1
# 731  actual :  0  predicted :  0
# 732  actual :  0  predicted :  0
# 733  actual :  1  predicted :  1
# 734  actual :  0  predicted :  0
# 735  actual :  1  predicted :  1
# 736  actual :  0  predicted :  0
# 737  actual :  0  predicted :  0
# 738  actual :  0  predicted :  0
# 739  actual :  1  predicted :  1
# 740  actual :  0  predicted :  0
# 741  actual :  0  predicted :  0
# 742  actual :  1  predicted :  0
# 743  actual :  0  predicted :  0
# 744  actual :  1  predicted :  1
# 745  actual :  1  predicted :  0
# 746  actual :  1  predicted :  1
# 747  actual :  0  predicted :  0
# 748  actual :  1  predicted :  1
# 749  actual :  1  predicted :  1
# 750  actual :  0  predicted :  0
# 751  actual :  0  predicted :  0
# 752  actual :  0  predicted :  0
# 753  actual :  1  predicted :  1
# 754  actual :  0  predicted :  0
# 755  actual :  1  predicted :  1
# 756  actual :  1  predicted :  1
# 757  actual :  1  predicted :  1
# 758  actual :  0  predicted :  0
# 759  actual :  0  predicted :  0
# 760  actual :  1  predicted :  1
# 761  actual :  0  predicted :  1
# 762  actual :  0  predicted :  0
# 763  actual :  1  predicted :  0
# 764  actual :  1  predicted :  1
# 765  actual :  0  predicted :  0
# 766  actual :  1  predicted :  0
# 767  actual :  1  predicted :  0
# 768  actual :  1  predicted :  1
# 769  actual :  0  predicted :  0
# 770  actual :  0  predicted :  1
# 771  actual :  0  predicted :  0
# 772  actual :  1  predicted :  0
# 773  actual :  1  predicted :  1
# 774  actual :  0  predicted :  0
# 775  actual :  1  predicted :  1
# 776  actual :  0  predicted :  0
# 777  actual :  1  predicted :  1
# 778  actual :  0  predicted :  0
# 779  actual :  1  predicted :  1
# 780  actual :  0  predicted :  0
# 781  actual :  0  predicted :  1
# 782  actual :  0  predicted :  0
# 783  actual :  0  predicted :  0
# 784  actual :  1  predicted :  1
# 785  actual :  1  predicted :  1
# 786  actual :  0  predicted :  0
# 787  actual :  0  predicted :  0
# 788  actual :  0  predicted :  0
# 789  actual :  0  predicted :  0
# 790  actual :  0  predicted :  0
# 791  actual :  0  predicted :  0
# 792  actual :  0  predicted :  0
# 793  actual :  0  predicted :  0
# 794  actual :  0  predicted :  0
# 795  actual :  1  predicted :  0
# 796  actual :  1  predicted :  1
# 797  actual :  0  predicted :  0
# 798  actual :  0  predicted :  0
# 799  actual :  1  predicted :  1
# 800  actual :  0  predicted :  0
# 801  actual :  1  predicted :  1
# 802  actual :  1  predicted :  0
# 803  actual :  0  predicted :  0
# 804  actual :  1  predicted :  1
# 805  actual :  0  predicted :  0
# 806  actual :  1  predicted :  1
# 807  actual :  1  predicted :  1
# 808  actual :  1  predicted :  1
# 809  actual :  0  predicted :  0
# 810  actual :  0  predicted :  0
# 811  actual :  1  predicted :  1
# 812  actual :  0  predicted :  1
# 813  actual :  0  predicted :  0
# 814  actual :  1  predicted :  1
# 815  actual :  0  predicted :  0
# 816  actual :  0  predicted :  0
# 817  actual :  1  predicted :  1
# 818  actual :  0  predicted :  0
# 819  actual :  0  predicted :  0
# 820  actual :  1  predicted :  1
# 821  actual :  0  predicted :  0
# 822  actual :  0  predicted :  0
# 823  actual :  1  predicted :  1
# 824  actual :  1  predicted :  1
# 825  actual :  0  predicted :  0
# 826  actual :  1  predicted :  1
# 827  actual :  0  predicted :  0
# 828  actual :  1  predicted :  1
# 829  actual :  0  predicted :  0
# 830  actual :  0  predicted :  0
# 831  actual :  0  predicted :  0
# 832  actual :  0  predicted :  0
# 833  actual :  1  predicted :  1
# 834  actual :  0  predicted :  0
# 835  actual :  1  predicted :  1
# 836  actual :  1  predicted :  1
# 837  actual :  0  predicted :  0
# 838  actual :  0  predicted :  0
# 839  actual :  1  predicted :  0
# 840  actual :  0  predicted :  0
# 841  actual :  0  predicted :  0
# 842  actual :  1  predicted :  1
# 843  actual :  0  predicted :  0
# 844  actual :  0  predicted :  1
# 845  actual :  0  predicted :  1
# 846  actual :  1  predicted :  1
# 847  actual :  0  predicted :  0
# 848  actual :  1  predicted :  0
# 849  actual :  1  predicted :  1
# 850  actual :  1  predicted :  1
# 851  actual :  1  predicted :  0
# 852  actual :  1  predicted :  0
# 853  actual :  0  predicted :  1
# 854  actual :  1  predicted :  1
# 855  actual :  1  predicted :  1
# 856  actual :  1  predicted :  1
# 857  actual :  1  predicted :  1
# 858  actual :  1  predicted :  1
# 859  actual :  0  predicted :  0
# 860  actual :  0  predicted :  0
# 861  actual :  1  predicted :  1
# 862  actual :  1  predicted :  1
# 863  actual :  1  predicted :  1
# 864  actual :  1  predicted :  0
# 865  actual :  1  predicted :  1
# 866  actual :  0  predicted :  0
# 867  actual :  1  predicted :  1
# 868  actual :  1  predicted :  1
# 869  actual :  1  predicted :  0
# 870  actual :  1  predicted :  0
# 871  actual :  1  predicted :  1
# 872  actual :  1  predicted :  1
# 873  actual :  1  predicted :  1
# 874  actual :  1  predicted :  1
# 875  actual :  0  predicted :  0
# 876  actual :  0  predicted :  0
# 877  actual :  0  predicted :  0
# 878  actual :  1  predicted :  1
# 879  actual :  1  predicted :  1
# 880  actual :  1  predicted :  1
# 881  actual :  0  predicted :  0
# 882  actual :  0  predicted :  0
# 883  actual :  0  predicted :  1
# 884  actual :  0  predicted :  1
# 885  actual :  0  predicted :  0
# 886  actual :  0  predicted :  1
# 887  actual :  1  predicted :  0
# 888  actual :  1  predicted :  1
# 889  actual :  1  predicted :  1
# 890  actual :  0  predicted :  0
# 891  actual :  0  predicted :  0
# 892  actual :  1  predicted :  1
# 893  actual :  0  predicted :  0
# 894  actual :  1  predicted :  1
# 895  actual :  1  predicted :  1
# 896  actual :  0  predicted :  0
# 897  actual :  1  predicted :  1
# 898  actual :  1  predicted :  1
# 899  actual :  0  predicted :  0
# 900  actual :  1  predicted :  1
# 901  actual :  0  predicted :  0
# 902  actual :  1  predicted :  1
# 903  actual :  1  predicted :  1
# 904  actual :  0  predicted :  0
# 905  actual :  0  predicted :  0
# 906  actual :  1  predicted :  0
# 907  actual :  0  predicted :  0
# 908  actual :  0  predicted :  0
# 909  actual :  0  predicted :  0
# 910  actual :  0  predicted :  0
# 911  actual :  0  predicted :  0
# 912  actual :  1  predicted :  1
# 913  actual :  1  predicted :  1
# 914  actual :  1  predicted :  1
# 915  actual :  1  predicted :  1
# 916  actual :  1  predicted :  1
# 917  actual :  0  predicted :  0
# 918  actual :  1  predicted :  1
# 919  actual :  1  predicted :  0
# 920  actual :  1  predicted :  1
# 921  actual :  1  predicted :  1
# 922  actual :  1  predicted :  1
# 923  actual :  1  predicted :  1
# 924  actual :  1  predicted :  0
# 925  actual :  0  predicted :  0
# 926  actual :  1  predicted :  1
# 927  actual :  1  predicted :  1
# 928  actual :  0  predicted :  0
# 929  actual :  1  predicted :  1
# 930  actual :  1  predicted :  1
# 931  actual :  1  predicted :  1
# 932  actual :  1  predicted :  1
# 933  actual :  1  predicted :  0
# 934  actual :  1  predicted :  1
# 935  actual :  0  predicted :  0
# 936  actual :  1  predicted :  1
# 937  actual :  1  predicted :  1
# 938  actual :  0  predicted :  0
# 939  actual :  0  predicted :  0
# 940  actual :  1  predicted :  1
# 941  actual :  0  predicted :  0
# 942  actual :  0  predicted :  0
# 943  actual :  1  predicted :  1
# 944  actual :  1  predicted :  1
# 945  actual :  1  predicted :  1
# 946  actual :  0  predicted :  0
# 947  actual :  1  predicted :  1
# 948  actual :  0  predicted :  0
# 949  actual :  0  predicted :  0
# 950  actual :  1  predicted :  1
# 951  actual :  1  predicted :  0
# 952  actual :  0  predicted :  0
# 953  actual :  1  predicted :  0
# 954  actual :  0  predicted :  0
# 955  actual :  1  predicted :  0
# 956  actual :  0  predicted :  0
# 957  actual :  1  predicted :  1
# 958  actual :  0  predicted :  0
# 959  actual :  1  predicted :  1
# 960  actual :  1  predicted :  1
# 961  actual :  1  predicted :  1
# 962  actual :  1  predicted :  1
# 963  actual :  1  predicted :  1
# 964  actual :  0  predicted :  0
# 965  actual :  1  predicted :  1
# 966  actual :  0  predicted :  0
# 967  actual :  0  predicted :  0
# 968  actual :  0  predicted :  0
# 969  actual :  1  predicted :  1
# 970  actual :  1  predicted :  1
# 971  actual :  1  predicted :  1
# 972  actual :  0  predicted :  0
# 973  actual :  0  predicted :  0
# 974  actual :  0  predicted :  0
# 975  actual :  0  predicted :  0
# 976  actual :  1  predicted :  1
# 977  actual :  1  predicted :  0
# 978  actual :  1  predicted :  1
# 979  actual :  1  predicted :  1
# 980  actual :  1  predicted :  1
# 981  actual :  1  predicted :  1
# 982  actual :  1  predicted :  1
# 983  actual :  0  predicted :  0
# 984  actual :  1  predicted :  1
# 985  actual :  0  predicted :  0
# 986  actual :  0  predicted :  0
# 987  actual :  1  predicted :  1
# 988  actual :  1  predicted :  1
# 989  actual :  0  predicted :  0
# 990  actual :  1  predicted :  1
# 991  actual :  0  predicted :  0
# 992  actual :  1  predicted :  1
# 993  actual :  1  predicted :  1
# 994  actual :  1  predicted :  1
# 995  actual :  0  predicted :  0
# 996  actual :  1  predicted :  1
# 997  actual :  1  predicted :  1
# 998  actual :  1  predicted :  1
# 999  actual :  1  predicted :  0
# 1000  actual :  1  predicted :  1
# 1001  actual :  1  predicted :  1
# Epoch: 242 Learning rate: 0.00000
# Running 4008 samples:

# %% [markdown]
# ### Maximum accuracy fasttext without removing puncuations **85.66**
#
# Results from fast text after removing puncuations
# final Accuracy :  0.8738522954091816
# final precision :  0.9021142508639968
# final recall :  0.850095785440613
# final f1 :  0.8753328730644049

# %% [markdown]
# # Restore and Test Model

# %%
def start_test_epoches(config, session,classifier, train_dataset, test_dataset):
    #record max
    #max_val_acc=-1
    #max_test_acc=-1
 
    all_actual = []
    all_predictions = []
    for i in range(config.max_max_epoch):
        actual, prediction = test_model(config, i, session, classifier, train_dataset, test_dataset)
        all_actual.extend(actual)
        all_predictions.extend(prediction)


    TN, FP, FN, TP = confusion_matrix(all_actual, all_predictions).ravel()

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1 = 2 * precision * recall / (precision + recall)
    accuracy = (TP+TN)/(TP+TN+FN+FP)

    print("final Accuracy : ",accuracy)
    print("final precision : ",precision)
    print("final recall : ",recall)
    print("final f1 : ",f1)

# %%
def test_model(config, i, session, model, train_dataset,test_dataset):
    #compute lr_decay
    lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
    #update learning rate
    model.assign_lr(session, config.learning_rate * lr_decay)


    #testing
    start_time = time.time()
    test_acc,test_precision, test_recall, test_f1,test_actual,test_predictions = run_epoch(session, config, model, test_dataset, tf.no_op(),1, False)
    print("Test Accuracy = %.4f, Test Precision = %.4f, Test Recall = %.4f, Test F1 = %.4f\n" % (test_acc,test_precision,test_recall,test_f1))    
    print("Time = %.3f seconds\n"%(time.time()-start_time))
    #return valid_acc, test_acc

    return test_actual,test_predictions

# %%
tf.reset_default_graph()

with tf.Graph().as_default(), tf.Session() as session:
  initializer = tf.random_normal_initializer(0, 0.05)

  classifier= Classifer(config=config, session=session)
  saver = tf.train.Saver()
  
  init = tf.global_variables_initializer()
  session.run(init)

  saver = tf.train.Saver()

  tf.train.Saver().restore(session,tf.train.latest_checkpoint("/content/drive/My Drive/UNI/FYP/Sentiment Analysis/supportive/S-LSTM/Trained_Model/slstm_models/50epochs/") )
  print("Model restored.")

  word_to_vec(matrix, session,config, classifier)
  start_test_epoches(config, session,classifier, train_dataset, test_dataset)
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/UNI/FYP/Sentiment Analysis/supportive/S-LSTM/Trained_Model/slstm_models/50epochs/
# Model restored.
# word2vec shape:  (18415, 300)
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.124 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.116 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.211 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.143 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.253 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.187 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.141 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.143 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.418 seconds
#
# Running 1002 samples:
# Total loss:
# 633.4246847018374
# Test Accuracy = 0.7665, Test Precision = 0.7045, Test Recall = 0.9502, Test F1 = 0.8091
#
# Time = 3.216 seconds
#
# Running 1002 samples:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-247-0ee1eb2c2e18> in <module>()
#      16
#      17   word_to_vec(matrix, session,config, classifier)
# ---> 18   start_test_epoches(config, session,classifier, train_dataset, test_dataset)
#
# <ipython-input-245-fd297308b987> in start_test_epoches(config, session, classifier, train_dataset, test_dataset)
#       7     all_predictions = []
#       8     for i in range(config.max_max_epoch):
# ----> 9         actual, prediction = test_model(config, i, session, classifier, train_dataset, test_dataset)
#      10         all_actual.extend(actual)
#      11         all_predictions.extend(prediction)
#
# <ipython-input-246-033e05745e1a> in test_model(config, i, session, model, train_dataset, test_dataset)
#       8     #testing
#       9     start_time = time.time()
# ---> 10     test_acc,test_precision, test_recall, test_f1,test_actual,test_predictions = run_epoch(session, config, model, test_dataset, tf.no_op(),1, False)
#      11     print("Test Accuracy = %.4f, Test Precision = %.4f, Test Recall = %.4f, Test F1 = %.4f\n" % (test_acc,test_precision,test_recall,test_f1))
#      12     print("Time = %.3f seconds\n"%(time.time()-start_time))
#
# <ipython-input-232-ba4007eade24> in run_epoch(session, config, model, data, eval_op, keep_prob, is_training)
#      24
#      25
# ---> 26         count, _, cost, to_print,prediction=         session.run([model.accuracy, eval_op,model.cost, model.to_print,model.prediction],            {model.input_data: x, model.labels: y, model.mask:mask, model.keep_prob:keep_prob})
#      27
#      28
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
