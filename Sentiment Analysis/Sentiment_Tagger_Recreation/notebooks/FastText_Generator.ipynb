# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading https://files.pythonhosted.org/packages/10/61/2e01f1397ec533756c1d893c22d9d5ed3fce3a6e4af1976e0d86bb13ea97/fasttext-0.9.1.tar.gz (57kB)
#      |████████████████████████████████| 61kB 4.8MB/s
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext) (2.4.3)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext) (45.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fasttext) (1.17.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.1-cp36-cp36m-linux_x86_64.whl size=2389684 sha256=7eb1a11b71adadffc5fb29cc5b866cbd4917f520825eaa863c8fb268d08fb3a0
#   Stored in directory: /root/.cache/pip/wheels/9f/f0/04/caa82c912aee89ce76358ff954f3f0729b7577c8ff23a292e3
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.9.1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# encoding: utf-8

import pandas as pd
import fasttext

num_features = 300
context = 5
model_location = "/content/gdrive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/saved_models/fastText" \
        + str(num_features) + "_" + str(context)

# %%
def generate_model():

    num_features = 100  # Word vector dimensionality
    # context = 10  # Context window size
    downsampling = 1e-3  # Downsample setting for frequent word
    min_word_count = 1  # Minimum word count - if not occurred this much remove
    num_workers = 6  # Number of threads to run in parallel

    model = fasttext.train_unsupervised('/content/gdrive/My Drive/University/FYP/Sentiment Analysis/Sentiment-tagger/corpus/analyzed/comments_all.csv', model='skipgram', dim=num_features, ws=context, min_count=min_word_count, thread=num_workers)
    # model.init_sims(replace=True)  # If you don't plan to train the model any further
    model.save_model(model_location)
    #
    # check_model_qulity(model, 'නැහැ')

    print(model['නැහැ'])
    print(model.words)
    return

# %%
def check_model_qulity(model, word):
    for s in model.most_similar(word):
        print(s[0].decode("utf-8"))

# %%
generate_model()
# Out:
# [-0.94191605 -0.27531505  0.9603088   0.53617394  0.08615702  0.8961595
#  -0.30326834 -1.1836946   0.20200837 -1.449513   -0.12885077 -0.5232761
#   0.9299135   0.05822072 -0.60200596  0.37264872  0.58063424 -0.09272172
#   0.39196622 -0.03024854 -1.0712343   0.06955294 -0.20500056  0.09230628
#   0.49188295 -0.4737205  -0.08054622  0.31577784  0.4030666   0.25161397
#  -0.41982245  0.27250323 -0.43450716  0.20130153 -0.921593   -0.9513917
#  -0.21944983 -0.48980957 -0.31987324 -0.2778132  -0.18288513  1.5659755
#  -0.51464885 -0.3468941  -0.33312336  0.03480588  0.43083677  0.09065194
#  -0.2780935   0.01734074 -0.8663673   0.25797126 -0.57495165 -0.30473438
#  -0.34768423 -0.3531759  -0.1304043   0.01450811  0.38283268  0.5461419
#  -0.27626777 -0.33702922 -0.13074541 -1.6128674  -0.86367446 -0.14933284
#  -0.76855373  0.88907105 -0.48992267 -0.21693642  1.21179     0.20361559
#  -0.41917977 -0.3971983   0.6037303  -0.14100067 -0.6692663  -0.21963318
#  -1.3543442  -0.75148195 -1.0042454  -0.19711454 -0.9446473  -0.28889394
#   0.50015223  0.31311134 -0.32521197 -0.43717164 -0.12516594  0.21060957
#  -0.16212223 -0.3249379  -0.03354751  0.39901882  0.26258445 -1.3467959
#  -0.03676942 -0.44162768  0.6568313   0.28438386]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
