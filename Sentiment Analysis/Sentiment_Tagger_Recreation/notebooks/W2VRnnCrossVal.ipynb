# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold

from sklearn import preprocessing
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from prettytable import PrettyTable
from sklearn.svm import SVC
import tensorflow as tf
import datetime
from random import randint
from gensim.models import word2vec

# %%
word2vec_model_name = "/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/word_embedding/fasttext/commen_docid_removed300_5"

num_features = 300
max_sentence_length = 50

batchSize = 24
lstmUnits = 64
numClasses = 2
iterations = 1000

labels = tf.placeholder(tf.int32, [batchSize, numClasses])
data = tf.placeholder(tf.float32, [batchSize, max_sentence_length, num_features])

# %%
def main():
    start_time = time.time()
    run_cross_val()
    end_time = time.time()
    print("Time taken for the process: " + str(end_time - start_time))
    return


def convert_to_vectors():
    comments = pd.read_csv("/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus/analyzed/comments_tagged_remove_all_punc_keep_question.csv", ";")
    data_vectors, data_labels = comments_to_vectors(comments)

    np.save('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/vectors_from_W2vRnnCrossVal/data_vectors_common_docid_removed.npy', data_vectors)
    np.save('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/vectors_from_W2vRnnCrossVal/data_labels_common_docid_removed.npy', data_labels)


def load_vectors():
    data_vectors = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/vectors_from_W2vRnnCrossVal/data_vectors_common_docid_removed.npy')
    data_labels = np.load('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/vectors_from_W2vRnnCrossVal/data_labels_common_docid_removed.npy')
    return data_vectors, data_labels


def comments_to_vectors(data):
    model = word2vec.Word2Vec.load(word2vec_model_name)
    comment_vectors = []
    comment_labels = []
    for comment in data["comment"]:
        comment_vectors.append(get_sentence_vector(model, comment))
    for label in data["label"]:
        if label == "POSITIVE":
            comment_labels.append([0, 1])
        else:
            comment_labels.append([1, 0])
    return np.array(comment_vectors), comment_labels


def get_sentence_vector(model, sentence):
    sentence_vector = np.zeros([max_sentence_length, num_features])
    counter = 0
    index2word_set = set(model.wv.index2word)
    for word in sentence.split():
        if word in index2word_set:
            sentence_vector[counter] = model[word]
            counter += 1
            if (counter == max_sentence_length):
                break
        else:
            print("word not in word2vec model: " + word)
    return sentence_vector


def get_batch(size, data, label):
    batch_data = np.empty((size, max_sentence_length, num_features), dtype=float)
    batch_label = []
    for i in range(size):
        random_int = randint(0, len(data) - 1)
        batch_data[i] = data[random_int]
        batch_label.append(label[random_int])
    return batch_data, batch_label


def get_batch_order(size, data, label, batch_no):
    batch_data = data[batch_no * size : (batch_no + 1) * size]
    batch_label = label[batch_no * size : (batch_no + 1) * size]
    return batch_data, batch_label


def neural_network_model():
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(lstmUnits)

    lstm_cell = tf.contrib.rnn.DropoutWrapper(cell=lstm_cell, output_keep_prob=0.75)
    value, _ = tf.nn.dynamic_rnn(lstm_cell, data, dtype=tf.float32)

    weight = tf.Variable(tf.truncated_normal([lstmUnits, numClasses]))
    bias = tf.Variable(tf.constant(0.1, shape=[numClasses]))
    value = tf.transpose(value, [1, 0, 2])
    last = tf.gather(value, int(value.get_shape()[0]) - 1)
    prediction = (tf.matmul(last, weight) + bias)

    correct_prediction = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    prediction_values = tf.argmax(prediction, 1)

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=labels))
    optimizer = tf.train.AdamOptimizer().minimize(loss)

    return loss, accuracy, prediction_values, optimizer


def train_neural_network(loss, accuracy, optimizer, train_data, train_labels):
    sess = tf.InteractiveSession()
    saver = tf.train.Saver()
    sess.run(tf.global_variables_initializer())

    tf.summary.scalar('Loss', loss)
    tf.summary.scalar('Accuracy', accuracy)
    merged = tf.summary.merge_all()
    logdir = "tensorboard/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
    writer = tf.summary.FileWriter(logdir, sess.graph)

    for i in range(iterations):
        #Next Batch of reviews
        next_batch, next_batch_labels = get_batch(batchSize, train_data, train_labels)
        sess.run(optimizer, {data: next_batch, labels: next_batch_labels})

        #Write summary to Tensorboard
        if (i % 499 == 0):
            summary = sess.run(merged, {data: next_batch, labels: next_batch_labels})
            writer.add_summary(summary, i)

        #Save the network every 10,000 training iterations
        if (i % 499 == 0 and i != 0):
            save_path = saver.save(sess, "/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt", global_step=i)
            print("saved to %s" % save_path)
    writer.close()


def measure_neural_network(accuracy, prediction_values, test_data, test_labels):
    sess = tf.InteractiveSession()
    saver = tf.train.Saver()
    saver.restore(sess, tf.train.latest_checkpoint('/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/'))

    overall_accuracy = 0
    all_predictions = []
    test_iterations = 20
    for i in range(test_iterations):
        next_batch, next_batch_labels = get_batch_order(batchSize, test_data, test_labels, i)
        accuracy_this_batch = (sess.run(accuracy, {data: next_batch, labels: next_batch_labels})) * 100
        predictions_this_batch = sess.run(prediction_values, {data: next_batch, labels: next_batch_labels})
        overall_accuracy = overall_accuracy + accuracy_this_batch
        all_predictions = all_predictions + predictions_this_batch.tolist()
        print("Accuracy for this batch:", accuracy_this_batch)

    true_labels = tf.argmax(test_labels, 1).eval()
    precision = precision_score(true_labels.tolist()[0:batchSize * test_iterations], all_predictions)
    f1 = f1_score(true_labels.tolist()[0:batchSize * test_iterations], all_predictions)
    recall = recall_score(true_labels.tolist()[0:batchSize * test_iterations], all_predictions)
    overall_accuracy = overall_accuracy / (test_iterations * 100)
    print(confusion_matrix(true_labels.tolist()[0:batchSize * test_iterations], all_predictions).ravel())

    all_test = true_labels.tolist()[0:batchSize * test_iterations]
    return overall_accuracy, precision, recall, f1, all_predictions, all_test


def run_cross_val():
    all_predictions = []
    all_used_test_labels = []
    # w2v_model_path = "../../../corpus/analyzed/saved_models/"
    comments = pd.read_csv("/content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/corpus/analyzed/comments_tagged_remove_all_punc_keep_question.csv", ";")
    pretty_table = PrettyTable(["Algorithm", "Accuracy", "Precision", "Recall", "F1_Score"])

    # convert_to_vectors()
    data_vectors, data_labels = load_vectors()

    print("Running tesnsorflow simulation.....")


    i = 1
    kf = KFold(n_splits=10)
    kf.get_n_splits(comments)
    for train_index, test_index in kf.split(data_vectors):
        train_data_comments, test_data_comments = data_vectors[train_index], data_vectors[test_index]
        train_data_labels, test_data_labels = data_labels[train_index], data_labels[test_index]


        tf.reset_default_graph()

        global labels
        global data
        labels = tf.placeholder(tf.int32, [batchSize, numClasses])
        data = tf.placeholder(tf.float32, [batchSize, max_sentence_length, num_features])

        loss, accuracy, prediction_values, optimizer = neural_network_model()
        train_neural_network(loss, accuracy, optimizer, train_data_comments, train_data_labels)
        accuracy, precision, recall, f1, predictions, used_test_labels = measure_neural_network(accuracy, prediction_values, test_data_comments, test_data_labels)

        all_predictions = all_predictions + predictions
        all_used_test_labels = all_used_test_labels + used_test_labels

        i = i + 1
        evaluation_metrics(used_test_labels, predictions, pretty_table, "iteration" + str(i))

    evaluation_metrics(all_used_test_labels, all_predictions, pretty_table, "final")
    print(pretty_table)
    print_confusion_matrix(all_used_test_labels, all_predictions)



def fit_models(vectorizer, train_data_comments, test_data_comments, train_data_labels, test_data_labels):
    pretty_table = PrettyTable(["Algorithm", "Accuracy", "Precision", "Recall", "F1_Score"])

    vectorized_train_comments = vectorizer.fit_transform(train_data_comments)
    vectorized_test_comments = vectorizer.transform(test_data_comments)

    model = SVC(C=1, kernel='linear')
    model = model.fit(vectorized_train_comments, train_data_labels)
    predictions = model.predict(vectorized_test_comments)
    evaluation_metrics(test_data_labels, predictions, pretty_table, "SVM")
    print_confusion_matrix(test_data_labels, predictions)

    print(pretty_table)
    print("")
    return predictions


def evaluation_metrics(true_sentiment, predicted_sentiment, pretty_table, algorithm):
    label_binarizer = preprocessing.LabelBinarizer()
    label_binarizer.fit(['NEGATIVE', 'POSITIVE'])
    test_labels = label_binarizer.transform(true_sentiment)
    predict_labels = label_binarizer.transform(predicted_sentiment)
    accuracy_str = str(accuracy_score(true_sentiment, predicted_sentiment))
    precision_str = str(precision_score(true_sentiment, predicted_sentiment))
    recall_str = str(recall_score(true_sentiment, predicted_sentiment))
    f1_score_str = str(f1_score(true_sentiment, predicted_sentiment))
    pretty_table.add_row([algorithm, accuracy_str, precision_str, recall_str, f1_score_str])
    return


def print_confusion_matrix(label, prediction):
    cf_matrix = confusion_matrix(label, prediction)
    print(cf_matrix.ravel())
    print(cf_matrix)

# %%
convert_to_vectors()
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# word not in word2vec model: කොළෙන්
# word not in word2vec model: පින්වැඩි
# word not in word2vec model: වරදටනම්
# word not in word2vec model: ිනයම
# word not in word2vec model: කෙනෙන්ක්ටම
# word not in word2vec model: එකකකට
# word not in word2vec model: මොරදෙන්නන්ට
# word not in word2vec model: හාඟන්නු
# word not in word2vec model: හිඟන්නගෙන්
# word not in word2vec model: හිඟාකෑමත්
# word not in word2vec model: හිගන්නොනේ
# word not in word2vec model: අනුග්‍රහයවත්
# word not in word2vec model: එකමුතුකමෙන්වත්
# word not in word2vec model: නොසැළිකිලිමත්කමේ
# word not in word2vec model: රියැදුරාගේ
# word not in word2vec model: දෙමවුපියොද?
# word not in word2vec model: නොදැනුනානම්
# word not in word2vec model: නරුනත්
# word not in word2vec model: සරදියෙල්වත්
# word not in word2vec model: සමරනවානම්
# word not in word2vec model: කෑවගේ
# word not in word2vec model: ඉ්සසරහට
# word not in word2vec model: සරදියෙල්ල
# word not in word2vec model: කුනුවෙන්න
# word not in word2vec model: අරිනවද?
# word not in word2vec model: අසීරුතාවයකින්ද
# word not in word2vec model: අපරාදෙයක්ද
# word not in word2vec model: විසිකෙරුවට
# word not in word2vec model: අමාත්‍යංශයකුයි
# word not in word2vec model: සත්කාරයකට
# word not in word2vec model: නොතකුවේය
# word not in word2vec model: සෙලු
# word not in word2vec model: බැබලෙව්වා
# word not in word2vec model: සහභාගීවෙන්න
# word not in word2vec model: තවට්
# word not in word2vec model: දධර්ය
# word not in word2vec model: මේඔබ
# word not in word2vec model: සහභාගීවෙන්න
# word not in word2vec model: සහභාගීවෙන්න
# word not in word2vec model: මෙවනිපින්කම්
# word not in word2vec model: වේදීයාට
# word not in word2vec model: රාජයාගේ
# word not in word2vec model: ගේනන්ත්
# word not in word2vec model: ගාමිනි
# word not in word2vec model: චින්දන
# word not in word2vec model: කණ්ඩ
# word not in word2vec model: තියෙන්නේ?ආශ්චර්යය
# word not in word2vec model: බෙහොම
# word not in word2vec model: දිටිට
# word not in word2vec model: කොටකෙතනෙ
# word not in word2vec model: පාපකර්මයන්
# word not in word2vec model: ආශ්චර්යටයි
# word not in word2vec model: තාත්තා‍
# word not in word2vec model: සිංහපිටිය
# word not in word2vec model: දනකුවේරයන්ගේ
# word not in word2vec model: වර්දන
# word not in word2vec model: ගන්නේකත්
# word not in word2vec model: බල්ලන්වත්
# word not in word2vec model: ඉස්කොලෝ
# word not in word2vec model: වැකියකින්
# word not in word2vec model: මිනිසූන්
# word not in word2vec model: තූල
# word not in word2vec model: ගතිපැවතූම්
# word not in word2vec model: විදහාපාම්න්
# word not in word2vec model: අනූකම්පාව
# word not in word2vec model: තිරිසනූන්
# word not in word2vec model: සත්තූ
# word not in word2vec model: මනූෂ්‍යයට
# word not in word2vec model: කිරයි
# word not in word2vec model: අයුක්තියක්
# word not in word2vec model: බල්ලෝද?
# word not in word2vec model: අරිම
# word not in word2vec model: ඩොබමන්
# word not in word2vec model: යුතුයිද?
# word not in word2vec model: විඩිය
# word not in word2vec model: ඩෝග්වත්
# word not in word2vec model: දැනෙවා
# word not in word2vec model: ගහගන්නවට
# word not in word2vec model: කරකුත්
# word not in word2vec model: නියරවලුත්
# word not in word2vec model: වක්කඩවලුත්
# word not in word2vec model: හාන්නවත්
# word not in word2vec model: කුබුරක
# word not in word2vec model: සද්දන්තයකු
# word not in word2vec model: ‍බෝරිච්චි
# word not in word2vec model: ගෙඩියකත්
# word not in word2vec model: මීටිමට
# word not in word2vec model: ගිනිදේවීය
# word not in word2vec model: මරයිද?ලෝකේ
# word not in word2vec model: සැබෑකරගන්න
# word not in word2vec model: සිරිලකටම
# word not in word2vec model: කෙනෙක්ද?නැත්නම්
# word not in word2vec model: චුලගේ
# word not in word2vec model: එට්චර
# word not in word2vec model: දකුණත්දැන්
# word not in word2vec model: ආස්චාර්යඅ
# word not in word2vec model: තකතීරුවෝද?
# word not in word2vec model: වැඩ්ඩො
# word not in word2vec model: දකුණටනේ
# word not in word2vec model: හිටින්නවත්
# word not in word2vec model: එනකොටනම්
# word not in word2vec model: කාර්ය්‍යාලයකම
# word not in word2vec model: නොකෙරෙයි
# word not in word2vec model: සබාවේම
# word not in word2vec model: කැත්නම්
# word not in word2vec model: මගත්තුරුන්
# word not in word2vec model: ඉවත්කරනවට
# word not in word2vec model: බන්ගලියන්
# word not in word2vec model: මිනිවලක්
# word not in word2vec model: බංගලියන්ට
# word not in word2vec model: මොහොශෙන්
# word not in word2vec model: මහශෙන්
# word not in word2vec model: බංගලිදේසෙට
# word not in word2vec model: අන්ජාතින්
# word not in word2vec model: පෙනිසිටිමින්
# word not in word2vec model: හෙලයෙක්ව
# word not in word2vec model: හෙළයෙක්ම
# word not in word2vec model: තම්බියාගේ
# word not in word2vec model: අදහස්තුලින්
# word not in word2vec model: දෙමටගොඩින්
# word not in word2vec model: ඉස්ටේෂමෙන්
# word not in word2vec model: අපායවත්
# word not in word2vec model: ධර්මදිපයකට
# word not in word2vec model: අපරදයක්නේ
# word not in word2vec model: කොම්පැනියෙන්ම
# word not in word2vec model: සවිකලේ
# word not in word2vec model: ඔස්ට්‍රලියාව
# word not in word2vec model: ක්ලීව්ලෑන්ඞ්
# word not in word2vec model: ක්ලීව්ලෑන්ඞ්
# word not in word2vec model: පැමිනීමත්
# word not in word2vec model: ඉන්ජිනේරුවන්ටත්
# word not in word2vec model: අලසකමත්
# word not in word2vec model: එක්කලා?
# word not in word2vec model: 1903
# word not in word2vec model: 1908
# word not in word2vec model: නැග්මක්
# word not in word2vec model: බෙරගහනවා
# word not in word2vec model: වෛද්‍යවරියන්
# word not in word2vec model: ඇටෙන්ඩන්ට්ලා
# word not in word2vec model: ආතුරයන්ව
# word not in word2vec model: ඔයවිදිහටම
# word not in word2vec model: හැදින්විමට
# word not in word2vec model: ආයුරක්ඛන්තු
# word not in word2vec model: මුස්ලිම්ලාගේලු
# word not in word2vec model: ඉන්ග්රීසින්ගේලු
# word not in word2vec model: බෙරගහනවා
# word not in word2vec model: සදසේ
# word not in word2vec model: මොල්යෙත්
# word not in word2vec model: සාපෙක්ෂවද?
# word not in word2vec model: ගමනාන්තයේ
# word not in word2vec model: ජම්පින්
# word not in word2vec model: ඔඩොක්කුවෙත්
# word not in word2vec model: කතාකරොත්
# word not in word2vec model: නානුඔයේ
# word not in word2vec model: ආඩ්මබරයි
# word not in word2vec model: වෙහෙසත්
# word not in word2vec model: තැම්බෙන්නෙ
# word not in word2vec model: viruwanene
# word not in word2vec model: where
# word not in word2vec model: ever
# word not in word2vec model: going
# word not in word2vec model: bless
# word not in word2vec model: worry
# word not in word2vec model: හිනදලු
# word not in word2vec model: නහින්නෙං
# word not in word2vec model: දිට්ඨධම්මවේදනීය
# word not in word2vec model: ඡ
# word not in word2vec model: ඡා
# word not in word2vec model: රඡසැප
# word not in word2vec model: අවාසිවෙන
# word not in word2vec model: චන්ගුමී
# word not in word2vec model: වපරැහින්
# word not in word2vec model: කොරියන්කාරයෝ
# word not in word2vec model: අමාත්යන්සයත්
# word not in word2vec model: කියැං
# word not in word2vec model: නෑම්
# word not in word2vec model: බුර්ජ්
# word not in word2vec model: කලීෆා
# word not in word2vec model: නැගිල්ල
# word not in word2vec model: කොරියං
# word not in word2vec model: watch?v=BH19J8ZF4Bk
# word not in word2vec model: චන්ගුමී
# word not in word2vec model: දුදරුවන්ටයි
# word not in word2vec model: රයිගමයටයි
# word not in word2vec model: ගම්පලයටයි
# word not in word2vec model: පවත්වාගෙනයන
# word not in word2vec model: අධ්‍යයාපන
# word not in word2vec model: පන්දමටනේ
# word not in word2vec model: හිරෙය්
# word not in word2vec model: නගරසභාවට
# word not in word2vec model: සියයම
# word not in word2vec model: හ‍රී
# word not in word2vec model: ?කොහේ
# word not in word2vec model: වරදක්ලු
# word not in word2vec model: කස්ස්පු
# word not in word2vec model: ඉස්කෝලෙයි
# word not in word2vec model: පන්තීයි
# word not in word2vec model: බන්දගෙන්
# word not in word2vec model: සුරකමට
# word not in word2vec model: සමජයවත්
# word not in word2vec model: නැගුමේ
# word not in word2vec model: හම්බුකරපු
# word not in word2vec model: චයිත්‍ය
# word not in word2vec model: ගෙවන්නබෑ
# word not in word2vec model: නැගුමේ
# word not in word2vec model: වහගමු
# word not in word2vec model: මේවබොරු
# word not in word2vec model: නීතිවත්
# word not in word2vec model: ම්න්ස්සු
# word not in word2vec model: දෙන්නවයි
# word not in word2vec model: ධර්මසිරිවයි
# word not in word2vec model: අත්දෙකට
# word not in word2vec model: බුවල්ලෙක්
# word not in word2vec model: වාහක
# word not in word2vec model: ලේන්ස්
# word not in word2vec model: ලේන්ස්
# word not in word2vec model: ඇතුල්වෙද්දිත්
# word not in word2vec model: පිටවෙද්දිත්
# word not in word2vec model: පලල්කරන්න
# word not in word2vec model: ඉගනගෙනද
# word not in word2vec model: නොකෙරුණු
# word not in word2vec model: ප්‍රතිපෝෂක
# word not in word2vec model: අරගොල්ලා
# word not in word2vec model: වගාපාලු
# word not in word2vec model: අර්දර්ශයකි
# word not in word2vec model: සත්තවයින්
# word not in word2vec model: දැකක්ම
# word not in word2vec model: කාමයක
# word not in word2vec model: අසුබයේ
# word not in word2vec model: නොපතන්න
# word not in word2vec model: අපායයි
# word not in word2vec model: අනුපමා
# word not in word2vec model: පොකුණකින්
# word not in word2vec model: වැටේවී
# word not in word2vec model: විසදෙනකල්
# word not in word2vec model: අවශතාවක්
# word not in word2vec model: ඇස්දෙකින්
# word not in word2vec model: නපුංසකයන්ටනේ
# word not in word2vec model: කලයුත්තක්
# word not in word2vec model: සටනක්ම
# word not in word2vec model: තීරණාත්
# word not in word2vec model: ජනප්‍රියත්වයත්
# word not in word2vec model: අවස්තාවාදේ
# word not in word2vec model: වැලැක්වුවානම්
# word not in word2vec model: අත්හිටුවිමක්වත්
# word not in word2vec model: නිරිදේශ
# word not in word2vec model: ගෙහිමි
# word not in word2vec model: කියාන්න
# word not in word2vec model: උන්ලග
# word not in word2vec model: කෙරැවාව
# word not in word2vec model: බෝඩින්කාරයට
# word not in word2vec model: පුරුෂවාදී
# word not in word2vec model: සැපවිදිමින්
# word not in word2vec model: වීර්යයකින්
# word not in word2vec model: භික්ෂූවක්
# word not in word2vec model: මෙහෙණියක්
# word not in word2vec model: ශීලයකින්
# word not in word2vec model: පිටකයෙන්
# word not in word2vec model: පෙන්නවාද?
# word not in word2vec model: සම්මාසම්බුද
# word not in word2vec model: ඛණ්ඩයකි
# word not in word2vec model: සිද්ධීන්ගේ
# word not in word2vec model: රසවත්භාවය
# word not in word2vec model: එදෙසට
# word not in word2vec model: යොමුවීමෙන්
# word not in word2vec model: නිසැකම
# word not in word2vec model: වාහනේත්
# word not in word2vec model: හයිවේ????
# word not in word2vec model: අත්දැකිමක්නේ
# word not in word2vec model: උණම
# word not in word2vec model: උත්සාහවන්තයෙක්
# word not in word2vec model: ප්‍රඤව
# word not in word2vec model: සැපදුක
# word not in word2vec model: ලජ්ජාවකට
# word not in word2vec model: වලටැත්
# word not in word2vec model: ගොල්ලන්ගේම
# word not in word2vec model: මල්වර
# word not in word2vec model: අවමන්ගල්ලය
# word not in word2vec model: සෙන්පෙතියෙක්
# word not in word2vec model: රත්නයක
# word not in word2vec model: සෙන්පෙතියෙක්
# word not in word2vec model: උරෙනුර
# word not in word2vec model: සෙන්පතියන්ට
# word not in word2vec model: ඉස්මෛල්
# word not in word2vec model: සෙනාධිපති
# word not in word2vec model: අශීර්වාධ
# word not in word2vec model: අශීර්වාධ
# word not in word2vec model: එකළස්
# word not in word2vec model: පිඉමියෙකුට
# word not in word2vec model: නීසි
# word not in word2vec model: කොමසාරිය
# word not in word2vec model: පස්සුව
# word not in word2vec model: ගහනවනම්
# word not in word2vec model: ලොරියකයි
# word not in word2vec model: සව්කොල
# word not in word2vec model: ඕවිටේ
# word not in word2vec model: අතීතයක්ද
# word not in word2vec model: අගෝස්තුම
# word not in word2vec model: සරුන්ගල්
# word not in word2vec model: තාත්තාවයි
# word not in word2vec model: බඩජාරින්
# word not in word2vec model: අපූරුතම
# word not in word2vec model: සරුන්ගල්ද
# word not in word2vec model: හඬදී
# word not in word2vec model: සැන්දැවේ
# word not in word2vec model: කොම්බු
# word not in word2vec model: විසුරවන්නේ
# word not in word2vec model: බෝදිපුජා
# word not in word2vec model: කැම්ප්
# word not in word2vec model: ඔ5ක්
# word not in word2vec model: විසුරවන්නේ
# word not in word2vec model: කැතවුණා
# word not in word2vec model: පොට්ටයෙකුට
# word not in word2vec model: රුසෙල්
# word not in word2vec model: රුසෙල්ටයි
# word not in word2vec model: රෙමාටයි
# word not in word2vec model: ශාපයට
# word not in word2vec model: අතිතේ
# word not in word2vec model: කරන්නෙ?ඉස්මෛල්
# word not in word2vec model: ඊර්ශියාව‍
# word not in word2vec model: විසඳනවට
# word not in word2vec model: 5$
# word not in word2vec model: විසදගන්නම්
# word not in word2vec model: අමාත්‍යාංශයටත්
# word not in word2vec model: තිබෙනවාටත්
# word not in word2vec model: හොදාආආආයි
# word not in word2vec model: නිනි
# word not in word2vec model: වැඳි
# word not in word2vec model: තාවේ
# word not in word2vec model: ලැබුවාවේ
# word not in word2vec model: දිවියෙ
# word not in word2vec model: ඔබතව
# word not in word2vec model: වැළදුවා
# word not in word2vec model: බුදුනුත්
# word not in word2vec model: සමිදුනුත්
# word not in word2vec model: දෙවිරකවරණ
# word not in word2vec model: වරුනෙට
# word not in word2vec model: නොසිඳී
# word not in word2vec model: මුන්දැට
# word not in word2vec model: 73ය්
# word not in word2vec model: උක්කුඅම්මටයි
# word not in word2vec model: අම්මලාටයි
# word not in word2vec model: එත්තේ
# word not in word2vec model: ගැටබරුව
# word not in word2vec model: දෙවොල
# word not in word2vec model: ගැටබරුව
# word not in word2vec model: දෙවොල
# word not in word2vec model: දැකිමෙන්ම
# word not in word2vec model: හැමදනාටම
# word not in word2vec model: ගැටබරුව
# word not in word2vec model: අධ්‍යාත්මයට
# word not in word2vec model: ගැටබුරුව
# word not in word2vec model: ගැටබරුව
# word not in word2vec model: ආදර‍ෙයන්
# word not in word2vec model: කරන්න්‍ෙ‍
# word not in word2vec model: නයිපිල්ලේ
# word not in word2vec model: විකුනවා
# word not in word2vec model: ගොවිය
# word not in word2vec model: අඩන්නම
# word not in word2vec model: කිරිඑරෙන්න
# word not in word2vec model: හැටහුටමාරක්
# word not in word2vec model: අව්වටයි
# word not in word2vec model: ගොවියෙක්ගෙ
# word not in word2vec model: පාලකයන්?
# word not in word2vec model: ව්කුන
# word not in word2vec model: පින්සිඳු
# word not in word2vec model: කඩවන්නද?
# word not in word2vec model: විරෝධයකින්
# word not in word2vec model: ඥානාන්විතව
# word not in word2vec model: විදිකහකට
# word not in word2vec model: පාංශුකූල
# word not in word2vec model: ව්‍යවසනය
# word not in word2vec model: ‍වියයුතුයි
# word not in word2vec model: මුතුඇටයට
# word not in word2vec model: ක‍රනවා
# word not in word2vec model: ඉනාඩ්
# word not in word2vec model: ආලයිකුම්
# word not in word2vec model: අහිංහක
# word not in word2vec model: සමාදානයත්
# word not in word2vec model: දවසලු
# word not in word2vec model: අයියා“
# word not in word2vec model: සහෝදරියකටම
# word not in word2vec model: සහෝදරියකටම
# word not in word2vec model: ජෝන්ටත්
# word not in word2vec model: බෞද්දයක්
# word not in word2vec model: මුස්ලෙම්
# word not in word2vec model: පුදදුන්
# word not in word2vec model: පැදීමට
# word not in word2vec model: වවුනියාවදී
# word not in word2vec model: අමාත්‍යවරයකු
# word not in word2vec model: බුද්ධිමත්කමෙත්
# word not in word2vec model: නිහතමානීකමෙත්
# word not in word2vec model: දේශපලඥයකුගේත්
# word not in word2vec model: ‍නිජ
# word not in word2vec model: මහමැතිතුමනි
# word not in word2vec model: දසවද
# word not in word2vec model: යන්නැද්ද??
# word not in word2vec model: දකින්නැහැ
# word not in word2vec model: නමයක්ම
# word not in word2vec model: එකෙක්ගෙ
# word not in word2vec model: කාංචනගෙ
# word not in word2vec model: මිනෝලී
# word not in word2vec model: ඊර්ෂ්‍යාවක්නෙ
# word not in word2vec model: ආවඩාන්ට
# word not in word2vec model: දේසක්කාරයින්ට
# word not in word2vec model: කියෙඩ්
# word not in word2vec model: අපායේම
# word not in word2vec model: වගාකිරීමක්
# word not in word2vec model: වගකිවයුත්තනේ
# word not in word2vec model: තැන්නේද
# word not in word2vec model: ෆාර්
# word not in word2vec model: ෆාර්
# word not in word2vec model: ගිනිතබන
# word not in word2vec model: ලලනාවියක්
# word not in word2vec model: නෙළු
# word not in word2vec model: ලස්සනද??
# word not in word2vec model: ෆාර්
# word not in word2vec model: ෆාර්
# word not in word2vec model: තියගන්නවත්
# word not in word2vec model: වහසන්සේලා
# word not in word2vec model: පැහයෙන්
# word not in word2vec model: නෙළු
# word not in word2vec model: මෑණීයන්
# word not in word2vec model: පිබ්දීලා
# word not in word2vec model: නමදී
# word not in word2vec model: නුවරඑළියට?
# word not in word2vec model: සමානකරන්න
# word not in word2vec model: සමානකරන්න
# word not in word2vec model: කිව්වවගේ
# word not in word2vec model: වඳුරාගේ
# word not in word2vec model: ලේබුනවගේ
# word not in word2vec model: මල්මාලය
# word not in word2vec model: කැතයිනේ
# word not in word2vec model: වඳුරාගේ
# word not in word2vec model: බලාගාරයක
# word not in word2vec model: රූපවතීලව
# word not in word2vec model: වැදිරියෝ
# word not in word2vec model: ටියුටරියත්
# word not in word2vec model: උගන්නන්නේ?
# word not in word2vec model: ලිව්වානම්
# word not in word2vec model: වියේදිත්
# word not in word2vec model: කව්රුන්ද?
# word not in word2vec model: ඛෙදවාචකයේ
# word not in word2vec model: මව්පියන්ද
# word not in word2vec model: සමනොල
# word not in word2vec model: රැකවරණයයි
# word not in word2vec model: නාදෙන්
# word not in word2vec model: තලයම
# word not in word2vec model: රැකෙත්වා
# word not in word2vec model: සමනොල
# word not in word2vec model: රිදවන්
# word not in word2vec model: ප්ලේන්ටියක්වත්
# word not in word2vec model: දන්වාවි
# word not in word2vec model: නිවනටම
# word not in word2vec model: සිත්තරෙකුගේ
# word not in word2vec model: උලුවස්සේත්
# word not in word2vec model: හටගත්තලු
# word not in word2vec model: වාසානාවට
# word not in word2vec model: තුරුල්ලේම
# word not in word2vec model: ගොවිතැටම
# word not in word2vec model: ගානින්ම
# word not in word2vec model: ඒසැන
# word not in word2vec model: වැඩිකෙර්
# word not in word2vec model: මධ‍යම
# word not in word2vec model: ක්‍රියත්මකවේ
# word not in word2vec model: යෙහෙලියන්ටත්
# word not in word2vec model: අතිරේවා
# word not in word2vec model: මිණුම
# word not in word2vec model: දල්වන්නා
# word not in word2vec model: ප්‍රදීපස්ථම්භයක්
# word not in word2vec model: පවතිනාතාක්
# word not in word2vec model: කරම්හ
# word not in word2vec model: උසුලනා
# word not in word2vec model: අහයපත්
# word not in word2vec model: මවුන්ටත්
# word not in word2vec model: සෙතම
# word not in word2vec model: ලක්මෑණිගෙ
# word not in word2vec model: කප්රුකෙ
# word not in word2vec model: පුදුමක්
# word not in word2vec model: බැරිවෙලාද?
# word not in word2vec model: වැරද්දනේ
# word not in word2vec model: ගේටි
# word not in word2vec model: තිබුනානමි
# word not in word2vec model: ලංකාව​
# word not in word2vec model: කමින්නේ
# word not in word2vec model: වැරද්දනේ
# word not in word2vec model: මෙහෙයකට
# word not in word2vec model: නිකායකම
# word not in word2vec model: දහිරියම
# word not in word2vec model: නිකායකටම
# word not in word2vec model: තුමාර
# word not in word2vec model: පිළිබිබු
# word not in word2vec model: නායකයෙක්ද?
# word not in word2vec model: දේවස්ථානයක්
# word not in word2vec model: දේවස්ථානයක්
# word not in word2vec model: දෙවස්තානයද
# word not in word2vec model: ප්‍රශංස
# word not in word2vec model: අසාධාරණයිනේ
# word not in word2vec model: වැරැදිකාරී
# word not in word2vec model: රත්තන්
# word not in word2vec model: කපටියිනේ
# word not in word2vec model: නැනාත්
# word not in word2vec model: උනපුර්ණය
# word not in word2vec model: නිර්මංසා
# word not in word2vec model: තීරකයා
# word not in word2vec model: පටකයාගේ
# word not in word2vec model: පුබුදුසිරි
# word not in word2vec model: පත්වූයේ
# word not in word2vec model: හේතුවෙනුයි
# word not in word2vec model: මේන්ම
# word not in word2vec model: මාංශද
# word not in word2vec model: හතකොට
# word not in word2vec model: කිකිලියන්
# word not in word2vec model: සන්වේදිතාවයක්
# word not in word2vec model: සූක්ශම
# word not in word2vec model: හරවන්න​
# word not in word2vec model: හින්සාවාදී
# word not in word2vec model: අදහස්​
# word not in word2vec model: ඉසමුදුනින්
# word not in word2vec model: ලිසියම්
# word not in word2vec model: අධාපනයයි
# word not in word2vec model: දිසාවකටයි
# word not in word2vec model: ජාත්‍යනතර
# word not in word2vec model: අරුණත්
# word not in word2vec model: වහෙන්නේ
# word not in word2vec model: ගත්‍රිකයෙක්නේ
# word not in word2vec model: බොරුනොද
# word not in word2vec model: සුරල
# word not in word2vec model: දුම්රියපලවල්
# word not in word2vec model: අලුත්කරලා
# word not in word2vec model: බෝදයක්
# word not in word2vec model: ජිණුවා
# word not in word2vec model: වාසිගන්නවා
# word not in word2vec model: ඔයතරමටම
# word not in word2vec model: මංකොල
# word not in word2vec model: දුසක්යෝ
# word not in word2vec model: දෙසපලනයක්
# word not in word2vec model: මහගත්තේ
# word not in word2vec model: විජ්ත්
# word not in word2vec model: විජ්ත්
# word not in word2vec model: ගැව්නත්
# word not in word2vec model: සද්දෙන්න්ද
# word not in word2vec model: පරකුවෙලා
# word not in word2vec model: අස්තාවරයි
# word not in word2vec model: ඇසෙල
# word not in word2vec model: ඇසලගෙ
# word not in word2vec model: මනුෂයනි
# word not in word2vec model: රතිඤ්ඤ
# word not in word2vec model: සන්තෝෂයටනේ
# word not in word2vec model: චන්දීගේ
# word not in word2vec model: අනුපමය
# word not in word2vec model: අනුපමය
# word not in word2vec model: නිලයන්ටත්
# word not in word2vec model: විරුවාණනි…ඔබට
# word not in word2vec model: බටත්
# word not in word2vec model: දීපයටත්
# word not in word2vec model: අපෙහිතට
# word not in word2vec model: 99%කටම
# word not in word2vec model: උද්ඝෝණයක්
# word not in word2vec model: සුභපතා
# word not in word2vec model: සරීරයට
# word not in word2vec model: බිඳා
# word not in word2vec model: මූණම
# word not in word2vec model: නශාර්
# word not in word2vec model: මිදීමටද
# word not in word2vec model: ආර්ථින
# word not in word2vec model: ඉතිරිකරගැනීමටද
# word not in word2vec model: කරදරවලින්
# word not in word2vec model: මිදීමටද
# word not in word2vec model: මතුරුවන්
# word not in word2vec model: ජේස්සුස්
# word not in word2vec model: අගාම්
# word not in word2vec model: අපයේදී
# word not in word2vec model: අකෘතඥතාවයට
# word not in word2vec model: අනථ
# word not in word2vec model: සලකන්නැත්නම්
# word not in word2vec model: හදාගත්තම
# word not in word2vec model: රවට්ටවා
# word not in word2vec model: පාළුවකට
# word not in word2vec model: පෙරලුනි
# word not in word2vec model: බිරින්දද
# word not in word2vec model: මෙවෙලාවේදී
# word not in word2vec model: බැබ‍ෙල්වා
# word not in word2vec model: වහනසේට
# word not in word2vec model: උසටත්
# word not in word2vec model: වැඩ්වේවා
# word not in word2vec model: උසටත්
# word not in word2vec model: වැඩ්වේවා
# word not in word2vec model: සමිබුදු
# word not in word2vec model: බැබළීමට
# word not in word2vec model: සියලළු
# word not in word2vec model: චතූරාසත්‍ය
# word not in word2vec model: හයපතක්
# word not in word2vec model: සියුල
# word not in word2vec model: බ‌‌ඹුන්
# word not in word2vec model: පස්මල්
# word not in word2vec model: මුතුන්මිතන්
# word not in word2vec model: ගියමග
# word not in word2vec model: සම්බන්ධවුණු
# word not in word2vec model: වැඩිවන්න
# word not in word2vec model: වැඩිවන්න
# word not in word2vec model: වැඩිවන්න
# word not in word2vec model: වැඩිවන්න
# word not in word2vec model: මඩියත්
# word not in word2vec model: සංතෝසයි
# word not in word2vec model: වෙලවල්
# word not in word2vec model: සකසලයි
# word not in word2vec model: වෙලුත්
# word not in word2vec model: ???පාරවල්
# word not in word2vec model: වෙලවල්
# word not in word2vec model: වගුරුබිම
# word not in word2vec model: ජිවීන්ගේ
# word not in word2vec model: ටාසන්ලාගෙ
# word not in word2vec model: අග්න
# word not in word2vec model: 3Km
# word not in word2vec model: දැනෙන්ව
# word not in word2vec model: 21යි
# word not in word2vec model: ඉදිරියගැන
# word not in word2vec model: අයලංකාවේ
# word not in word2vec model: කෙල්ලංව
# word not in word2vec model: දැනගත්ත්යි
# word not in word2vec model: කරන්න්ද?
# word not in word2vec model: මිටෙලු
# word not in word2vec model: අපුරුයිනේ
# word not in word2vec model: වෙනරටකින්
# word not in word2vec model: එලවූ
# word not in word2vec model: සාමාකාමී
# word not in word2vec model: ශිෂ්‍යාට
# word not in word2vec model: සන්වේදිතාවයක්
# word not in word2vec model: පෙළපාලී
# word not in word2vec model: ඕගොල්ලන්ගෙ
# word not in word2vec model: කසියා
# word not in word2vec model: මරෙනකල්ම
# word not in word2vec model: හැරෙනවනේ
# word not in word2vec model: මැතියන්
# word not in word2vec model: විලිසන්ගෙ
# word not in word2vec model: සුන්දරියෝනේ
# word not in word2vec model: නෝදකින්
# word not in word2vec model: ලමිස්සියොත්
# word not in word2vec model: සගිස්කුතිය
# word not in word2vec model: ගැහැණුන්ගේ‍
# word not in word2vec model: ලස්‍සන
# word not in word2vec model: අැස්‍
# word not in word2vec model: දෙකෙන්‍
# word not in word2vec model: වෙන්‍න
# word not in word2vec model: මිනිස්‍සු
# word not in word2vec model: තෙල්‍
# word not in word2vec model: ගැවුනු
# word not in word2vec model: වගේ‍
# word not in word2vec model: ගොල්‍ලන්‍ට
# word not in word2vec model: කියන්‍න
# word not in word2vec model: අප්‍සරාවන්‍ටත්‍
# word not in word2vec model: වන්‍න
# word not in word2vec model: පරදින්නෙත්
# word not in word2vec model: මහත්මයගෙ
# word not in word2vec model: T20
# word not in word2vec model: ක්‍රිඩකයින්ගේ
# word not in word2vec model: කොච්ච‍ර
# word not in word2vec model: කොච්ච‍ර
# word not in word2vec model: T20
# word not in word2vec model: කොල්ලන්ගෙන
# word not in word2vec model: චැඩක්
# word not in word2vec model: චේචා
# word not in word2vec model: ක‍ොල්ලන්ග‍ේ
# word not in word2vec model: ආඩම්බරයකට
# word not in word2vec model: අාඩම්බරයකුත්
# word not in word2vec model: අාශාවකුත්
# word not in word2vec model: චන්දිමල්
# word not in word2vec model: කැපවිමත්
# word not in word2vec model: අත්බවෙන්
# word not in word2vec model: අත්ම
# word not in word2vec model: පුංචිකාලෙ
# word not in word2vec model: යෙහෙළියක
# word not in word2vec model: පිංකර
# word not in word2vec model: රැජිණියේ
# word not in word2vec model: දරලත්
# word not in word2vec model: ඇළුමිනියම්
# word not in word2vec model: උයන්ඩවත්
# word not in word2vec model: තරඟයක්වත්
# word not in word2vec model: නැගලලු
# word not in word2vec model: නැගිල්ලෙ
# word not in word2vec model: අනුකම්පාවෙන්වත්
# word not in word2vec model: ලිපත්
# word not in word2vec model: වළනුත්
# word not in word2vec model: මදිත්
# word not in word2vec model: ටෙනියම්
# word not in word2vec model: අලුමීනියම්
# word not in word2vec model: නොවැටහුණ
# word not in word2vec model: නොඉල්ලුවට
# word not in word2vec model: සමයර
# word not in word2vec model: පිටුපසත්
# word not in word2vec model: ලක්ෂ්මී
# word not in word2vec model: ශ්‍රද්ධාවලු
# word not in word2vec model: නවත
# word not in word2vec model: නරයට
# word not in word2vec model: මැද්දෙම
# word not in word2vec model: මියගියදාට
# word not in word2vec model: ගිරවෙකුට
# word not in word2vec model: මොළවාගෙන
# word not in word2vec model: විසිකළහම
# word not in word2vec model: සීරුවෙ
# word not in word2vec model: හිටවමුද?
# word not in word2vec model: සත්තුට
# word not in word2vec model: පින්කන්
# word not in word2vec model: හෝට
# word not in word2vec model: වැයුවට
# word not in word2vec model: චානි
# word not in word2vec model: තොරනවත්
# word not in word2vec model: තියෙනකතාව
# word not in word2vec model: දෙසියයක්ම
# word not in word2vec model: ලෙවකනවට
# word not in word2vec model: සපත්තුවකින්
# word not in word2vec model: පීනුවත්
# word not in word2vec model: වැහුණත්
# word not in word2vec model: යටහත්භාවය
# word not in word2vec model: වැසියන්ගේත්
# word not in word2vec model: කිරීමේදි
# word not in word2vec model: පුමා
# word not in word2vec model: අධිදාස්
# word not in word2vec model: කලමනාකරුවන්
# word not in word2vec model: ඉන්ජිනෙරුවන්
# word not in word2vec model: අයෙක්ටම
# word not in word2vec model: මිනිබිරියෝ
# word not in word2vec model: අත්තොගේ
# word not in word2vec model: ජෝජ්ජ
# word not in word2vec model: සුද්දීයෝද
# word not in word2vec model: ම්කේ
# word not in word2vec model: ඔපාදුමමයි
# word not in word2vec model: රාවණටත්
# word not in word2vec model: ගොත්රයකින්
# word not in word2vec model: වනචාරිව
# word not in word2vec model: දිවිගෙවූ
# word not in word2vec model: කොටස්වලින්
# word not in word2vec model: සුරකීමක්
# word not in word2vec model: නැසෙනවා
# word not in word2vec model: කාලිං
# word not in word2vec model: හංසිනි
# word not in word2vec model: හිරමනයෙන්ද
# word not in word2vec model: මොල්ගහෙන්ද?
# word not in word2vec model: මෙවී
# word not in word2vec model: හැමදීකදිම
# word not in word2vec model: වර්ගීකරණ
# word not in word2vec model: කුලගෝත්‍ර
# word not in word2vec model: අසාර්තකයින්
# word not in word2vec model: නොකිවත්
# word not in word2vec model: නිබන්දනවල
# word not in word2vec model: හෙසිරෙනවා
# word not in word2vec model: හිඔුටු
# word not in word2vec model: අැටඹ
# word not in word2vec model: ඉදිගහක්
# word not in word2vec model: ඉදුණහම
# word not in word2vec model: දැම්මහමත්
# word not in word2vec model: මුලතිවි
# word not in word2vec model: වාර‍ෙ
# word not in word2vec model: වාරෙත්
# word not in word2vec model: සමුදායකින්
# word not in word2vec model: පිරිගියා
# word not in word2vec model: දුකේදිත්
# word not in word2vec model: සැපේදිත්
# word not in word2vec model: රැදේවී
# word not in word2vec model: ඔබසැමෙට
# word not in word2vec model: T20
# word not in word2vec model: බොක්කටම
# word not in word2vec model: ‍ඕන‍
# word not in word2vec model: හදපතුලෙන්ම
# word not in word2vec model: සැමදත්
# word not in word2vec model: මහපාරත්
# word not in word2vec model: ප්‍රියකුමරගේ
# word not in word2vec model: දෙපෙත්තේ
# word not in word2vec model: පැකර්ලගේ
# word not in word2vec model: ගනිල්ලද
# word not in word2vec model: වැදගතාට
# word not in word2vec model: කියමනයි
# word not in word2vec model: මර්ඩොක්
# word not in word2vec model: නොගෙනාවත්
# word not in word2vec model: අභිය‍ෝග
# word not in word2vec model: අධියෝග
# word not in word2vec model: ධහ
# word not in word2vec model: මඟීන්ටත්
# word not in word2vec model: කැළිකසල
# word not in word2vec model: මන්දගාමීව
# word not in word2vec model: මඟහැරීමක්
# word not in word2vec model: දෙපාර්තමේන්කුව
# word not in word2vec model: කෝච්ච්යේ
# word not in word2vec model: බලධරයනි
# word not in word2vec model: ලක්කරගෙනයි
# word not in word2vec model: දුම්රියකරණය
# word not in word2vec model: සමාජකරණය
# word not in word2vec model: පුහුණුවීමයි
# word not in word2vec model: ප්‍රධානියකු
# word not in word2vec model: අධ්‍යාපනයකුත්
# word not in word2vec model: දුකක්?
# word not in word2vec model: පන්නිපිටියේ
# word not in word2vec model: සතියෙවත්
# word not in word2vec model: ගොව්වගේ
# word not in word2vec model: ගාලූ
# word not in word2vec model: අසියාවෙත්
# word not in word2vec model: දාල‍ා
# word not in word2vec model: හපුගල
# word not in word2vec model: කරතොත්
# word not in word2vec model: ලංකාදීපම
# word not in word2vec model: ගැළවිල්ලක්
# word not in word2vec model: යෞවුන්
# word not in word2vec model: පාළමකට
# word not in word2vec model: ගොනුවෙලා
# word not in word2vec model: වීදියකම
# word not in word2vec model: ලැගුම්හල්
# word not in word2vec model: පෝරණුවකට
# word not in word2vec model: බේරුණානේ
# word not in word2vec model: බෝම්බකාරයෙක්
# word not in word2vec model: බේරුණාට
# word not in word2vec model: බලලගේ
# word not in word2vec model: බල්ලෝ
# word not in word2vec model: රාළටත්
# word not in word2vec model: බල්ලන්ටයි
# word not in word2vec model: පුසන්ටයි
# word not in word2vec model: බේරුණානේ
# word not in word2vec model: බල්ලෝ
# word not in word2vec model: නැවතුම්පොළේ
# word not in word2vec model: තුම්
# word not in word2vec model: දෙජාතියම
# word not in word2vec model: මගමරු
# word not in word2vec model: පොලක්ද
# word not in word2vec model: එ?
# word not in word2vec model: තටාකයකට
# word not in word2vec model: නවතුම්පලත්
# word not in word2vec model: බස්නැව
# word not in word2vec model: තුම්
# word not in word2vec model: සතිපොළ
# word not in word2vec model: තොටුපලවල්වත්
# word not in word2vec model: මාර්ගවත්
# word not in word2vec model: දනටමන්
# word not in word2vec model: බලවතෙක්ට
# word not in word2vec model: වහවී
# word not in word2vec model: ඔෂාන්
# word not in word2vec model: පොන්ඩ්
# word not in word2vec model: පත්වුවන්
# word not in word2vec model: දුවනියන්
# word not in word2vec model: ආත්මවලදීද
# word not in word2vec model: රාජනියෝ
# word not in word2vec model: ගුනවර්දෙන
# word not in word2vec model: පරාමාර්ථයක්
# word not in word2vec model: බෞසරයක්
# word not in word2vec model: පද්මකුමාර
# word not in word2vec model: මනරම්ව
# word not in word2vec model: සහයෝගී
# word not in word2vec model: උස්සවය
# word not in word2vec model: දිදුලනවාට
# word not in word2vec model: විදුසක
# word not in word2vec model: රැජිණියන්
# word not in word2vec model: නොවැටෙමු
# word not in word2vec model: අසංකා
# word not in word2vec model: සංසුන්
# word not in word2vec model: උනේ්?
# word not in word2vec model: ෆෛරූස්
# word not in word2vec model: හම්දුරුවන්ට
# word not in word2vec model: රාජකරිය
# word not in word2vec model: තෝසේ
# word not in word2vec model: වඩය
# word not in word2vec model: වඩයක්නේ
# word not in word2vec model: පඬිවරයන්
# word not in word2vec model: බෙරගෙඩියක්
# word not in word2vec model: සම්බාරුවට
# word not in word2vec model: දුවපනිමින්
# word not in word2vec model: ගැසුණත්
# word not in word2vec model: දෙමවුපිටන්ට
# word not in word2vec model: නො‍තේරෙන්නේ
# word not in word2vec model: මහත්වෙද්දි
# word not in word2vec model: දුවනියි
# word not in word2vec model: මෙයදැයි
# word not in word2vec model: කටෝලුවක්ම
# word not in word2vec model: ඉවසන්නෙත්
# word not in word2vec model: එතුමම
# word not in word2vec model: ලාංකාවේ
# word not in word2vec model: පවරණ
# word not in word2vec model: සුළුජාතික
# word not in word2vec model: කෙනහිලිකර
# word not in word2vec model: ආරක්‍ෂාකරලීමට
# word not in word2vec model: මර්සලීන්
# word not in word2vec model: පියතුමාව
# word not in word2vec model: තැනීයන්
# word not in word2vec model: දැනීයන්
# word not in word2vec model: රෝයිගේ
# word not in word2vec model: සාකච්ඡාවය
# word not in word2vec model: කෙරෙන්නට
# word not in word2vec model: හිංසාවේ
# word not in word2vec model: සහනයකුත්
# word not in word2vec model: ඡයාගේ
# word not in word2vec model: ආගමිකයෙක්ම
# word not in word2vec model: සත්‍යතාවන්
# word not in word2vec model: අවස්ථවාදීන්
# word not in word2vec model: කාළයත්
# word not in word2vec model: සහාජීවනය
# word not in word2vec model: කථාකරති
# word not in word2vec model: බැන්කින්
# word not in word2vec model: දලෙයි
# word not in word2vec model: ලාමලා
# word not in word2vec model: ජසීරාළ
# word not in word2vec model: දිවයිනෙත්
# word not in word2vec model: කන්කරච්චල්
# word not in word2vec model: ධනුෂ්කට
# word not in word2vec model: පේනවනේ
# word not in word2vec model: විකාරවලට
# word not in word2vec model: ශාන්ල
# word not in word2vec model: දගල්ලන්න
# word not in word2vec model: කම්මැළි
# word not in word2vec model: යුතුකමෙන්
# word not in word2vec model: සුසිරි
# word not in word2vec model: ඇසුරි
# word not in word2vec model: ශිෂ්‍යන්ටත්
# word not in word2vec model: ශ්‍රමදානය
# word not in word2vec model: කසම්බිලිය
# word not in word2vec model: ශ්‍රමදානය
# word not in word2vec model: පෙම්වතුන්නේ
# word not in word2vec model: පිරිමින්ටවත්
# word not in word2vec model: සුසන්තිකාට
# word not in word2vec model: අනුරංගට
# word not in word2vec model: ත්‍රිවිදරත්නයේ
# word not in word2vec model: දෙඅතේ
# word not in word2vec model: පදවන්නන්ට
# word not in word2vec model: වීයාප්ත
# word not in word2vec model: මටහරිම
# word not in word2vec model: දුවනෙකට
# word not in word2vec model: සමානකරන්න
# word not in word2vec model: උගස්කර
# word not in word2vec model: මත්පැන්බීගෙන
# word not in word2vec model: අනුරංගගේ
# word not in word2vec model: කඩලත්
# word not in word2vec model: බුලත්විටක්
# word not in word2vec model: විහාරාධිපතීන්
# word not in word2vec model: කිරිකන්න
# word not in word2vec model: පැටලුනදාට
# word not in word2vec model: ෆෛරූස්
# word not in word2vec model: කර්පෙට්
# word not in word2vec model: කේම
# word not in word2vec model: කණුවටම
# word not in word2vec model: නයකත්වය
# word not in word2vec model: නල්ලම්
# word not in word2vec model: නල්ලම්
# word not in word2vec model: සුහදත්වයක්
# word not in word2vec model: බොරයි
# word not in word2vec model: ඒගින්නෙන්
# word not in word2vec model: ඇතුලතිනුත්
# word not in word2vec model: සුහදත්වයක්
# word not in word2vec model: අනනෝන්‍ය
# word not in word2vec model: ඔප්පුකරනවා
# word not in word2vec model: නරුමයට
# word not in word2vec model: බඩේලිය
# word not in word2vec model: දහඩියක්
# word not in word2vec model: නරුමයට
# word not in word2vec model: ඇතිවෙනනේ
# word not in word2vec model: නමුත්‍
# word not in word2vec model: මහන්සියෙන්ද
# word not in word2vec model: නොපවතීවා
# word not in word2vec model: වගකිවයුත්තගෙත්
# word not in word2vec model: ගොවිතැනටයි
# word not in word2vec model: යනබවක්වත්
# word not in word2vec model: ස්‍‍භාවධර්මයත්
# word not in word2vec model: අතිරිකත්ත
# word not in word2vec model: පහදුකම්
# word not in word2vec model: මැදගන
# word not in word2vec model: වදුරෙකි
# word not in word2vec model: වැදිරිය
# word not in word2vec model: පැටවකුගේ
# word not in word2vec model: උසස්වෙන
# word not in word2vec model: නසිනවට
# word not in word2vec model: යෙහෙකැයි
# word not in word2vec model: පන්නන්නත්
# word not in word2vec model: අලිපොත
# word not in word2vec model: හම්බවෙන්නට
# word not in word2vec model: සුදානයක්
# word not in word2vec model: කක්කුස්සියේ
# word not in word2vec model: හාරනවලු
# word not in word2vec model: හිදිලලු
# word not in word2vec model: පත්කරගත්තහම
# word not in word2vec model: කාලකන්න්නියන්ගෙන්
# word not in word2vec model: අවහිරය
# word not in word2vec model: වගකිවයුතෝ
# word not in word2vec model: සාකාච්ච
# word not in word2vec model: වෙකරන
# word not in word2vec model: සතාසීපාවා
# word not in word2vec model: අනුගහය
# word not in word2vec model: නොවිකුණුවොත්
# word not in word2vec model: තියෙනතාක්කල්
# word not in word2vec model: හින්දවල
# word not in word2vec model: නැවතුනද
# word not in word2vec model: සහායකයෝ
# word not in word2vec model: ශෝප්පින්
# word not in word2vec model: අහපවූ
# word not in word2vec model: මරියාව
# word not in word2vec model: අභිමානයෙන්ම
# word not in word2vec model: පරිපාලකයින්
# word not in word2vec model: වටයටවත්
# word not in word2vec model: සුසුන්තිකාට
# word not in word2vec model: පරිසාදන
# word not in word2vec model: 142
# word not in word2vec model: පදකමේ
# word not in word2vec model: බඩගොස්තරවාදී
# word not in word2vec model: ළමයටයි
# word not in word2vec model: ‍හැසිරෙන්නේ?
# word not in word2vec model: මෙවැන්නන්ගෙන්
# word not in word2vec model: මොකටද?දුප්පත්
# word not in word2vec model: සළකනවනේ
# word not in word2vec model: නිර්මලව
# word not in word2vec model: දෘෂ්ටියට
# word not in word2vec model: මෝඩයන්ගේය
# word not in word2vec model: දෝමනස්සයක්
# word not in word2vec model: උමේෂ්ගේ
# word not in word2vec model: පහත්වන
# word not in word2vec model: තැනටලු
# word not in word2vec model: කූඩුවක්ම
# word not in word2vec model: කාර්යාලයේ?
# word not in word2vec model: අතුගානවිටවත්
# word not in word2vec model: ඇනපුදාට
# word not in word2vec model: බඳිනවලුනේ
# word not in word2vec model: කොටීන්ටත්
# word not in word2vec model: ‘ඊශ්‍රායල්’
# word not in word2vec model: ඊශ්‍රායල්‍
# word not in word2vec model: කොයිකාගේ
# word not in word2vec model: ගත්තාටත්
# word not in word2vec model: නිමකරන්නට
# word not in word2vec model: ඊශ්‍රායාලය
# word not in word2vec model: සාර්ථකවේවි
# word not in word2vec model: මෙහෙකාරියෙකුත්
# word not in word2vec model: මීගලාවේ
# word not in word2vec model: දැවද්දයි
# word not in word2vec model: වටාපිටාව
# word not in word2vec model: සුන්දරත්වයත්
# word not in word2vec model: සමණය
# word not in word2vec model: වඩිද්දි
# word not in word2vec model: ඇවිදිලා
# word not in word2vec model: හැටියකි
# word not in word2vec model: යුරෝපීයයන්ට
# word not in word2vec model: කාවද්දන
# word not in word2vec model: මහාභාරත
# word not in word2vec model: මානවකයා
# word not in word2vec model: මහින්දාගමනයට
# word not in word2vec model: අනන්තාවක්
# word not in word2vec model: යක්ෂයන්ටත්
# word not in word2vec model: නාගයන්ටත්
# word not in word2vec model: දඬුමොනරේ
# word not in word2vec model: මුලාශ්‍රයක
# word not in word2vec model: කොරතුරු
# word not in word2vec model: අධ්‍යාන
# word not in word2vec model: අධ්‍යානයටයි
# word not in word2vec model: ධ්‍යානයට
# word not in word2vec model: එයාලද
# word not in word2vec model: හෙවිල්ලලා
# word not in word2vec model: දන්නලා
# word not in word2vec model: වාර්ථාවට
# word not in word2vec model: පාතාලයා
# word not in word2vec model: හෝදල
# word not in word2vec model: අතහොදල
# word not in word2vec model: අතහොදල
# word not in word2vec model: මල්ලවආරච්චි
# word not in word2vec model: උපහාරයෙන්
# word not in word2vec model: දර්ශන්ට
# word not in word2vec model: ප්‍රමාදවුණ
# word not in word2vec model: මල්ලවාරර්චි
# word not in word2vec model: වියෝවූ
# word not in word2vec model: ජනාදර
# word not in word2vec model: ඔසරියයි
# word not in word2vec model: එය?
# word not in word2vec model: විව‍ාහ
# word not in word2vec model: හවස්කාලෙට
# word not in word2vec model: පත්තුවී
# word not in word2vec model: බලනමුත්
# word not in word2vec model: නිවසෙ
# word not in word2vec model: ළදගේ
# word not in word2vec model: කොන්දේසිනේ
# word not in word2vec model: කොන්දේසිකාරියෝ
# word not in word2vec model: මනමාලයින්
# word not in word2vec model: සංස්ථාවකි
# word not in word2vec model: ඇඳුමද
# word not in word2vec model: නොසන්ස‍ෛදේ
# word not in word2vec model: එ්මඩට
# word not in word2vec model: ඉදගෙනත්
# word not in word2vec model: ගොබ්බම
# word not in word2vec model: ගොබ්බ
# word not in word2vec model: ITN
# word not in word2vec model: බලනකෙනෙක්100%
# word not in word2vec model: වළල්ලේ
# word not in word2vec model: ජෙනරාල්ලා
# word not in word2vec model: කීපදෙනාගෙන්
# word not in word2vec model: යුධවිරුවා
# word not in word2vec model: ගාවන
# word not in word2vec model: සිල්යල්ල
# word not in word2vec model: මූර්
# word not in word2vec model: බ්‍රිතාන
# word not in word2vec model: ලංදේසියට
# word not in word2vec model: කලාපයක්?
# word not in word2vec model: ජතියකට
# word not in word2vec model: ආගමක්නේ
# word not in word2vec model: කිණිගම
# word not in word2vec model: බිංගෙවල්වල්
# word not in word2vec model: අතගෑ
# word not in word2vec model: අතගාපු
# word not in word2vec model: බිංගේක
# word not in word2vec model: තාලයටම
# word not in word2vec model: හඳුණන
# word not in word2vec model: මිනිසකුව
# word not in word2vec model: නිවැසියන්ටද
# word not in word2vec model: මිතුරාය
# word not in word2vec model: මිනිස්ගුණය
# word not in word2vec model: නොපිහිටියේ
# word not in word2vec model: දසුණ
# word not in word2vec model: තිරිසන
# word not in word2vec model: කෙලෙහෙගුණ
# word not in word2vec model: හිතුණොත්
# word not in word2vec model: බහිනකොටත්
# word not in word2vec model: 0773
# word not in word2vec model: 951679
# word not in word2vec model: හැඩීමට
# word not in word2vec model: ගෙටගන්න
# word not in word2vec model: චරියාවනම්
# word not in word2vec model: හැරෙනකොට
# word not in word2vec model: නොසිතුව
# word not in word2vec model: උපකම
# word not in word2vec model: අළෙවිකර
# word not in word2vec model: දේශද්‍රෝභීන්
# word not in word2vec model: දෙමාවුපියන්ගෙත්
# word not in word2vec model: පෙළගැසේවා
# word not in word2vec model: නිකම්මත්
# word not in word2vec model: නැතිකරගන්නා
# word not in word2vec model: අනතුරටත්
# word not in word2vec model: බැැරි
# word not in word2vec model: දියං
# word not in word2vec model: දියං
# word not in word2vec model: මරාගත්තෙ
# word not in word2vec model: සෑහිමකට
# word not in word2vec model: සැනසෙන්
# word not in word2vec model: කොපමනද?
# word not in word2vec model: මනුසත්වකුට
# word not in word2vec model: රෝගබාදයන්
# word not in word2vec model: සාදාදෙන්න
# word not in word2vec model: ලක්පුතුට
# word not in word2vec model: දන්නට
# word not in word2vec model: රැදේවි
# word not in word2vec model: ඔබතුමාණන්ට
# word not in word2vec model: සුවෙසත
# word not in word2vec model: දුටුගැමුණුයි
# word not in word2vec model: මහාරජාණන්
# word not in word2vec model: දීර්ගායූෂ
# word not in word2vec model: සැබෙවකි
# word not in word2vec model: සිටුනුයේ
# word not in word2vec model: කරගන්නෙමු
# word not in word2vec model: සඳුත්
# word not in word2vec model: පේරාදෙණියෙත්
# word not in word2vec model: චැනල්වල
# word not in word2vec model: අනවබෝදයෙන්
# word not in word2vec model: අන්ධානුකරණයක්
# word not in word2vec model: වෙන්නෑති
# word not in word2vec model: බලදාරින්ගෙන්
# word not in word2vec model: වළදාන
# word not in word2vec model: මානවවාදියෙක්
# word not in word2vec model: සුගන්ධවත්
# word not in word2vec model: දෙකඩවිය
# word not in word2vec model: විශේෂන්ඥයන්ගේ
# word not in word2vec model: ඈයියා
# word not in word2vec model: හෙලුවැල්ලෙන්නේ
# word not in word2vec model: නග්නයේ
# word not in word2vec model: සදාවාරය
# word not in word2vec model: පිටුපායාමක්ය
# word not in word2vec model: ශිෂ්ටසම්පන්නබව
# word not in word2vec model: වැදත්
# word not in word2vec model: නග්නයේ
# word not in word2vec model: කලාකෘතියක්
# word not in word2vec model: හිතුණුදේමයි
# word not in word2vec model: බුද්ධපුත්‍රයන්
# word not in word2vec model: දිවිදී
# word not in word2vec model: පව්දෙන්න
# word not in word2vec model: කළහරිය
# word not in word2vec model: පුර්ණකාලීන
# word not in word2vec model: ඔබෙල
# word not in word2vec model: පැවැත්මයි
# word not in word2vec model: කෙළෙසෙනවා
# word not in word2vec model: තෑග්ගෙනුත්
# word not in word2vec model: තෑග්ගක
# word not in word2vec model: ප්‍රබෝධයයි
# word not in word2vec model: තේරන්නෙ
# word not in word2vec model: ලෙහෙසියයි
# word not in word2vec model: පහසුවයි
# word not in word2vec model: මිනිසුන්ටවත්
# word not in word2vec model: යානයටත්
# word not in word2vec model: තමන්ගේකමට
# word not in word2vec model: හැපුවනම්
# word not in word2vec model: සලකනේ
# word not in word2vec model: විදලද
# word not in word2vec model: මිනිසාෙග්
# word not in word2vec model: අාදෙරන්
# word not in word2vec model: අාදරණීය
# word not in word2vec model: පෝතකයන්
# word not in word2vec model: කොටුකරලා
# word not in word2vec model: සතාගේ
# word not in word2vec model: මොණරෙත්
# word not in word2vec model: ‍මොකක්හරි
# word not in word2vec model: තවුතිසාවේ
# word not in word2vec model: සෝබනකාරයෝ
# word not in word2vec model: ඉන්නරට
# word not in word2vec model: ඉපුදුණේ
# word not in word2vec model: බීසීසී
# word not in word2vec model: බීසීසීය
# word not in word2vec model: දේශප්‍රේමීත්වය
# word not in word2vec model: පරම්පාරාවම
# word not in word2vec model: ගෙන්නන්නෙ?
# word not in word2vec model: පරම්පාරාවම
# word not in word2vec model: ගෙන්නන්නෙ?
# word not in word2vec model: පරම්පාරාවම
# word not in word2vec model: ගෙන්නන්නෙ?
# word not in word2vec model: වෙලෙන්දො
# word not in word2vec model: පටන්ගන්නවාට
# word not in word2vec model: කරගෙනයෑමට
# word not in word2vec model: ඔපන්
# word not in word2vec model: ගන්නවනං
# word not in word2vec model: දියුනුවෙමු
# word not in word2vec model: අහියෝගයක්
# word not in word2vec model: අහියෝගයක්
# word not in word2vec model: අහියෝගයක්
# word not in word2vec model: මිත්රෝන්
# word not in word2vec model: කබාසිනියකරන
# word not in word2vec model: ප්‍රකාශ්
# word not in word2vec model: 48000
# word not in word2vec model: අගමැතිමේ
# word not in word2vec model: සැපවින්දා
# word not in word2vec model: කුමන්ත්‍රණකාරයින්
# word not in word2vec model: ගෙදරටවෙලා
# word not in word2vec model: ආදර්ශයක
# word not in word2vec model: මනසිකයන්
# word not in word2vec model: මතපැන්
# word not in word2vec model: හරියනම
# word not in word2vec model: ළමයකුටවත්
# word not in word2vec model: හේත්තුවුණ
# word not in word2vec model: පියුන්ගේ
# word not in word2vec model: ෆ‍්‍රෑන්ක්
# word not in word2vec model: ෆෙනර්
# word not in word2vec model: දොඩංගොඩයි
# word not in word2vec model: ශුක්‍රාණු
# word not in word2vec model: වැඩිවුනොත්
# word not in word2vec model: ළි‍ඳේ
# word not in word2vec model: ඇමෙරිකව
# word not in word2vec model: දාහතරම
# word not in word2vec model: සංහාරක
# word not in word2vec model: නානායක්කාරට
# word not in word2vec model: මහින්දීයයක්
# word not in word2vec model: ලෝපතල
# word not in word2vec model: කීර්ථියෙනි
# word not in word2vec model: දිනදිනා
# word not in word2vec model: කීර්තියෙනි
# word not in word2vec model: ලෝපතල
# word not in word2vec model: කීර්ථියෙනි
# word not in word2vec model: දිනදිනා
# word not in word2vec model: කීර්තියෙනි
# word not in word2vec model: පරිත්‍යාගවලින්
# word not in word2vec model: බිහිවූවක්
# word not in word2vec model: පරිත්‍යාගවලින්
# word not in word2vec model: බිහිවූවක්
# word not in word2vec model: රිච්මන්ඩ්වරයකු
# word not in word2vec model: ස්පා
# word not in word2vec model: ට්‍රීට්මන්ට්
# word not in word2vec model: ස්පා
# word not in word2vec model: ස්පා
# word not in word2vec model: සීයාකෙනෙකු
# word not in word2vec model: ගනකාධිකාරිනියන්
# word not in word2vec model: ගැහුනාම
# word not in word2vec model: රවටාගත්
# word not in word2vec model: ස්පා
# word not in word2vec model: සක්කරවට්ටමකට
# word not in word2vec model: චමිකා
# word not in word2vec model: අපහරණයට
# word not in word2vec model: චරිතවත්ම
# word not in word2vec model: බොරුකරියෝ
# word not in word2vec model: ස්පා
# word not in word2vec model: යතිවරෙයක්
# word not in word2vec model: වැන්නවුත්
# word not in word2vec model: සමැදා
# word not in word2vec model: පූජාපිටිය
# word not in word2vec model: ආදීය
# word not in word2vec model: හොදකරන්න
# word not in word2vec model: ආත්මයකදීත්
# word not in word2vec model: විසිවේවී
# word not in word2vec model: තැනක්දෙන
# word not in word2vec model: අවධාරනය
# word not in word2vec model: තැනක්දෙන
# word not in word2vec model: පෙරමුණයි
# ...
# word not in word2vec model: පාපයක්ද?
# word not in word2vec model: දිනයයට
# word not in word2vec model: ෆොනසේකා
# word not in word2vec model: පත්තුකරල
# word not in word2vec model: ඩෙගානටනවා
# word not in word2vec model: ඒමනුෂ්‍යයාට
# word not in word2vec model: වරයාණනි
# word not in word2vec model: ‍භේදයෙන්
# word not in word2vec model: පුත්ත්‍රයෙකි
# word not in word2vec model: රැකවරනයි෴
# word not in word2vec model: බාලගිරිදෝසය
# word not in word2vec model: මුලපිරූ
# word not in word2vec model: පැවැත්වුණත්
# word not in word2vec model: නොපැවැත්වුණත්
# word not in word2vec model: ගිණිතියල
# word not in word2vec model: විවේචයක්
# word not in word2vec model: නිරයම
# word not in word2vec model: ඇවිදිල්ලේ
# word not in word2vec model: විලක්කුවක්
# word not in word2vec model: ජීවනවියදම්
# word not in word2vec model: දල්වන්නෙ
# word not in word2vec model: මනුෂ්‍යයිනි
# word not in word2vec model: ඉපදීම්
# word not in word2vec model: බ්‍රස්පති
# word not in word2vec model: ලැබිලානේ?
# word not in word2vec model: බලපානවද
# word not in word2vec model: ස්පින්
# word not in word2vec model: ආදරයටම
# word not in word2vec model: ස්වභාවයවත්
# word not in word2vec model: බ්‍රස්පති
# word not in word2vec model: දිගලු
# word not in word2vec model: හිතවතියනි
# word not in word2vec model: ඉල්ලද්දි
# word not in word2vec model: Fනිදහස
# word not in word2vec model: වැජඹිය
# word not in word2vec model: වැජඹිය
# word not in word2vec model: තාතත්ට
# word not in word2vec model: පිළිපදින්නට
# word not in word2vec model: තියපුවාම
# word not in word2vec model: “අම්මා
# word not in word2vec model: සඳකි
# word not in word2vec model: හිරුය
# word not in word2vec model: දිලි“
# word not in word2vec model: “පියාණනි
# word not in word2vec model: අපාරවූ
# word not in word2vec model: හිතිලාවත්
# word not in word2vec model: අංගුලිමාලා
# word not in word2vec model: මහනවිය
# word not in word2vec model: උපසකල
# word not in word2vec model: පහුවෙනතුරු
# word not in word2vec model: පින්කඳන්
# word not in word2vec model: අසමත්කම
# word not in word2vec model: අපච්චිට
# word not in word2vec model: බැරිවට
# word not in word2vec model: වැඩීමටත්
# word not in word2vec model: දැරීමටත්
# word not in word2vec model: එකක්වේවි
# word not in word2vec model: කතාකරවට
# word not in word2vec model: නිශ්ශබ්දවම
# word not in word2vec model: අංගොඩින්වත්
# word not in word2vec model: කලදවස?
# word not in word2vec model: මරාහරි
# word not in word2vec model: උරුම්
# word not in word2vec model: වැඩකටයුතුත්
# word not in word2vec model: රඟදක්වන්නේ
# word not in word2vec model: රාළලා
# word not in word2vec model: අයවනේ
# word not in word2vec model: වෙනමොනවා
# word not in word2vec model: ගොපිලයෝ
# word not in word2vec model: ගැලවුම්කරුවන්
# word not in word2vec model: හෙලිවනවිට
# word not in word2vec model: දෙපරන්ද
# word not in word2vec model: ගරහ
# word not in word2vec model: ඇරියොත්﻿
# word not in word2vec model: හා‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# word not in word2vec model: නො‍වෑ
# word not in word2vec model: දෙදෙනවත්
# word not in word2vec model: ප්‍රවෘත්තිමය
# word not in word2vec model: විපක්ෂේයෙත්
# word not in word2vec model: ලේකම්වරයකු
# word not in word2vec model: නිදිවදිනවද
# word not in word2vec model: green
# word not in word2vec model: card
# word not in word2vec model: නොසන්දල්යෝ
# word not in word2vec model: පෙළපාළියට
# word not in word2vec model: බෙබේල
# word not in word2vec model: ප්‍රයෝජයක්
# word not in word2vec model: දේට​
# word not in word2vec model: රථයකටත්
# word not in word2vec model: මිලේච්චයෝ
# word not in word2vec model: කියගත්තොත්
# word not in word2vec model: පාදයාත්‍රාව
# word not in word2vec model: දේසපාලකයාගේ
# word not in word2vec model: පොට්ටවුණු
# word not in word2vec model: ඉපදිලනොව
# word not in word2vec model: හූමිටිතියන්නත්
# word not in word2vec model: වට්ටගත්තා
# word not in word2vec model: නුදුරින්මයි
# word not in word2vec model: අලුත්ගමගේ
# word not in word2vec model: කැගහනන
# word not in word2vec model: කුජිතඊ
# word not in word2vec model: ළමයාගේවැඩේ
# word not in word2vec model: විරාජ්ගේ
# word not in word2vec model: ආදරයනම්
# word not in word2vec model: තමයිහදන්නේ
# word not in word2vec model: මේව්ගෙ
# word not in word2vec model: වලකන්නේ
# word not in word2vec model: දීරිඝායු
# word not in word2vec model: චලනි
# word not in word2vec model: ඩෑන්
# word not in word2vec model: බ්‍රවුන්ගේ
# word not in word2vec model: පෙන්වුවට
# word not in word2vec model: පුරෝගාමීන්
# word not in word2vec model: මුහුණුවරපෙනෙන්න
# word not in word2vec model: අාත්මාර්ථකමිත්වය
# word not in word2vec model: ශිෂ්‍යයෝයි
# word not in word2vec model: දැනගන්නවත්
# word not in word2vec model: සහභිගිවීමම
# word not in word2vec model: ධජයට
# word not in word2vec model: හුළඟටත්
# word not in word2vec model: සිදුවන්නටත්
# word not in word2vec model: ඒවිදිහට
# word not in word2vec model: රන්ඳයි
# word not in word2vec model: ජයමෙන්
# word not in word2vec model: 91%ක්
# word not in word2vec model: විස්‌වාසය
# word not in word2vec model: @කරොලිදස්
# word not in word2vec model: කොරන්නෑ
# word not in word2vec model: ඉදින්කෝ
# word not in word2vec model: පරදේසක්කාරයෝවත්
# word not in word2vec model: බිඳදමනවා
# word not in word2vec model: දුරකථනත්
# word not in word2vec model: පෙරහරටත්
# word not in word2vec model: එක්කරල
# word not in word2vec model: ඉන්ගිනේරුවන්ගෙන්
# word not in word2vec model: ප්‍රබේදයවත්
# word not in word2vec model: ප්‍රබේදයවත්
# word not in word2vec model: දුප්පත්රටේ
# word not in word2vec model: සැපිරීමට
# word not in word2vec model: මෙහෙයවීමම
# word not in word2vec model: දේවා
# word not in word2vec model: මිතොටමුල්ලේ
# word not in word2vec model: ආකල
# word not in word2vec model: විස‍ඳේ
# word not in word2vec model: දැවිමේදී
# word not in word2vec model: පුච්චපුවම
# word not in word2vec model: නිපැයුම්කරු
# word not in word2vec model: නිපැයුම්කරු
# word not in word2vec model: නිපදෙව්වේ
# word not in word2vec model: උල්ලංගනයවීම්
# word not in word2vec model: ද්‍රෝහීව
# word not in word2vec model: පන්නනතුරුම
# word not in word2vec model: වැයුවා
# word not in word2vec model: ඩයස්පොරා
# word not in word2vec model: අසරණවෙද්දී
# word not in word2vec model: පාපතරයින්ව
# word not in word2vec model: තොන්ඩුවක්දාල
# word not in word2vec model: පිරිහිලාද?කෙතරම්
# word not in word2vec model: බාගෙකින්
# word not in word2vec model: තාත්ත‍‍
# word not in word2vec model: බිලිවේවි
# word not in word2vec model: තාත්ත‍‍
# word not in word2vec model: සිත්‍රී
# word not in word2vec model: පත්තුවෙන්නෙත්
# word not in word2vec model: රැක්කාට
# word not in word2vec model: විශ්වාසනීයව
# word not in word2vec model: මෙළොවට
# word not in word2vec model: ලාකිකයෙක්
# word not in word2vec model: අවවාදාදය
# word not in word2vec model: ඉස්තුතිය්
# word not in word2vec model: මවුරටටයි
# word not in word2vec model: විශ්වාසනීයව
# word not in word2vec model: මාධ්‍යවේදියායි
# word not in word2vec model: අමවාර්ථ
# word not in word2vec model: වාර්තාකරන
# word not in word2vec model: රටේසම්පත්
# word not in word2vec model: මේපොඩි
# word not in word2vec model: සහන්ට
# word not in word2vec model: හෝදගන්න
# word not in word2vec model: මරාගැනීමේ
# word not in word2vec model: මට්ටමකය
# word not in word2vec model: පලවිකාප
# word not in word2vec model: ක්‍රීඩිකාවක්
# word not in word2vec model: මතක්වුණේ
# word not in word2vec model: මෑතකදිනේ
# word not in word2vec model: පොරෝජනයක්
# word not in word2vec model: කවපෙත්ත්
# word not in word2vec model: යගුලිය
# word not in word2vec model: ක්‍රීඩකයින්ගෙන්
# word not in word2vec model: තිබෙනදේවත්
# word not in word2vec model: ආකර්ෂණ
# word not in word2vec model: අනාථාගාරයේ
# word not in word2vec model: ඡායාරූපයකට
# word not in word2vec model: අයකරලත්
# word not in word2vec model: ශ්‍රීලාල්ගේ
# word not in word2vec model: සංස්කෘතිකාංගවල
# word not in word2vec model: නොහෙලූ
# word not in word2vec model: හිස්වුණ
# word not in word2vec model: ශිෂ්ටචාරය
# word not in word2vec model: හලවන්න
# word not in word2vec model: පරදිද
# word not in word2vec model: බෙදයත්
# word not in word2vec model: අත්අරින්නේ
# word not in word2vec model: අවමංගල්‍යය
# word not in word2vec model: සාපෙළවත්?
# word not in word2vec model: රැකෙන්නට
# word not in word2vec model: අධෙර්යයමත්
# word not in word2vec model: ඔයාලගේ
# word not in word2vec model: ජනගහනයම
# word not in word2vec model: නොපෙනෙනෙන
# word not in word2vec model: ජනාධිපතිවරණෙට
# word not in word2vec model: තොටුපොලයි
# word not in word2vec model: කුමාරලගේ
# word not in word2vec model: පිච්චුව
# word not in word2vec model: අනහි
# word not in word2vec model: රඟේ?
# word not in word2vec model: ගේමක්නේ
# word not in word2vec model: කපුවගෙන්
# word not in word2vec model: අහුවෙනවනේ?
# word not in word2vec model: ශාන්තිකර්මය
# word not in word2vec model: කපෝතිම
# word not in word2vec model: ගාවටයි
# word not in word2vec model: වගකියයුතුයි
# word not in word2vec model: එළිවෙන්නෙ
# word not in word2vec model: මන්දබුද්දිකයෝ
# word not in word2vec model: දදැක්කම
# word not in word2vec model: මන්තරගුරුකම්
# word not in word2vec model: මන්ත්‍රීලනම්
# word not in word2vec model: හමිමෝ
# word not in word2vec model: පැමින්නේ
# word not in word2vec model: වංචාවන්ට?
# word not in word2vec model: සුබවාදීවේගෙන
# word not in word2vec model: කඩවුණු
# word not in word2vec model: කාමාග්නියෙන්
# word not in word2vec model: දසවද
# word not in word2vec model: දැමියා
# word not in word2vec model: මෙමත්
# word not in word2vec model: පුරුද්දක්දෝ
# word not in word2vec model: අවිශ්වාසම
# word not in word2vec model: පද්මිනිගේ
# word not in word2vec model: හෑබෑට
# word not in word2vec model: රජවෙච්ච
# word not in word2vec model: එහමනේ
# word not in word2vec model: වත්කමක්?
# word not in word2vec model: ජැකලීන්
# word not in word2vec model: ජැකලීන්
# word not in word2vec model: ෆර්නැන්ඩස්ගේ
# word not in word2vec model: සූපවේදියෝ
# word not in word2vec model: සූපවේදියෝ
# word not in word2vec model: ඉන්දිවේ
# word not in word2vec model: මේනිසා
# word not in word2vec model: ශාඛාවල්
# word not in word2vec model: ජැකලීන්
# word not in word2vec model: එංගලන්නේ
# word not in word2vec model: ඇමැරිකාවේ
# word not in word2vec model: එකවම
# word not in word2vec model: පුරුදුකළ
# word not in word2vec model: දෙමව්පියෝ
# word not in word2vec model: මැරුවාද?
# word not in word2vec model: මරණයෙනුත්
# word not in word2vec model: අසත්පුරුෂයෝද
# word not in word2vec model: වෙන්නේ‍?
# word not in word2vec model: නතකරන්න
# word not in word2vec model: ලංකාද්වීපයද
# word not in word2vec model: ‘හු‘
# word not in word2vec model: තමුන්නාන්සේවනේ
# word not in word2vec model: නවලවත්
# word not in word2vec model: අල්ලුවා
# word not in word2vec model: හීනමනයකු
# word not in word2vec model: ???මේක
# word not in word2vec model: නැමිල්ල????
# word not in word2vec model: චාන්ද්
# word not in word2vec model: හිවල්ලුම
# word not in word2vec model: තකතීරුවෝම
# word not in word2vec model: ඇදකුල
# word not in word2vec model: අංගසමිපූර්ණ
# word not in word2vec model: පරීක්ෂණට
# word not in word2vec model: සංවිධානයවූ
# word not in word2vec model: ස්වාමිපුරුෂයෙක්
# word not in word2vec model: බලවතෙන්
# word not in word2vec model: කිරිවලි
# word not in word2vec model: කරුණවන්ත
# word not in word2vec model: 435
# word not in word2vec model: 874
# word not in word2vec model: නොහැකිවුණ
# word not in word2vec model: තෑග්ගලු
# word not in word2vec model: අටඅනූවක්
# word not in word2vec model: තත්ත්වයද
# word not in word2vec model: ප්‍රහරයකට
# word not in word2vec model: ලක්නොවේවා
# word not in word2vec model: පිලිසියට
# word not in word2vec model: දැම්මාහම
# word not in word2vec model: මෙහයවයි
# word not in word2vec model: උද්ඝා්ෂණය
# word not in word2vec model: මහාචර්යා
# word not in word2vec model: විනිමයලු
# word not in word2vec model: දුලි
# word not in word2vec model: දුලී
# word not in word2vec model: දුලී
# word not in word2vec model: උදව්වෙන්ද
# word not in word2vec model: දුලි
# word not in word2vec model: එන්නබැරි
# word not in word2vec model: අනාරක්ශාකාරියි
# word not in word2vec model: අවොත්උඹවත්
# word not in word2vec model: සමහරුන්ගේ?
# word not in word2vec model: බාවයකට
# word not in word2vec model: දියයුතුව
# word not in word2vec model: 62?
# word not in word2vec model: දූෂිතයන්ටත්
# word not in word2vec model: දෙකඩවීමකට
# word not in word2vec model: සුභුපතුමි
# word not in word2vec model: වේයන්
# word not in word2vec model: ඔබකළ
# word not in word2vec model: ගුණමකුවූ
# word not in word2vec model: මහත්තයා​
# word not in word2vec model: නැඟිලා
# word not in word2vec model: වැඩපිළිවෙලටයි
# word not in word2vec model: ඒදඩු
# word not in word2vec model: අනගතයට
# word not in word2vec model: දෙයක්නෙමෙයි
# word not in word2vec model: ශ්‍රමධාන
# word not in word2vec model: එලසින
# word not in word2vec model: වැටෙනතුරුද?
# word not in word2vec model: බැණගන්නවා
# word not in word2vec model: අන්ධවෙලාද?
# word not in word2vec model: අවදියේම
# word not in word2vec model: වැළදුනොත්
# word not in word2vec model: වැළදුනා
# word not in word2vec model: ඒඩිස්
# word not in word2vec model: සෙල්ලමිබඩුවක්
# word not in word2vec model: කෝලමක්ද
# word not in word2vec model: බොරුකියලා
# word not in word2vec model: කාමුකව
# word not in word2vec model: නාරදටයි
# word not in word2vec model: ජාත්‍යන්තරයයි
# word not in word2vec model: හිතවාදිනුයි
# word not in word2vec model: උද්ඝෝෂණයයි
# word not in word2vec model: සහජිවනෙයි
# word not in word2vec model: පළදෙන්නට
# word not in word2vec model: බෞද්ධයින්ටයි
# word not in word2vec model: අභිමතාර්ථය
# word not in word2vec model: හිතෙට
# word not in word2vec model: ඩොලර්වලට
# word not in word2vec model: ජිවත්වෙන්නෙ
# word not in word2vec model: මහපරිමාණ
# word not in word2vec model: ලෝකයකද
# word not in word2vec model: පනතවත්
# word not in word2vec model: කොම්පැනියි
# word not in word2vec model: සූරාකෑමනේ
# word not in word2vec model: මාෆියාවම
# word not in word2vec model: ඉල්ලන්නේත්?
# word not in word2vec model: ලෙදකට
# word not in word2vec model: මාෆියාවන්
# word not in word2vec model: වෙදැදුරන්ට
# word not in word2vec model: විකුණාගැනීමත්
# word not in word2vec model: ගස්සාකන්නන්
# word not in word2vec model: බෙහෙතකින්ම
# word not in word2vec model: පනතට?
# word not in word2vec model: අර්බුදවල
# word not in word2vec model: JR
# word not in word2vec model: නැමුවාට
# word not in word2vec model: නායකයාලු
# word not in word2vec model: අසානැති
# word not in word2vec model: ආත්මර්ථකාමි
# word not in word2vec model: අපකිර්ති
# word not in word2vec model: ජනාධිපතිවරයාය
# word not in word2vec model: ඔබකිවා
# word not in word2vec model: දෙසපාලනඥයා
# word not in word2vec model: අමහ
# word not in word2vec model: රජිවූ
# word not in word2vec model: තමපුත්
# word not in word2vec model: වුවමණාවත්
# word not in word2vec model: කබරයන්සේ
# word not in word2vec model: නිදිවදියි
# word not in word2vec model: පුතින්
# word not in word2vec model: 35000ක
# word not in word2vec model: බාෂා
# word not in word2vec model: බඩුවට
# word not in word2vec model: බඩුවකට
# word not in word2vec model: පීරුවත්
# word not in word2vec model: බඩුවකට
# word not in word2vec model: ගෙන්නදී
# word not in word2vec model: ෆොර්න්
# word not in word2vec model: ගත්හු
# word not in word2vec model: තලන්නේ?
# word not in word2vec model: වාතාවක්
# word not in word2vec model: එලිකරන්න
# word not in word2vec model: නැදෑයන්ගෙ
# word not in word2vec model: භාවයෙන්මයි
# word not in word2vec model: නිළධාරීන්ගෙ
# word not in word2vec model: සේවකයෝ
# word not in word2vec model: අැතිනෙ
# word not in word2vec model: පුච්චාගන්නෙ
# word not in word2vec model: මොකටද?
# word not in word2vec model: මානූෂීය
# word not in word2vec model: රේගුවේ
# word not in word2vec model: දාන්නැතුව
# word not in word2vec model: පැමිණිල්ලක්වත්
# word not in word2vec model: බැරිදේකට
# word not in word2vec model: කුහකත්වයයි
# word not in word2vec model: හැදුවැයි
# word not in word2vec model: ෆයින්
# word not in word2vec model: ශෙයාර්
# word not in word2vec model: එක්සෑම්
# word not in word2vec model: ඊර්ෂ්‍යාවල්
# word not in word2vec model: ගසාකනවෝ
# word not in word2vec model: තනියෙන්මයි
# word not in word2vec model: දිවිනැගුමේ
# word not in word2vec model: දිවිනැගුනා
# word not in word2vec model: නඟාගත්
# word not in word2vec model: අාණ්ඩුවත්
# word not in word2vec model: අාණ්ඩුවත්
# word not in word2vec model: කෛයිරාටිකයන්ට
# word not in word2vec model: සෙවිල්ල
# word not in word2vec model: යමපාලනයක්ද??
# word not in word2vec model: ආණ්‌ඩුවේ
# word not in word2vec model: කොට්‌ඨාශයට
# word not in word2vec model: උවමනාවකින්
# word not in word2vec model: විමර්ශනයක්‌
# word not in word2vec model: කාරණයක්‌
# word not in word2vec model: ආණ්‌ඩුවේ
# word not in word2vec model: ආණ්‌ඩුවේ
# word not in word2vec model: දැරූවන්
# word not in word2vec model: අැමෙරිකාවෙි
# word not in word2vec model: වැරදුනොත්
# word not in word2vec model: අැමෙරිකාවෙි
# word not in word2vec model: අැතිව
# word not in word2vec model: මොඩයන්

# %%
main()
# Out:
# Running tesnsorflow simulation.....
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 100.0
# Accuracy for this batch: 54.16666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 75.0
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 54.16666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 75.0
# [197  59  30 194]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 66.66666865348816
# Accuracy for this batch: 75.0
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 75.0
# Accuracy for this batch: 75.0
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 100.0
# Accuracy for this batch: 100.0
# Accuracy for this batch: 87.5
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 100.0
# [191  40  31 218]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 100.0
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 62.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 87.5
# [148  44  22 266]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 100.0
# Accuracy for this batch: 100.0
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 100.0
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 87.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 83.33333134651184
# [195  17  43 225]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 100.0
# Accuracy for this batch: 100.0
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 75.0
# Accuracy for this batch: 62.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 100.0
# [212  40  29 199]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 87.5
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 75.0
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 66.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 75.0
# Accuracy for this batch: 87.5
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 100.0
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 87.5
# [231   9  61 179]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 100.0
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 100.0
# Accuracy for this batch: 87.5
# [203  15  43 219]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 87.5
# Accuracy for this batch: 75.0
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 75.0
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 95.83333134651184
# [174  19  24 263]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 75.0
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 87.5
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 75.0
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 100.0
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 95.83333134651184
# [270  20  30 160]
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-499
# saved to /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/University/FYP/Sentiment Analysis/Implementation/Sentiment-tagger/RNN/models/from_fasttext/5/pretrained_lstm.ckpt-998
# Accuracy for this batch: 87.5
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 87.5
# Accuracy for this batch: 91.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 100.0
# Accuracy for this batch: 75.0
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 70.83333134651184
# Accuracy for this batch: 95.83333134651184
# Accuracy for this batch: 79.16666865348816
# Accuracy for this batch: 100.0
# Accuracy for this batch: 66.66666865348816
# Accuracy for this batch: 66.66666865348816
# Accuracy for this batch: 83.33333134651184
# Accuracy for this batch: 87.5
# Accuracy for this batch: 54.16666865348816
# Accuracy for this batch: 95.83333134651184
# [265  63   9 143]
# +-------------+--------------------+--------------------+--------------------+--------------------+
# |  Algorithm  |      Accuracy      |     Precision      |       Recall       |      F1_Score      |
# +-------------+--------------------+--------------------+--------------------+--------------------+
# |  iteration2 | 0.8145833333333333 | 0.766798418972332  | 0.8660714285714286 | 0.8134171907756814 |
# |  iteration3 | 0.8520833333333333 | 0.8449612403100775 | 0.8755020080321285 | 0.8599605522682445 |
# |  iteration4 |       0.8625       | 0.8580645161290322 | 0.9236111111111112 | 0.8896321070234114 |
# |  iteration5 |       0.875        | 0.9297520661157025 | 0.8395522388059702 | 0.8823529411764706 |
# |  iteration6 |      0.85625       | 0.8326359832635983 | 0.8728070175438597 | 0.8522483940042828 |
# |  iteration7 | 0.8541666666666666 | 0.9521276595744681 | 0.7458333333333333 | 0.836448598130841  |
# |  iteration8 | 0.8791666666666667 | 0.9358974358974359 | 0.8358778625954199 | 0.8830645161290323 |
# |  iteration9 | 0.9104166666666667 | 0.9326241134751773 | 0.9163763066202091 | 0.9244288224956063 |
# | iteration10 | 0.8958333333333334 | 0.8888888888888888 | 0.8421052631578947 | 0.8648648648648649 |
# | iteration11 |        0.85        | 0.6941747572815534 | 0.9407894736842105 | 0.7988826815642458 |
# |    final    |       0.865        | 0.8637123745819398 | 0.8651591289782244 | 0.8644351464435147 |
# +-------------+--------------------+--------------------+--------------------+--------------------+
# [2086  326  322 2066]
# [[2086  326]
#  [ 322 2066]]
# Time taken for the process: 532.7527823448181
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# Results from 100 epochs
#
# +-------------+--------------------+--------------------+--------------------+--------------------+
# |  Algorithm  |      Accuracy      |     Precision      |       Recall       |      F1_Score      |
# +-------------+--------------------+--------------------+--------------------+--------------------+
# |  iteration2 | 0.7479166666666667 | 0.8456375838926175 |       0.5625       | 0.6756032171581771 |
# |  iteration3 |      0.74375       | 0.8705882352941177 | 0.5943775100401606 | 0.7064439140811456 |
# |  iteration4 | 0.8083333333333333 | 0.9336283185840708 | 0.7326388888888888 | 0.8210116731517509 |
# |  iteration5 | 0.7666666666666667 | 0.9148936170212766 | 0.6417910447761194 | 0.7543859649122806 |
# |  iteration6 |       0.775        | 0.8571428571428571 | 0.631578947368421  | 0.7272727272727273 |
# |  iteration7 | 0.7708333333333334 | 0.8963414634146342 |       0.6125       | 0.7277227722772278 |
# |  iteration8 | 0.8020833333333334 | 0.8812785388127854 | 0.7366412213740458 | 0.8024948024948024 |
# |  iteration9 | 0.7854166666666667 | 0.9380952380952381 | 0.686411149825784  | 0.7927565392354124 |
# | iteration10 | 0.8041666666666667 | 0.8243243243243243 | 0.6421052631578947 | 0.7218934911242604 |
# | iteration11 | 0.8083333333333333 | 0.7380952380952381 | 0.6118421052631579 | 0.6690647482014388 |
# |    final    |      0.78125       | 0.878393665158371  | 0.6503350083752094 | 0.7473532242540905 |
# +-------------+--------------------+--------------------+--------------------+--------------------+
# [2197  215  835 1553]
# [[2197  215]
#  [ 835 1553]]
